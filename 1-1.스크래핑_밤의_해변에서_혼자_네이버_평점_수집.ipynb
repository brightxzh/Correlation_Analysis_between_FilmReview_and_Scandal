# %% [markdown]
# <a href="https://colab.research.google.com/github/brightxzh/movie_review/blob/main/1-1.%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EB%B0%A4%EC%9D%98_%ED%95%B4%EB%B3%80%EC%97%90%EC%84%9C_%ED%98%BC%EC%9E%90_%EB%84%A4%EC%9D%B4%EB%B2%84_%ED%8F%89%EC%A0%90_%EC%88%98%EC%A7%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 156465 ## 밤의 해변에서 혼자
total_count = 1893  ## 전체 크기=1,893

# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false#

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20201023150533" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20201023150533" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20201023150533" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20201023150533" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="156465"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>1,893</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443703, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>이상현(lshk****)</span>
# </a>
# </em>
# <em>2017.03.23 01:01</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lshk****', 'WMOWt5PhWBXtBd7MQqmZzdZHUPvfVhwlHwXM0UMPJDg=', '제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다. ', '12443703', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443703">2254</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443703">720</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																누군가에게는 상처일수도 있는 일들이.. 공공연하게 떠벌려지고.. 영화까지...본인들끼리의 사랑이라면 사랑일수있지만 다른사람에게 상처는 최대한 덜줍시다..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443776, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>7112****</span>
# </a>
# </em>
# <em>2017.03.23 01:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','7112****', '9OuEiY2xVy5FgRfh9eyf6g8bjkfJYjfwnJ5f5j6AX3E=', '누군가에게는 상처일수도 있는 일들이.. 공공연하게 떠벌려지고.. 영화까지...본인들끼리의 사랑이라면 사랑일수있지만 다른사람에게 상처는 최대한 덜줍시다.. ', '12443776', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443776">1689</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443776">469</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																너무별로에요 드러워요
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443995, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>qkrs****</span>
# </a>
# </em>
# <em>2017.03.23 04:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','qkrs****', '8z+wQ80eTuvBATq/0eJQ/GfcTMDRITaSc8QEIcBvIrw=', '너무별로에요 드러워요 ', '12443995', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443995">1492</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443995">454</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																역겨워서 못 볼거같아~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443836, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>카이(tlsc****)</span>
# </a>
# </em>
# <em>2017.03.23 02:04</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','tlsc****', '3yiCIDFgY4C3Opt+ss1Bnri7v/kLiKzMCuwX3pn3lwU=', '역겨워서 못 볼거같아~ ', '12443836', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443836">1276</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443836">423</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																지나친 사랑의 자유는 예술이 아니다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12444028, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>누군가(jhh1****)</span>
# </a>
# </em>
# <em>2017.03.23 04:48</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','jhh1****', '5/DXosTI4bdY6NwsKUmIpXxfxO/MZyLX1/j7Kqs1+uU=', '지나친 사랑의 자유는 예술이 아니다 ', '12444028', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12444028">1216</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12444028">374</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:30.0%"></span></span><em>3</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																자기들에대한 쉴드가 지나침
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12446379, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>vmfm****</span>
# </a>
# </em>
# <em>2017.03.23 22:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','vmfm****', 'mmyHgmdys54ErzfFD4j5D4VNkkMv2ap7QGu9+jJ2u0A=', '자기들에대한 쉴드가 지나침 ', '12446379', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12446379">906</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12446379">208</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:20.0%"></span></span><em>2</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																불륜도 예술이 될 수 있어서 좋겠다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443615, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>베짱베짱(hpla****)</span>
# </a>
# </em>
# <em>2017.03.23 00:31</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','hpla****', 'Z/GPRkLZ4KoqgRNZirdcc+iTdooOxUCNVNO0Pa0oGSQ=', '불륜도 예술이 될 수 있어서 좋겠다 ', '12443615', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443615">974</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443615">294</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																이거 영화보는사람도 있네 7위나 하다니
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443635, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>킬디에이전트(rjk0****)</span>
# </a>
# </em>
# <em>2017.03.23 00:38</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','rjk0****', 'zi7YVj52ffsA/5cl1boepBFYSlXP8yVsJMSGDlZgo9E=', '이거 영화보는사람도 있네 7위나 하다니 ', '12443635', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443635">854</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443635">255</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:20.0%"></span></span><em>2</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																뻔하디뻔한 불륜이야기...불륜하는사람 마음은 특별할거없 이 늘 똑같다..그러니 제발 조용히 사랑하길....
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12444136, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>지구형행성(yuha****)</span>
# </a>
# </em>
# <em>2017.03.23 08:06</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','yuha****', 'yS3jWoFKr2ls17ao7FfvGq4zLfQr3ZOAAQOE9a2r5I4=', '뻔하디뻔한 불륜이야기...불륜하는사람 마음은 특별할거없 이 늘 똑같다..그러니 제발 조용히 사랑하길.... ', '12444136', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12444136">812</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12444136">218</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
# <span class="_unfold_ment" id="_unfold_ment9">
# <a data-src="늙은 할아범이랑 삼십대에 멀대같은 여자가 사랑타령하는 영화를 보면 내 시간이 너무도 아까울거 같은데 ㅋㅋㅋㅋ 할아범은 자기자식을 위해서라도 정신차리고 늙은여우는 정신차리고 해외로 귀화하길 물론 노망난 할아범도 같이 ㅋㅋㅋㅋ 내 의견 고맙다고? 천만에~ " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		늙은 할아범이랑 삼십대에 멀대같은 여자가 사랑타령하는 영화를 보면 내 시간이 너무도 아까울거 같은데 ㅋㅋㅋㅋ 할아범은 자기자식을 위해서라도 정신차리고 늙은여우는 정신차리고 해외로 귀화하길 물론 노망난 할아범도 같이 ...
# 																	</a>
# </span>
# </span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443608, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>장윤영(wkdd****)</span>
# </a>
# </em>
# <em>2017.03.23 00:28</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','wkdd****', 'ytYmaBh/3jw2yaG8rc7ChmUQfdciVTNQstPGagXcBe8=', '늙은 할아범이랑 삼십대에 멀대같은 여자가 사랑타령하는 영화를 보면 내 시간이 너무도 아까울거 같은데 ㅋㅋㅋㅋ 할아범은 자기자식을 위해서라도 정신차리고 늙은여우는 정신차리고 해외로 귀화하길 물론 노망난 할아범도 같이 ㅋㅋㅋㅋ 내 의견 고맙다고? 천만에~ ', '12443608', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443608">840</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443608">264</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=156465&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "156465",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=156465#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=156465&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=156465#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("156465", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443703, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>이상현(lshk****)</span>
# </a>
# </em>
# <em>2017.03.23 01:01</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lshk****', 'WMOWt5PhWBXtBd7MQqmZzdZHUPvfVhwlHwXM0UMPJDg=', '제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다. ', '12443703', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443703">2254</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443703">720</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																누군가에게는 상처일수도 있는 일들이.. 공공연하게 떠벌려지고.. 영화까지...본인들끼리의 사랑이라면 사랑일수있지만 다른사람에게 상처는 최대한 덜줍시다..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(12443776, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>7112****</span>
# </a>
# </em>
# <em>2017.03.23 01:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','7112****', '9OuEiY2xVy5FgRfh9eyf6g8bjkfJYjfwnJ5f5j6AX3E=', '누군가에게는 상처일수도 있는 일들이.. 공공연하게 떠벌려지고.. 영화까지...본인들끼리의 사랑이라면 사랑일수있지만 다른사람에게 상처는 최대한 덜줍시다.. ', '12443776', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_12443776">1689</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_12443776">469</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다. \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다.'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '1'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('2254', '720')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# '이상현(lshk****)'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2017, 3, 23, 1, 1)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 156465
total_count = 1893  ## 전체 크기=1893

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['이상현(lshk****)',
#   '제 정신 아닌 년/놈들이 만든 영화를 예술로 만들어 주는 세상이 역겹다.',
#   '1',
#   '2254',
#   '720',
#   datetime.datetime(2017, 3, 23, 1, 1),
#   0],
#  ['7112****',
#   '누군가에게는 상처일수도 있는 일들이.. 공공연하게 떠벌려지고.. 영화까지...본인들끼리의 사랑이라면 사랑일수있지만 다른사람에게 상처는 최대한 덜줍시다..',
#   '1',
#   '1689',
#   '469',
#   datetime.datetime(2017, 3, 23, 1, 33),
#   0],
#  ['qkrs****',
#   '너무별로에요 드러워요',
#   '1',
#   '1492',
#   '454',
#   datetime.datetime(2017, 3, 23, 4, 11),
#   0],
#  ['카이(tlsc****)',
#   '역겨워서 못 볼거같아~',
#   '1',
#   '1276',
#   '423',
#   datetime.datetime(2017, 3, 23, 2, 4),
#   0],
#  ['누군가(jhh1****)',
#   '지나친 사랑의 자유는 예술이 아니다',
#   '1',
#   '1216',
#   '374',
#   datetime.datetime(2017, 3, 23, 4, 48),
#   0],
#  ['vmfm****',
#   '자기들에대한 쉴드가 지나침',
#   '3',
#   '906',
#   '208',
#   datetime.datetime(2017, 3, 23, 22, 41),
#   '관람객'],
#  ['베짱베짱(hpla****)',
#   '불륜도 예술이 될 수 있어서 좋겠다',
#   '2',
#   '974',
#   '294',
#   datetime.datetime(2017, 3, 23, 0, 31),
#   0],
#  ['킬디에이전트(rjk0****)',
#   '이거 영화보는사람도 있네 7위나 하다니',
#   '1',
#   '854',
#   '255',
#   datetime.datetime(2017, 3, 23, 0, 38),
#   0],
#  ['지구형행성(yuha****)',
#   '뻔하디뻔한 불륜이야기...불륜하는사람 마음은 특별할거없 이 늘 똑같다..그러니 제발 조용히 사랑하길....',
#   '2',
#   '812',
#   '218',
#   datetime.datetime(2017, 3, 23, 8, 6),
#   0],
#  ['장윤영(wkdd****)',
#   '늙은 할아범이랑 삼십대에 멀대같은 여자가 사랑타령하는 영화를 보면 내 시간이 너무도 아까울거 같은데 ㅋㅋㅋㅋ 할아범은 자기자식을 위해서라도 정신차리고 늙은여우는 정신차리고 해외로 귀화하길 물론 노망난 할아범도 같이 ...',
#   '1',
#   '840',
#   '264',
#   datetime.datetime(2017, 3, 23, 0, 28),
#   0],
#  ['haha(rain****)',
#   '홍상수는 자기 가족보기를 아주 머같이 보는듯..가족들은 지금 가슴에 칼꽂아두고 사는기분일텐데...미안해서라도 조용히 지낼것이지..보란듯이 공식석상나와서 약올리고..이런영화까지내고..진짜잔인...그래서 이영화가 청불인...',
#   '1',
#   '599',
#   '103',
#   datetime.datetime(2017, 3, 23, 8, 0),
#   0],
#  ['amad****',
#   '아무리 꾸며도 불륜은 불륜. 아직 우리 사회가 이 정도 분별력은 있다고 믿는다.',
#   '1',
#   '560',
#   '117',
#   datetime.datetime(2017, 3, 23, 10, 1),
#   0],
#  ['sang****',
#   '평론가들 평점이 더역겹다ㅋㅋㅋ유식한척 꼴갑들떨고있네ㅋㅋㅋㅋ',
#   '1',
#   '496',
#   '98',
#   datetime.datetime(2017, 3, 23, 16, 32),
#   0],
#  ['hsam****',
#   '별로다... 대사 완전 오글 거리고 보는 내내 너무 불편했음',
#   '2',
#   '446',
#   '110',
#   datetime.datetime(2017, 3, 25, 13, 1),
#   '관람객'],
#  ['토토로(chun****)',
#   '관객수로 평가받기를~',
#   '1',
#   '460',
#   '140',
#   datetime.datetime(2017, 3, 23, 1, 22),
#   0],
#  ['ALL마이트(okok****)',
#   '멀쩡하던 집안이 한순간 풍비박산이 나버렸다 너희 둘은 일망타진 되였으면 한다',
#   '1',
#   '424',
#   '110',
#   datetime.datetime(2017, 3, 23, 7, 3),
#   0],
#  ['dddd(s115****)',
#   '더럽고 역겹고 토나온다',
#   '1',
#   '423',
#   '114',
#   datetime.datetime(2017, 3, 23, 10, 15),
#   0],
#  ['lyjj****',
#   '구역질이 자꾸나네 왜 일까?  인간이면 부끄너운줄 알아라.제발 .끼리끼리 노니까 지들이 정상인줄 알지?ㅠㅠ별하나도 아깝다.',
#   '1',
#   '381',
#   '99',
#   datetime.datetime(2017, 3, 23, 11, 54),
#   0],
#  ['sjk3****',
#   '불륜을 예술로 포장하지말라결국은 남아있는 가족들에게 정신적인 살인을 저지르는것과 다를바 없다',
#   '1',
#   '349',
#   '84',
#   datetime.datetime(2017, 3, 23, 17, 27),
#   0],
#  ['mylo****',
#   '내면의 불안함이 그대로 투영된 듯한 영화',
#   '1',
#   '324',
#   '66',
#   datetime.datetime(2017, 3, 25, 17, 10),
#   '관람객'],
#  ['love****',
#   '제정신 아닌 것들이 영화 찍는다고 애썼다.',
#   '1',
#   '318',
#   '80',
#   datetime.datetime(2017, 3, 23, 12, 29),
#   0],
#  ['수현사랑(ambt****)',
#   '한번뿐인  인생 . 똑바로 살자.',
#   '1',
#   '311',
#   '80',
#   datetime.datetime(2017, 3, 23, 11, 51),
#   0],
#  ['켱켱이(soo1****)',
#   '니네 이야기는이불속에서나 둘이 하세요!영화로 만들고 난리니 ㅎㅎ',
#   '1',
#   '274',
#   '76',
#   datetime.datetime(2017, 3, 23, 9, 31),
#   0],
#  ['날아(dbru****)',
#   '불륜을 미화한 영화. 이렇게라도 만드니까 예술 같고 마음이 편하니?',
#   '1',
#   '246',
#   '56',
#   datetime.datetime(2017, 3, 23, 17, 18),
#   0],
#  ['트리비아(blue****)',
#   '무슨 생각으로 이런 영화인지 다큐인지를 만들었는지...일기장에나 쓰시지.',
#   '1',
#   '252',
#   '63',
#   datetime.datetime(2017, 3, 23, 12, 57),
#   0],
#  ['샤이닝(shin****)',
#   '정말 남자로서 한 가정의 가장으로서 부끄럽습니다.',
#   '1',
#   '257',
#   '72',
#   datetime.datetime(2017, 3, 23, 11, 21),
#   0],
#  ['정미현(sona****)',
#   '홍감독님 영화만들 멘탈 상태가 아니었던듯',
#   '1',
#   '210',
#   '57',
#   datetime.datetime(2017, 3, 25, 21, 38),
#   '관람객'],
#  ['봉봉(cana****)',
#   '불륜은 불륜일뿐이지. 그게 어찌 사랑이 될수있나불륜도 당당하게 인정하는 시대. 세상 참 말세로다',
#   '1',
#   '208',
#   '63',
#   datetime.datetime(2017, 3, 23, 11, 58),
#   0],
#  ['6711****',
#   '대놓고 더러워 떡하니 드러워 뜨으으윽',
#   '1',
#   '205',
#   '63',
#   datetime.datetime(2017, 3, 23, 12, 27),
#   0],
#  ['율이준이맘(dian****)',
#   '이영화 보러 가지도 말고 관심을 끊자.',
#   '1',
#   '206',
#   '65',
#   datetime.datetime(2017, 3, 23, 10, 15),
#   0],
#  ['wnsr****',
#   '이영화는 반개줘야할것같아요',
#   '1',
#   '183',
#   '51',
#   datetime.datetime(2017, 3, 25, 22, 44),
#   '관람객'],
#  ['날 개(puhi****)',
#   '추천하고싶지 않은 영화',
#   '1',
#   '157',
#   '35',
#   datetime.datetime(2017, 3, 26, 20, 49),
#   '관람객'],
#  ['qipq****',
#   '망해라 인간이길 포기한것들 짐승이다',
#   '1',
#   '156',
#   '37',
#   datetime.datetime(2017, 3, 23, 19, 36),
#   0],
#  ['달토끼(pret****)',
#   '지금 둘이 뭐 대단한 예술 한다고 생각하나봐',
#   '1',
#   '140',
#   '23',
#   datetime.datetime(2017, 3, 24, 1, 4),
#   0],
#  ['885po(kuk9****)',
#   '세상에는 그  둘만 있는게 아니잖아요? 결혼을 했고 자식을 낳았으면 책임을 져야죠 . 단순히 둘만 좋자고 그런행동을하나요? 그러면 세상에 어쩔수없이 헤어지고 돌아서는 사람들은 덜사랑하거나 멍청해서 그럴까요 ㅋㅋ 어린...',
#   '1',
#   '148',
#   '31',
#   datetime.datetime(2017, 3, 24, 0, 47),
#   0],
#  ['kd03****',
#   '가정 파괴범이 영화 배우로 치장을 한다~이 세상에 도덕도 없고 윤리도 없다 . 천륜을 배반한  인간이여우 주연상을 받는  더럽고 부패한  연예계 이다.인생은 어차피 한번 왔다 가는건데 너무  김민희는 치욕적으로사는 ...',
#   '1',
#   '143',
#   '28',
#   datetime.datetime(2017, 3, 23, 21, 31),
#   0],
#  ['별(ping****)',
#   '1점도 아깝네요 ㅎㅎㅎ',
#   '1',
#   '143',
#   '33',
#   datetime.datetime(2017, 3, 23, 10, 27),
#   0],
#  ['제이호(amul****)',
#   '별루엿어요ㅠㅠ 지루하고 잠오고 ㅠㅠ',
#   '1',
#   '129',
#   '24',
#   datetime.datetime(2017, 3, 23, 19, 12),
#   0],
#  ['hoya****',
#   '안좋은 평에도 불구하고 조그마한 기대를 가지고 찾은 나를 책망할정도로 의미없는 영화였다. 중간에 나오고 싶었지만 예매한 좌석이 안쪽이라 옆 관람객에게 미안해 계속 앉아 있었다..그래도 그들만의 세상이 있겠거니 하면서...',
#   '1',
#   '126',
#   '27',
#   datetime.datetime(2017, 3, 26, 16, 44),
#   '관람객'],
#  ['말똥구리(yeji****)',
#   '궁금하지도 보고싶지도 않다불륜을 예술이라는 이름으로 미화시키지 않았으면..',
#   '1',
#   '127',
#   '28',
#   datetime.datetime(2017, 3, 23, 9, 44),
#   0],
#  ['행복소리(kmoa****)',
#   '홍상수감독이라서  매번 영화를 보고있는데 이번영화는 솔직히  별로 느낌이 안왔다 영화에 감동이   없으면  재미도 없다고  본다 ~담에는  생각해봐야겠다',
#   '6',
#   '145',
#   '46',
#   datetime.datetime(2017, 3, 25, 21, 49),
#   '관람객'],
#  ['0103****',
#   "대기업의 부도덕함에는 앞장서서 목소리를 높이고 불매운동을 하면서 '예술작품'에는 이중잣대를 대는 반쪽짜리 깨시민들은 부디 각성하시기를 바랍니다.",
#   '1',
#   '130',
#   '32',
#   datetime.datetime(2017, 3, 23, 20, 48),
#   0],
#  ['이영국(lyk3****)',
#   '그냥 관심없고 안본다  10자 10자',
#   '1',
#   '133',
#   '40',
#   datetime.datetime(2017, 3, 23, 9, 35),
#   0],
#  ['thsl****',
#   '1점주기도 아까운 더러운 영화 .. 남의 눈에 피눈물나게하고 사는 김민희나 최순실같은 인간들 꼭 벌받기를 .. 정말 그런 사람들이 성공하는거 싫다',
#   '1',
#   '109',
#   '18',
#   datetime.datetime(2017, 3, 23, 21, 57),
#   0],
#  ['wvip****',
#   '배고파서 그랬나본데, 아무리 아니라고 해도 짜깁기 일기장일 뿐',
#   '2',
#   '120',
#   '31',
#   datetime.datetime(2017, 3, 26, 15, 15),
#   '관람객'],
#  ['pin3****',
#   '이거 보는 인간들도 저것들과 같은 분류당  인간말종들...쯧 쓰레기  치워라  더럽고 역겹당어디 쓰레기 들고 나와서 예술이라 뻥치노',
#   '1',
#   '123',
#   '35',
#   datetime.datetime(2017, 3, 23, 11, 39),
#   0],
#  ['c983****',
#   '잃은 것이 아무 것도 없는데 고통은 무슨 고통? 돈,명예,권력까지 갖춘 홍감독을 탈취(?)하고  사랑이란 미명 아래 자행했던,그리고 하고 있는, 한 여자에(홍감독 부인)대한  인격말살과 여우주연상까지거머쥐었는데.모든...',
#   '1',
#   '108',
#   '23',
#   datetime.datetime(2017, 3, 24, 0, 3),
#   0],
#  ['검은양(nino****)',
#   '불꽃놀이는 순간 뜨겁지만 금방 식는다',
#   '1',
#   '104',
#   '20',
#   datetime.datetime(2017, 3, 23, 14, 37),
#   0],
#  ['권또(bbb5****)',
#   '안에서도 밖에서도 불편하다',
#   '6',
#   '110',
#   '27',
#   datetime.datetime(2017, 3, 26, 13, 26),
#   '관람객'],
#  ['한송이꽃(dlwj****)',
#   '0점은 왜 없는거니?...',
#   '1',
#   '86',
#   '11',
#   datetime.datetime(2017, 3, 23, 21, 29),
#   0],
#  ['쇽쇽(nyms****)',
#   '한집안 풍비박살? 분륜...? 합리화 되기 좀 힘드네요...마치 박근혜 전대통령  꼴 같이,,, 촛불시위하듯  대중들의 비난이그 둘에겐 들리지 않나 봅니다.  영화노노',
#   '1',
#   '90',
#   '22',
#   datetime.datetime(2017, 3, 23, 21, 10),
#   0],
#  ['ske0****',
#   '홍상수 허세영화에 놀아난 느낌이다  꼭 불륜이 아니더라도 걍 영화가 최악',
#   '1',
#   '84',
#   '17',
#   datetime.datetime(2017, 3, 29, 17, 16),
#   '관람객'],
#  ['dnfl****',
#   '아직 상처도 덜 아물었다,,,상업적으로 이용하지마라',
#   '1',
#   '86',
#   '20',
#   datetime.datetime(2017, 3, 23, 16, 59),
#   0],
#  ['jellypom(cand****)',
#   '아이고 아이고 아이고 ㅉ',
#   '1',
#   '95',
#   '30',
#   datetime.datetime(2017, 3, 23, 9, 16),
#   0],
#  ['이선화(yomg****)',
#   '이영화를왜보지..더러워..1점도아깝다..',
#   '1',
#   '76',
#   '12',
#   datetime.datetime(2017, 3, 23, 23, 56),
#   0],
#  ['kong****',
#   '다른말이 필요없는 최악 그자체',
#   '1',
#   '76',
#   '12',
#   datetime.datetime(2017, 3, 23, 20, 59),
#   0],
#  ['hsyo****',
#   '프랑스에선가 상을 받은 작품이라 작품성은있으려나했는데 왜 상을 받았는지 조차 모르겠네요 여배우의 스캔들이겹쳐보여 영횐에집중이잘안됐음',
#   '6',
#   '89',
#   '25',
#   datetime.datetime(2017, 3, 25, 19, 17),
#   '관람객'],
#  ['엄씨(rain****)',
#   '남의 상처가지고 뭣 하는 짓거리신지들 볼 가치가없다',
#   '1',
#   '79',
#   '16',
#   datetime.datetime(2017, 3, 23, 16, 52),
#   0],
#  ['마각(sink****)',
#   '에효 잠이나 잘껄 괜시리',
#   '1',
#   '79',
#   '17',
#   datetime.datetime(2017, 3, 23, 17, 29),
#   0],
#  ['유나유나(yuna****)',
#   '변명을 아름답게 포장한 영화',
#   '2',
#   '70',
#   '13',
#   datetime.datetime(2017, 3, 26, 23, 25),
#   '관람객'],
#  ['관우장비조운(subi****)',
#   '김민희 나와서 1점을 줌',
#   '1',
#   '110',
#   '54',
#   datetime.datetime(2017, 3, 23, 0, 35),
#   0],
#  ['입만열면_거짓말(rent****)',
#   '발연기로 인해 몰입불가',
#   '1',
#   '65',
#   '10',
#   datetime.datetime(2017, 3, 23, 23, 15),
#   0],
#  ['연구대상(sola****)',
#   '1점 주기도 아깝다. 정도가 아닌걸 용인하고 옹호하는 한국 영화계... 각잡고 반성 좀 하세요.',
#   '1',
#   '65',
#   '10',
#   datetime.datetime(2017, 3, 23, 23, 10),
#   0],
#  ['KHU(fada****)',
#   '내가 왜 이걸 돈 주고 봤을까....후회중 ㅠㅜ',
#   '1',
#   '64',
#   '10',
#   datetime.datetime(2017, 3, 23, 20, 42),
#   0],
#  ['이현정(sams****)',
#   '그냥...솔직히 왜 은곰상 받은지 모르겠어요',
#   '1',
#   '59',
#   '6',
#   datetime.datetime(2017, 3, 24, 16, 7),
#   0],
#  ['즐라탄(prob****)',
#   '최악의 산업폐기물이다',
#   '1',
#   '61',
#   '8',
#   datetime.datetime(2017, 3, 24, 17, 18),
#   0],
#  ['sslo2983(tnsm****)',
#   '1부는 영화 2부는 불륜미화',
#   '1',
#   '64',
#   '11',
#   datetime.datetime(2017, 3, 23, 12, 23),
#   0],
#  ['대비(rnqj****)',
#   'ㅋㅋㅋㅋ평론가들 돈먹었냐고 평점썼었는데 지웠네그래봤자 영화 안떠요ㅎㅎ이미 망한걸',
#   '1',
#   '67',
#   '14',
#   datetime.datetime(2017, 3, 23, 16, 7),
#   0],
#  ['jay(ichi****)',
#   '그래도 김민희라서 봤다.. 오늘 이후로 나의 영웅이었던 김민희가 죽었다. 이젠 더이상 김민희라는 배우를 볼 일 없을 것 같습니다.',
#   '1',
#   '77',
#   '24',
#   datetime.datetime(2017, 3, 23, 12, 1),
#   0],
#  ['jhh1****',
#   '연극하는 애들 지 잘난맛에 사는데 그걸 영화로 만들어서 돈받네',
#   '6',
#   '86',
#   '33',
#   datetime.datetime(2017, 3, 26, 13, 25),
#   '관람객'],
#  ['여름날의 미풍(ssss****)',
#   '예술이라는 단어를 욕먹이는 영화',
#   '1',
#   '57',
#   '6',
#   datetime.datetime(2017, 3, 24, 12, 47),
#   0],
#  ['cryc****',
#   '깜방에서 콩밥먹고있을 년 놈들이 지네얘기 지가 만들어서 지가 연기하고 다해먹는ㅋㅋ 캭~~~퉤!!',
#   '1',
#   '58',
#   '7',
#   datetime.datetime(2017, 3, 23, 22, 17),
#   0],
#  ['Astrick로세(swee****)',
#   '영화보진않았지만 평점낮추고싶음.  꼴보기싫어서',
#   '1',
#   '59',
#   '8',
#   datetime.datetime(2017, 3, 23, 23, 11),
#   0],
#  ['용아(jke8****)',
#   '하... 세상이 종말을 향해 가는건지..',
#   '1',
#   '61',
#   '10',
#   datetime.datetime(2017, 3, 23, 20, 40),
#   0],
#  ['bbal****',
#   '영희: 입 좀 조용히 하세요',
#   '8',
#   '69',
#   '19',
#   datetime.datetime(2017, 3, 27, 6, 58),
#   '관람객'],
#  ['한국도농상생총연합회(2015****)',
#   '알수없는 영화에 이해하기 힘든 수상.',
#   '4',
#   '55',
#   '7',
#   datetime.datetime(2017, 3, 24, 20, 3),
#   0],
#  ['배종현(bjh6****)',
#   '유투버를 해라 누가보겠나 ㅋㅋㅋ',
#   '1',
#   '62',
#   '14',
#   datetime.datetime(2017, 3, 23, 10, 25),
#   0],
#  ['애기똥풀(se2i****)',
#   '예술응 개똥이나예술~님들도 ㅎㅎ똑같은일 겪으시고 예술이구만~하세오~꼭 당하시길 바라옵니다',
#   '1',
#   '53',
#   '7',
#   datetime.datetime(2017, 3, 24, 9, 1),
#   0],
#  ['cmys****',
#   '최악이다 정말 이딴 영화 왜 개봉했나? 극장주들이 미쳤나보다  별 반개도 아까워 마이너스다',
#   '1',
#   '51',
#   '6',
#   datetime.datetime(2017, 3, 24, 11, 45),
#   0],
#  ['미니멀리스트(star****)',
#   '더러운것들 망해도 쌉니다. 불륜미화 누가 보나요? 다시는 한국 스크린 안방에 나올생각 마십시오. 둘이 외국가든지.. 김민희가 여배우 연기력 1위 라는 댓글에 빵터지고 갑니다ㅋㅋㅋ 베를린? 진짜 작품성 연기력으로 받았...',
#   '1',
#   '49',
#   '5',
#   datetime.datetime(2017, 3, 25, 11, 51),
#   0],
#  ['필라델피아(ninz****)',
#   '쓰레기 들이 쓰레기들 보라고 만든 영화, 사생활이라 하면 부모가 자식이랑 섹스하고 근친상간해도 사생활이냐? 참 역겨운 놈들이다. 별점도 0점 못줘서 1점준다. 불륜도 포장을 할상황이란것이  있지만. 결국 포장된 불륜...',
#   '1',
#   '49',
#   '6',
#   datetime.datetime(2017, 3, 25, 0, 0),
#   0],
#  ['박상진(wmwl****)',
#   '김민희님 정신 차리면 좋겠어요  제발',
#   '1',
#   '51',
#   '8',
#   datetime.datetime(2017, 3, 23, 22, 37),
#   0],
#  ['모카0307(saa0****)',
#   '홍상수ㅋㅋㅋㅋ 김민희씨 주변에서도 그렇고 니들을 욕하는게 일부라고? 정신차려라 이 발정난 노친네야 누가 니들을 인정해 니들앞에 대놓고 손가락질 하것니?니들 소식 친한척 다 듣고 뒤에서 까고 다닌단다 ㅋㅋㅋ 내 지인 ...',
#   '1',
#   '54',
#   '11',
#   datetime.datetime(2017, 3, 24, 23, 27),
#   0],
#  ['윤선민(esca****)',
#   '완전 삼류영화 자기 사생활을 풀어서 미화한듯 모든사람이 자기를 이런식으로 변명할줄 알게되면 쓰레기 세상되게겠네',
#   '1',
#   '48',
#   '6',
#   datetime.datetime(2017, 3, 24, 17, 56),
#   0],
#  ['영이(kmy5****)',
#   '진짜 정신을 해탈한거임?ㅋ',
#   '1',
#   '51',
#   '10',
#   datetime.datetime(2017, 3, 23, 16, 2),
#   0],
#  ['zzz(hj12****)',
#   '사생활 빼고 영화를 영화로 보자하고 갔음에도 너무 실망했습니다 홍상수 감독님 앞으로 영화접으세요...',
#   '3',
#   '43',
#   '3',
#   datetime.datetime(2017, 4, 7, 20, 25),
#   '관람객'],
#  ['엘리시움(0613****)',
#   '불륜남녀가 지둘이 불륜짓 한걸 영화로 만들어서 개봉하다니 ㅋㅋ 너무 웃기고 어이가 없다  이런걸 어떻게 개봉을 할수가있지.. 부끄러움을 모르는구나 ㅉㅉ',
#   '1',
#   '48',
#   '8',
#   datetime.datetime(2017, 3, 24, 4, 15),
#   0],
#  ['PROZECT30(kkk3****)',
#   '우리는 막장 드라마의 실사판을 보고 있습니다.',
#   '1',
#   '46',
#   '7',
#   datetime.datetime(2017, 3, 24, 11, 8),
#   0],
#  ['스마일(soon****)',
#   '불륜미화 영화...  영화를 자기 행위를 정당화하는 도구로 사용하는 것이 싫네요',
#   '1',
#   '49',
#   '10',
#   datetime.datetime(2017, 3, 24, 0, 37),
#   0],
#  ['짱꼴라OUT(tpdm****)',
#   '더러워 더러워 더러워 ㅇ',
#   '1',
#   '43',
#   '5',
#   datetime.datetime(2017, 3, 24, 22, 53),
#   0],
#  ['cjy8****',
#   '불륜커플을 관음하고 있는듯하다. 불편한 흥미로움.',
#   '3',
#   '48',
#   '10',
#   datetime.datetime(2017, 3, 28, 22, 41),
#   '관람객'],
#  ['shinbab(gjls****)',
#   '너무나  슬픈영화임이 분명하다~영화를 본사람이 이렇게나 많다니...난 차마 볼수가엄따 너무나 고통스러울 이들이 잇기에~안봐도 슬프네 ㅎㄹ',
#   '1',
#   '43',
#   '6',
#   datetime.datetime(2017, 3, 24, 17, 19),
#   0],
#  ['cred****',
#   '로멘스? 사랑?  웃기고있네,,, 이런걸 영화라고 ,,, 삼류쓰레기쥐',
#   '1',
#   '43',
#   '6',
#   datetime.datetime(2017, 3, 24, 8, 29),
#   0],
#  ['뷰티장금이(wjwk****)',
#   '대박..   태어나서 별 하나도 아깝운 영화는 처음봄  ㅜㅜ',
#   '1',
#   '43',
#   '6',
#   datetime.datetime(2017, 3, 24, 1, 55),
#   0],
#  ['haffye(ma_t****)',
#   '역겹다 역겹다 역겹다 역겹다',
#   '1',
#   '42',
#   '6',
#   datetime.datetime(2017, 3, 24, 20, 25),
#   0],
#  ['사랑둥이(miya****)',
#   '불륜이 예술로??역겹네요',
#   '1',
#   '43',
#   '7',
#   datetime.datetime(2017, 3, 24, 16, 36),
#   0],
#  ['매너가이(yoon****)',
#   '사랑해선 사랑해선 안 될 사람을~ 사랑하는안 될 사람을~ 사랑하는',
#   '1',
#   '44',
#   '8',
#   datetime.datetime(2017, 3, 23, 4, 50),
#   0],
#  ['333(jcho****)',
#   'ㅋㅋㅋ이거 왜봐 like for what',
#   '1',
#   '42',
#   '7',
#   datetime.datetime(2017, 3, 23, 15, 40),
#   0],
#  ['cncn****',
#   '이영화는 홍상수의 변명이라기보단 김민희에 대한 선물이자 편지다',
#   '8',
#   '61',
#   '26',
#   datetime.datetime(2017, 3, 26, 20, 52),
#   '관람객'],
#  ['호구와트마법학교(dpfl****)',
#   '1점도 아깝다.. 이딴것도 영화라고 퉤',
#   '1',
#   '36',
#   '3',
#   datetime.datetime(2017, 3, 24, 15, 9),
#   0],
#  ['쏭지(song****)',
#   '1점도아깝다 ,,ㅡㅡㅡ',
#   '1',
#   '36',
#   '3',
#   datetime.datetime(2017, 3, 24, 14, 49),
#   0],
#  ['Stechkin(wkuh****)',
#   '1점 주는거에 대해 긴말은 생략한다',
#   '1',
#   '38',
#   '5',
#   datetime.datetime(2017, 3, 24, 23, 7),
#   0],
#  ['ㅎㅎ 나는 나(ymj3****)',
#   '진짜 보고 싶지 않은 영화다~',
#   '1',
#   '38',
#   '5',
#   datetime.datetime(2017, 3, 24, 11, 48),
#   0],
#  ['mmm(0952****)',
#   '예술로 버무리려해도 드러나는 추잡함',
#   '1',
#   '39',
#   '6',
#   datetime.datetime(2017, 4, 4, 21, 21),
#   '관람객'],
#  ['강기화(busy****)',
#   '김민희 너무나 맹한대화법  부자연 어색 영화비아까울정도 실망이다',
#   '3',
#   '41',
#   '8',
#   datetime.datetime(2017, 3, 31, 0, 56),
#   '관람객'],
#  ['모그(moon****)',
#   '세상의 비난을 받고있는 연인에게 주는 선물..',
#   '10',
#   '50',
#   '17',
#   datetime.datetime(2017, 5, 20, 23, 33),
#   '관람객'],
#  ['Leo(saku****)',
#   '이젠 저들이 소름끼친다...',
#   '1',
#   '37',
#   '5',
#   datetime.datetime(2017, 3, 24, 12, 29),
#   0],
#  ['winner(jhyk****)',
#   '앞으로 홍상수감독 영화는 볼 일 없을 것 같네요',
#   '1',
#   '35',
#   '4',
#   datetime.datetime(2017, 4, 5, 9, 49),
#   '관람객'],
#  ['ㅋ(coup****)',
#   '응 그래 1점~~~~ㅎ',
#   '1',
#   '38',
#   '7',
#   datetime.datetime(2017, 3, 23, 18, 49),
#   0],
#  ['나그네정신(zack****)',
#   '김민희가 과연 베를린 영화제 여우상을 받을만 했는가 하는 의문점이 남는다.',
#   '6',
#   '40',
#   '9',
#   datetime.datetime(2017, 4, 20, 14, 40),
#   '관람객'],
#  ['귀여운척(qkek****)',
#   '감히 이런 소재로 예술을 논하고 인간의 고독을 거론하지마세요. 뭇매맞을걸 뻔히 알면서 당당히 작품을 내놓은것이 비난마저 예술로 믿으려는 연출 같아 기가막힘. 좋아했던 배우였는데.. 표현해야할것이있고 보편적 배려의 의...',
#   '1',
#   '36',
#   '6',
#   datetime.datetime(2017, 3, 25, 3, 40),
#   0],
#  ['rofk****',
#   '김민희 때문에 봤는데, 너무 역겹다.',
#   '4',
#   '43',
#   '13',
#   datetime.datetime(2017, 3, 28, 17, 32),
#   '관람객'],
#  ['이은(leee****)',
#   '기자 평론가 평 왜 저모양이지',
#   '5',
#   '31',
#   '2',
#   datetime.datetime(2017, 3, 24, 21, 20),
#   0],
#  ['EWBF(cine****)',
#   '모두가 보는데서 똥을 싸면 예술이 되는가?',
#   '1',
#   '33',
#   '4',
#   datetime.datetime(2017, 3, 25, 1, 52),
#   0],
#  ['stam****',
#   '이런 영화는 세상에나오면 않된다!!! 그렇지않아도 나라가 너무나 혼란스러운데 쓰레기 같은 영화가 나와 냄새를 풍기며 더 혼란스럽게 하는지....',
#   '1',
#   '33',
#   '4',
#   datetime.datetime(2017, 3, 24, 23, 24),
#   0],
#  ['hugh****',
#   '기자.평론가분들 열일하시네요.',
#   '1',
#   '33',
#   '4',
#   datetime.datetime(2017, 3, 24, 14, 18),
#   0],
#  ['woon****',
#   '1점주기도 아깝다..아휴. 뭐 자랑일까요. 남한테 상처주느 ㄴ행동이 뭐 자랑이라고',
#   '1',
#   '33',
#   '4',
#   datetime.datetime(2017, 3, 24, 10, 58),
#   0],
#  ['ahng****',
#   '자기 연민에 빠지면 예술가도 쓰레기통에 빠진다는 걸 여지없이 보여주는 결과물. 구구절절하게 떠들면 처절한 인생이 아니라 천박한 인생이 된다는걸 감독과 주인공은 모르는 듯. 뭔 예술가가 그런것도 모르는지 이전 작품들의...',
#   '1',
#   '34',
#   '5',
#   datetime.datetime(2017, 3, 25, 16, 24),
#   0],
#  ['구름(lemo****)',
#   '아직 보진않았는데 내가하면로맨스의 영화판일까싶음.. 자기미화..',
#   '1',
#   '34',
#   '5',
#   datetime.datetime(2017, 3, 24, 15, 53),
#   0],
#  ['joju****',
#   '절대안보고싶은영화....',
#   '1',
#   '34',
#   '5',
#   datetime.datetime(2017, 3, 24, 14, 22),
#   0],
#  ['포이즌(gksf****)',
#   '이거 보면서 돈보태주지마라 둘의 사랑을 응원해줄거아니면 욕하고 싶어보는거면 그럴바엔 안보고 망해라고 속으로 생각하는게 더 낫다. 뭐하러 봐??누구 좋으라고',
#   '1',
#   '35',
#   '6',
#   datetime.datetime(2017, 3, 24, 8, 51),
#   0],
#  ['투잇(khan****)',
#   '이런 정상밖의 이야기는 정상밖의 대접이 어울린다',
#   '1',
#   '37',
#   '8',
#   datetime.datetime(2017, 3, 23, 23, 28),
#   0],
#  ['Hydro(ohg8****)',
#   '불쾌했다.그지같다정말',
#   '1',
#   '33',
#   '5',
#   datetime.datetime(2017, 4, 1, 15, 39),
#   '관람객'],
#  ['나(tksy****)',
#   '만든의도를모르겟다 재미없다',
#   '1',
#   '40',
#   '12',
#   datetime.datetime(2017, 3, 29, 9, 25),
#   '관람객'],
#  ['해씨아니(gksd****)',
#   '홍상수는 아주 교활한 사람이라고 생각했다. 김민희를 정신적으로 자신에게 가두어 두려고 하는 스토리였다. 두 사람은 고통스럽고 행복하다고 자기위안 하는 스토리.',
#   '5',
#   '30',
#   '3',
#   datetime.datetime(2017, 4, 30, 19, 49),
#   '관람객'],
#  ['myle****',
#   '포장하고 합리화해야만 하는 정도까지 왔다면..',
#   '1',
#   '31',
#   '4',
#   datetime.datetime(2017, 3, 24, 9, 59),
#   0],
#  ['밝은미래(336t****)',
#   '대단한 예술가들 납셨네 예술이 범죄를 미화시키는도구인가요?불륜은 범죄입니다',
#   '1',
#   '34',
#   '7',
#   datetime.datetime(2017, 3, 24, 12, 21),
#   0],
#  ['무(amug****)',
#   '영화 평점을 쓰거라. 불륜평점쓰지말고. 니네 이러다 나중에 늙어서 태극기 든다~',
#   '10',
#   '41',
#   '14',
#   datetime.datetime(2017, 7, 15, 7, 56),
#   0],
#  ['tactic(tact****)',
#   '네티즌들 극혐이네 영화랑 사생활이랑 좀 나누자;;; 영화로 봐 제발 미친듯이 별점 테러나 하지말고',
#   '10',
#   '42',
#   '15',
#   datetime.datetime(2017, 7, 4, 16, 12),
#   0],
#  ['뉴욕수(coke****)',
#   '답지 않게, 감독은 남의 눈을 의식했다.',
#   '4',
#   '29',
#   '3',
#   datetime.datetime(2017, 3, 29, 18, 31),
#   '관람객'],
#  ['걸어서숲으로(epon****)',
#   '보면서 기분이 구려질수밖에 없었다..이젠 홍상수 영화를 못볼 것 같다.',
#   '6',
#   '30',
#   '4',
#   datetime.datetime(2017, 4, 5, 2, 53),
#   '관람객'],
#  ['Fdkgh(chlo****)',
#   '역겨워서 토할 것 같다. 뻔뻔하고 더러움',
#   '1',
#   '32',
#   '6',
#   datetime.datetime(2017, 3, 24, 14, 5),
#   0],
#  ['홍승완(the4****)',
#   '이 영화의 제목은 김민희',
#   '9',
#   '57',
#   '31',
#   datetime.datetime(2017, 3, 26, 17, 58),
#   '관람객'],
#  ['마도로스김(sohw****)',
#   '더럽다 영화도 감독도 배우도',
#   '1',
#   '31',
#   '6',
#   datetime.datetime(2017, 3, 24, 8, 58),
#   0],
#  ['김주아(jjua****)',
#   '어이가없는영화...돈주고 본게 너무 아깝다 불우이웃이나 도와줄걸',
#   '1',
#   '35',
#   '10',
#   datetime.datetime(2017, 3, 24, 18, 11),
#   0],
#  ['예니(sehe****)',
#   '별점10주는사람은 아마 영화에 절대적으로 공감하는 사람일것이다. 모두가  불륜을 욕할때 그들은 뭐 어떠냐는 식이다. 여러분  이런 더러움과 아름다운 예술을 착각하지마세요. 별점1도 아깝네요',
#   '1',
#   '35',
#   '10',
#   datetime.datetime(2017, 3, 24, 16, 0),
#   0],
#  ['Cj크류(rkfl****)',
#   '인생을 살아가는데 사자성어  세개만알면  아무런 문제가없다   역지사지 ,  사필귀정 ,  마지막은 ...   나대지마,   끝',
#   '1',
#   '27',
#   '3',
#   datetime.datetime(2017, 3, 25, 11, 19),
#   0],
#  ['몰라(mmmo****)',
#   '역대급  쓰레기    개쓰러기',
#   '1',
#   '29',
#   '5',
#   datetime.datetime(2017, 3, 25, 11, 21),
#   0],
#  ['하루(ghkw****)',
#   '영화를 통한  자기 합리화',
#   '1',
#   '29',
#   '5',
#   datetime.datetime(2017, 3, 25, 2, 2),
#   0],
#  ['즐라탄VS석현준(digi****)',
#   '평론가들 쓸때없이 이런곳에만 점수 쓰네',
#   '1',
#   '29',
#   '5',
#   datetime.datetime(2017, 3, 24, 23, 35),
#   0],
#  ['Ttt3885(tls5****)',
#   '지들 불륜 포장영화가 보고 싶냐ㅉㅉ걍 주변에 불륜커플봐라 걔들=얘들',
#   '1',
#   '27',
#   '4',
#   datetime.datetime(2017, 3, 25, 0, 37),
#   0],
#  ['더달콩(thed****)',
#   '간통을 로맨스인양...본인들의 행위를 미화하듯...대중앞에 포장하는 모양새..',
#   '1',
#   '28',
#   '5',
#   datetime.datetime(2017, 3, 24, 22, 32),
#   0],
#  ['랑이씽(dlad****)',
#   '할말없다...노답..',
#   '1',
#   '25',
#   '3',
#   datetime.datetime(2017, 3, 24, 14, 46),
#   0],
#  ['유(yuna****)',
#   '연기가 아닌 진심이여서 연기의 극찬을 받은건가?',
#   '1',
#   '28',
#   '6',
#   datetime.datetime(2017, 3, 24, 10, 45),
#   0],
#  ['open(wowa****)',
#   '고뇌의 산물인 예술이불륜을 미화시키는 도구라니.',
#   '1',
#   '28',
#   '6',
#   datetime.datetime(2017, 3, 24, 1, 25),
#   0],
#  ['UCS(uc85****)',
#   '킁킁.. 영화에서 똥냄새가 난다',
#   '1',
#   '28',
#   '6',
#   datetime.datetime(2017, 3, 23, 23, 13),
#   0],
#  ['0818(flow****)',
#   '웩역겹다.. 적당히하자',
#   '1',
#   '28',
#   '6',
#   datetime.datetime(2017, 3, 23, 23, 10),
#   0],
#  ['찡이(vvv_****)',
#   '둘이 영화를 또 찍었네, 역겹다',
#   '1',
#   '29',
#   '7',
#   datetime.datetime(2017, 3, 24, 17, 47),
#   0],
#  ['loup(sess****)',
#   '사람이 얼마나 잔인할 수 있는 지 보여주는...자신들이 만든 고통을  다른 이들 탓하지 마라.',
#   '1',
#   '25',
#   '4',
#   datetime.datetime(2017, 3, 25, 11, 57),
#   0],
#  ['완소듕이(hyan****)',
#   '살아생전 평점 달아보긴 첨이네! 정말 드럽다',
#   '1',
#   '27',
#   '6',
#   datetime.datetime(2017, 3, 24, 1, 40),
#   0],
#  ['durr****',
#   '불륜을 포장하지마라 역겹다',
#   '1',
#   '28',
#   '7',
#   datetime.datetime(2017, 3, 24, 12, 15),
#   0],
#  ['beka****',
#   '여기 욕하는 사람들도 아닌 척하는거죠. 사랑이 깨끗하기만 한가요',
#   '10',
#   '31',
#   '10',
#   datetime.datetime(2018, 3, 29, 3, 17),
#   0],
#  ['일렉트라(song****)',
#   "다른건 그닥 공감하지 못하겠고, 걍 술자리에서 스탭들이 무슨 생각을 하고 있을지. 그들의 심정만이 핵공감됐다. '이 꼰대 ㅅㄲ 또 시작됐네. 아...ㅅㅂ 좆됐다..'",
#   '3',
#   '23',
#   '3',
#   datetime.datetime(2017, 3, 25, 0, 3),
#   0],
#  ['샤오미(qorg****)',
#   '포스터만 봐도 ooo 남.',
#   '1',
#   '23',
#   '3',
#   datetime.datetime(2017, 3, 24, 15, 18),
#   0],
#  ['김보라(purp****)',
#   '가짜를 진짜인냥 포장하려하지만 역시.가짜.',
#   '1',
#   '21',
#   '2',
#   datetime.datetime(2017, 4, 21, 23, 34),
#   '관람객'],
#  ['hell****',
#   '여보세요! 최소한 자기자식을 낳은  여자에게 의리는 지키세요! 그런 기본적인 인간의 의리도 없는 남자가 무슨일을 하겟다고...쯧쯧',
#   '1',
#   '23',
#   '4',
#   datetime.datetime(2017, 3, 25, 15, 24),
#   0],
#  ['작전주에당한개미(sh0u****)',
#   '별 한개도 아까운 OOO기 불륜커플의 입장 정리',
#   '1',
#   '24',
#   '5',
#   datetime.datetime(2017, 3, 30, 15, 42),
#   '관람객'],
#  ['현소(akad****)',
#   '드러워요 기분이 이것도 영화라고 본 내가 한심하네요',
#   '1',
#   '25',
#   '6',
#   datetime.datetime(2017, 3, 26, 10, 26),
#   0],
#  ['성진(7437****)',
#   '12345435142424',
#   '1',
#   '21',
#   '3',
#   datetime.datetime(2017, 3, 24, 11, 31),
#   0],
#  ['굿샷(2005****)',
#   '홍상수 감독님 빠 인데 이번 영화는 꽝이네요~',
#   '3',
#   '22',
#   '4',
#   datetime.datetime(2017, 3, 24, 10, 22),
#   0],
#  ['isis****',
#   '왜 상을 받았을까?일부러 상받기 위해 심심하고 재미없게 여기저기 심오한척  설정해 놓은게 한심할뿐...70-80년대 같음 아~심오하구나 하겠지만 요즘은 진부함',
#   '5',
#   '23',
#   '5',
#   datetime.datetime(2017, 4, 22, 13, 45),
#   '관람객'],
#  ['포동이(mmin****)',
#   '둘이 연애든 불륜이든 뭐든 조용히 둘이하세요. 계속해서 이목 집중시키고 이런영화까지만들고 도대체 이유가 뭡니까 불편합니다 이기적인 인간들아',
#   '1',
#   '23',
#   '5',
#   datetime.datetime(2017, 3, 25, 4, 9),
#   0],
#  ['srug****',
#   '별한개두 아깝다 0 개 없낭',
#   '1',
#   '24',
#   '6',
#   datetime.datetime(2017, 3, 24, 4, 32),
#   0],
#  ['appl****',
#   '흠..영화의 목적이 무엇인가요',
#   '5',
#   '31',
#   '13',
#   datetime.datetime(2017, 3, 27, 14, 43),
#   '관람객'],
#  ['동구왕자(dhjg****)',
#   '김민희 안이쁜데 왜 다들 이쁘다고 함? 아부떠는거임? 평론가들 평점 왤케 높음? 아부떠는거임? 다른 괜찮은 영화에는 그렇게 별을 박하게 주더니만, 영화 갖지도 않은 것엔 왤케 후하게 주냐? 앞으로 평론가라고 하고 다...',
#   '1',
#   '18',
#   '1',
#   datetime.datetime(2017, 5, 2, 3, 47),
#   0],
#  ['유령함장(drea****)',
#   '홍상수감독도 그냥 주연으로 출연했으면 좋았을텐데 담 영화에서는 꼭 홍상수 김민희 두분이 같이 나왔으면 좋겠어요 물론 영화를 보지는 않았답니다; 홍감독님 영화는 너무 건조하고 카메라워킹이 어지러워서요 그리고 이번영화는...',
#   '1',
#   '21',
#   '5',
#   datetime.datetime(2017, 3, 25, 4, 23),
#   0],
#  ['굿맨(khb1****)',
#   '1점도 아깝다...이걸 영화라고 내걸은 홍상수새끼...넌 쓰레기다...잘했다고 상준놈들 도 똑같다...영화인이라는것들은 다 이러나?이상하게 꼬와놓곤...예술이라며 여우주연상이란다...ㅋ',
#   '1',
#   '21',
#   '5',
#   datetime.datetime(2017, 3, 25, 0, 5),
#   0],
#  ['무명씨(rand****)',
#   '이제 홍감독님 작품만 출연하는 전문배우가 되었습니다.  전화 한통 없네요.',
#   '1',
#   '21',
#   '5',
#   datetime.datetime(2017, 3, 23, 21, 52),
#   0],
#  ['ppippi(ppip****)',
#   '자기 얘기만 하는건 지루해요',
#   '1',
#   '22',
#   '6',
#   datetime.datetime(2017, 3, 26, 13, 30),
#   0],
#  ['안정순(jsaa****)',
#   '평론가들 돈얼마 받았냐',
#   '1',
#   '23',
#   '7',
#   datetime.datetime(2017, 3, 26, 14, 58),
#   0],
#  ['소희짱(he53****)',
#   '와 왜 삭제됏지 ㅋㅋㅋㅋ왜 삭제하셧어요 ㅋㅋㅋㅋ 진짜 평점부대들 작작좀하세요;; 빈말투성이네;',
#   '1',
#   '23',
#   '7',
#   datetime.datetime(2017, 3, 24, 10, 40),
#   0],
#  ['jove****',
#   '이 영화 관람객들은 불륜의 경험이 있는듯, 옛추억을 떠올리게 하나부다..난 타자 아프게 한 얘기 불륜인들 좋으려고 공개적으로 커밍아웃하고 그걸 반영한 예술이라고 치부하는건 너무 사치이자 극도의 이기주의라 생각한다. ...',
#   '1',
#   '24',
#   '8',
#   datetime.datetime(2017, 3, 25, 9, 36),
#   0],
#  ['모모네(momo****)',
#   '더러운 최악의 인간들 사회악이다 이런 인간들은',
#   '1',
#   '24',
#   '8',
#   datetime.datetime(2017, 3, 24, 22, 28),
#   0],
#  ['하루살이(ddig****)',
#   '심오하네여 그냥 그저그래요',
#   '1',
#   '31',
#   '15',
#   datetime.datetime(2017, 3, 26, 13, 28),
#   '관람객'],
#  ['조찡찡(whdb****)',
#   '마음이 아프다. 영희의 불안하고 마음둘곳 하나없는 애처로운 감정선이 너무나 잘 드러난다. 김민희의 노래, 인용한 시 구절 등등.. 마음 시리고 아프게 훌륭하다.',
#   '10',
#   '46',
#   '30',
#   datetime.datetime(2017, 3, 27, 12, 1),
#   0],
#  ['eart****',
#   '1점도 아깝다 10자 채우는것도 아까비',
#   '1',
#   '17',
#   '2',
#   datetime.datetime(2017, 3, 25, 15, 51),
#   0],
#  ['aewo****',
#   '0점0점0점0점0점',
#   '1',
#   '17',
#   '2',
#   datetime.datetime(2017, 3, 25, 13, 14),
#   0],
#  ['내버려둬(quee****)',
#   '너무지루해 불륜커플의 비겁한변명 하소연',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2017, 4, 23, 17, 17),
#   '관람객'],
#  ['jinj****',
#   '배우와 감독의 사생활이 영화몰입하는데 방해가 되었다.',
#   '2',
#   '18',
#   '3',
#   datetime.datetime(2017, 4, 5, 13, 37),
#   '관람객'],
#  ['피닉스(coco****)',
#   '0점이 없어서 1점 준다 OO맞은 감독 OO맞은 배우 OO같은 작품 그 이상 그이하도 아님 그런 더러운 짓거리는 니들 세상에서 하소서. 대중의 관심과 인정이 없으면 아무것도 아닌것들이 지들은 특별한 척 지들만의 리그...',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2017, 3, 25, 16, 12),
#   0],
#  ['saintrookie(dltn****)',
#   '영화자체로만 평가하자고? 가상의 불륜영화라면 이해라도하지 불륜 저지른것도 모자라 자기들 합리화시키고 미화 시키는 불륜영화까지 내놓을 필요가 있을까? 현실은 발정난 짐승같이 잠자리나 같이하는 사이를 아름다운 사랑으로 ...',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2017, 3, 25, 13, 3),
#   0],
#  ['양인자(jiyo****)',
#   '그냥할말도없다...',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2017, 3, 25, 11, 5),
#   0],
#  ['민지(minj****)',
#   'z wkdsksgksk alclssus hhh',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2017, 3, 25, 2, 6),
#   0],
#  ['쌤(miff****)',
#   '어휴...에휴...휴...',
#   '1',
#   '21',
#   '6',
#   datetime.datetime(2017, 3, 26, 0, 3),
#   0],
#  ['만두(3mj1****)',
#   '....하이구야 쩝쩝',
#   '1',
#   '21',
#   '6',
#   datetime.datetime(2017, 3, 24, 19, 13),
#   0],
#  ['나(chrg****)',
#   '조연들은 무슨 죄냐 상수야!!최고급 연기자들을 조연으로 쓰냐!!제정신이냐!',
#   '1',
#   '21',
#   '6',
#   datetime.datetime(2017, 3, 24, 0, 33),
#   0],
#  ['우주하늘(john****)',
#   '으휴 김민희 엄마라는 여자가 이랬답니다. - 곱게 키운 딸입니다. 함부로 말하지 마세요. - 완전 모전녀전 무조건 잘못했다고 무릎 꿇고 싹싹 빌어도 부족할 판국에... 구역질난다. 증말...',
#   '1',
#   '23',
#   '8',
#   datetime.datetime(2017, 3, 24, 10, 10),
#   0],
#  ['띵띵아(mast****)',
#   '영화계에서 얼굴을 안보면 좋겠다..',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2017, 3, 25, 15, 50),
#   0],
#  ['타이니(aman****)',
#   '뭐야.. 이 영화 보는사람도 있어? 역시 볼사람은 보는구나',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2017, 3, 25, 15, 37),
#   0],
#  ['0뿌잉뿌잉0(gamj****)',
#   '내 인생 최악의 영화절대 보지마세요',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2017, 3, 25, 14, 54),
#   0],
#  ['청률(hala****)',
#   '부도덕한 본인들 행실을 예술로 포장하는건 영화와 예술을 폄하하는일',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2017, 3, 25, 13, 33),
#   0],
#  ['삐코얼룩이(go57****)',
#   '줄거리가... 자기들만의 세계인듯',
#   '1',
#   '17',
#   '3',
#   datetime.datetime(2017, 3, 25, 16, 45),
#   0],
#  ['lightcollecteur(malm****)',
#   '짱난다 이걸 왜 돈주고 봤는지. 일기는 일기장에.스크립터쓰는애가 훨 이쁨영희야 넌 진짜 이뻐 넌 진짜 매력적이야 이걸 영화 내내 반복하는데 도대체 뭐가;;;주인공도 중2병 정신질환있는 여자같음. 실제로 불륜이든 아니...',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 4, 1, 16, 29),
#   0],
#  ['하와이(aik4****)',
#   '홍상수감독영화가 그동안 극사실주의여서 때론 민낯을 들키는 기준으로 때로는 훔쳐보는 기분으로 때로는 지식인들도 똑같구나 하는 마음으로 꼭 찾아봤던 1인으로 저 영화는 자기들 불륜을 포장한 영화가 아니다.돈이 아깝고 나...',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 3, 25, 14, 25),
#   0],
#  ['조돈근(peug****)',
#   '할말이없습니다...',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 3, 24, 8, 52),
#   0],
#  ['7SG2(club****)',
#   '대가리 빈 O과 늙어빠진 할뱡 OOO  또 뭘 찍엇다냐?에라이 캌아아앜 퉤!퉤!',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 3, 24, 7, 51),
#   0],
#  ['MilkyBlue(shel****)',
#   '유일하게 본 홍상수 영화에서 인간은 못되도 괴물은 되지 말자는 대사가 있던데...',
#   '1',
#   '19',
#   '5',
#   datetime.datetime(2017, 3, 26, 21, 36),
#   0],
#  ['맹고(93__****)',
#   '평식아 7점이나 되냐 이게?',
#   '1',
#   '19',
#   '5',
#   datetime.datetime(2017, 3, 24, 1, 54),
#   0],
#  ['여례(ygy0****)',
#   '기분나쁘다 이딴걸 보는 새끼들도 있다니 미래의 볼륜남(녀)아니면 현재 볼륜남(녀)겠네',
#   '1',
#   '24',
#   '10',
#   datetime.datetime(2017, 3, 24, 16, 55),
#   0],
#  ['love****',
#   '애매하다 참. 연기도 애매, 감독의 메세지도 애매. 영화보고나면 생각은 많아지지만 참 찝찝한 영화다. 예술의 정의가 뭘지..',
#   '4',
#   '16',
#   '3',
#   datetime.datetime(2017, 4, 8, 0, 16),
#   '관람객'],
#  ['외계인a(song****)',
#   '자의식 과잉으로 완성된 완전한 그사세.',
#   '3',
#   '13',
#   '1',
#   datetime.datetime(2017, 3, 30, 19, 39),
#   '관람객'],
#  ['dddo****',
#   '이 더러운 이야기 가상이 아닌 실화라서 싫네요. 절대안봅니다.',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2017, 3, 25, 16, 14),
#   0],
#  ['And(sham****)',
#   '점수 없엉~~    -10점 줄께',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2017, 3, 25, 12, 51),
#   0],
#  ['롤리(heav****)',
#   '개똥철학을 아름답게 포장하려 애썼으나 아직도 본인이 청춘인줄 아는 노망난 할아버지 늙어서 진심 감떨어진듯 니들이 말하는 사랑도 청춘일때 하는거지 노망난 할아버지의 예술허세 개똥철학 사랑은 추하다 주름낀 얼굴로 울면서...',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 4, 6, 2, 22),
#   0],
#  ['ashu(myas****)',
#   '알았어, 알았다고 둘이 사랑하라고. 대신 돈들여서 이런거 만들지 말라고.',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 3, 31, 18, 18),
#   0],
#  ['구자(eveh****)',
#   '평론가들 점수봐라 씨발 외국에서 상하나 탔으니 점수는 후하게 빨아주는것봐라 줏대없네 색히들ㅋ영화자체만 봐도 5점때가 될까말까야 임마들아 어휴 평론가들 허세 가오는 이미 정평이나왔느니 이영화 평점 7이상준놈들이평가하는...',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 3, 30, 14, 24),
#   0],
#  ['이유뮤직(spee****)',
#   '정신 차리세요 정신 좀 차려',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 3, 25, 19, 25),
#   0],
#  ['송윤지(gpfr****)',
#   '1점 주기도 아까운 영화였습니다 0점은 없나요',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 3, 25, 16, 55),
#   0],
#  ['uga3****',
#   '영화란 매개를 이용해 자기합리화하는 감독과 여배우의  진부한 변명에 개악을 금할 수 없었다 최악의 하질',
#   '1',
#   '17',
#   '5',
#   datetime.datetime(2017, 3, 25, 22, 22),
#   0],
#  ['타미(ksm8****)',
#   '정말 미친 것 같다. 이런 제정신이 아닌 영화를 9700명이나 보다니 참',
#   '1',
#   '17',
#   '5',
#   datetime.datetime(2017, 3, 25, 20, 28),
#   0],
#  ['레니토이(534k****)',
#   '다 1점드리는 분위기니까 저도 1점',
#   '1',
#   '17',
#   '5',
#   datetime.datetime(2017, 3, 25, 0, 10),
#   0],
#  ['김고은(goeu****)',
#   '불편하고 깨름직한 영화',
#   '1',
#   '17',
#   '5',
#   datetime.datetime(2017, 3, 24, 8, 31),
#   0],
#  ['ㅇ천비ㅇ(chun****)',
#   '아무리 이리포장하고 저리포장해도 불륜은 불륜. 뭐 잘났다고 영화로까지 너희 얘길 퍼트리냐?',
#   '1',
#   '18',
#   '6',
#   datetime.datetime(2017, 3, 26, 10, 40),
#   0],
#  ['라이언킴37(ryan****)',
#   '전국 누적관객수를 보라.ㅋㅋㅋ비정규직요원도 1만4천이나 넘었건만ㅋ',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 3, 26, 4, 40),
#   0],
#  ['fc00****',
#   '영화라기보다 자기들이 대중에게 하고싶은  얘기하는 다큐프로 보는거같았다.  재미도 없었음.돈아깝고 시간아까웠음.',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 3, 26, 2, 48),
#   0],
#  ['taeo****',
#   '실망.이네요 보지마세요',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 3, 26, 0, 37),
#   0],
#  ['겸댕(thtj****)',
#   '이딴 영화가 5점이나 된다니 말도안되',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 3, 26, 0, 26),
#   0],
#  ['카멜로(whxk****)',
#   '별점 1점 밑으로 주고싶은데... 연기 진짜 다들 별로에요 ㅋㅋㅋ 연영과 애들이 척하는 연기 너무 생각나서 개 별로임',
#   '1',
#   '11',
#   '0',
#   datetime.datetime(2017, 5, 2, 0, 4),
#   0],
#  ['옥시기(oxyb****)',
#   '시간만 낭비한다. 보지마라. 다큐도 아니고, 연애영화도 아니고, 감독이 뭘 이야기 하고 싶다는건지... 예술도 오락도 아닌 아무것도 아닌영화, 아니 영화도 아니다.',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2017, 6, 19, 12, 7),
#   0],
#  ['이시우(furi****)',
#   '채미도 없고 의미도 없고 비겁한 변명..기억나는대사 제정신이 아니다..',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2017, 5, 1, 16, 55),
#   0],
#  ['okin****',
#   '당신들의 인생이니 멋대로 사는건 뭐라 않겠지만 진실이 사라진 영화는 더 이상 만들지 마세요',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2017, 4, 20, 16, 57),
#   0],
#  ['베베베(best****)',
#   '홍상수 감독의 분풀이 영화',
#   '3',
#   '12',
#   '1',
#   datetime.datetime(2017, 4, 17, 7, 48),
#   0],
#  ['룰룰루(hlj7****)',
#   '전작들에 비해 재미가없었음.',
#   '2',
#   '12',
#   '1',
#   datetime.datetime(2017, 4, 10, 4, 59),
#   '관람객'],
#  ['아이비짱(kosu****)',
#   '보다보다 이런 별로인 영화는 처음 ...시간무지 아까웠고,  영화보로간 내가 한심했다.   지루하고...   아예 슬프리가로 하던지 ,   것도 아니고....  쯔',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 5, 27, 16, 49),
#   '관람객'],
#  ['별명이없다(slee****)',
#   '솔직히 감독의 개인적인 이야기를 떠나서 영화자체가 별로임.',
#   '2',
#   '13',
#   '2',
#   datetime.datetime(2017, 4, 17, 22, 31),
#   0],
#  ['씨종이는(a18o****)',
#   '뭔 말이 필요해? 김민희와 홍상순데 ㅋ 제 점수는여~',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 4, 5, 20, 26),
#   0],
#  ['yaja****',
#   '홍상수 영화는 역시 내용이 별로 없구나',
#   '5',
#   '13',
#   '2',
#   datetime.datetime(2017, 4, 1, 19, 30),
#   '관람객'],
#  ['진짜천사(4611****)',
#   '자격? 놀고 있네~ 그저 외설일뿐.. 청소년관람불가 판정은 잘한거다. 에잇 퉤!!',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 3, 25, 14, 57),
#   0],
#  ['선우(gs28****)',
#   '이영화관람은 시간낭비임',
#   '1',
#   '14',
#   '3',
#   datetime.datetime(2017, 4, 24, 18, 56),
#   '관람객'],
#  ['해리케인(paul****)',
#   '영화 스토리랑 각본 보니까 진짜 홍상수랑 김민희 너무하네ㅡㅡ',
#   '1',
#   '14',
#   '3',
#   datetime.datetime(2017, 4, 1, 19, 43),
#   0],
#  ['쿠쿠쿠(chld****)',
#   '모르겠다. .ㅡ...',
#   '1',
#   '14',
#   '3',
#   datetime.datetime(2017, 3, 25, 19, 53),
#   0],
#  ['jinsworld(codu****)',
#   '누구말대로 영화 자체만 놓고 봤을 땐 평균 정도의 점수를 주고 싶으나, 영화 중간중간 열이 오르는 대사들이 있더라고요. 이왕 욕 먹고도 지킨 사랑 오래오래 간직하며 살고, 남에게 지독한 아픔을 안겨주었다는 사실은 잊...',
#   '5',
#   '14',
#   '3',
#   datetime.datetime(2017, 3, 24, 2, 1),
#   0],
#  ['흰돌고래(won3****)',
#   '0점이없다니 얼자다ㅋ',
#   '1',
#   '15',
#   '4',
#   datetime.datetime(2017, 3, 26, 13, 15),
#   0],
#  ['swan(pann****)',
#   '무슨 재미로 보라고 지들 사랑을 여기다 풀었나 그게 제일 의심스러움',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2017, 3, 26, 15, 2),
#   0],
#  ['방가(mytw****)',
#   '보면안되고안되는영화',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2017, 3, 25, 20, 37),
#   0],
#  ['부엉이(gust****)',
#   '예술의 시작은 예술가이다.',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2017, 3, 24, 2, 39),
#   0],
#  ['량오니(didd****)',
#   '흠 뭐라고 해야되나..',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2017, 3, 23, 23, 46),
#   0],
#  ['smc(obam****)',
#   '60대여성분이영화관람후기자가소감물어봤는데 참재미잇고감명깊게봤단다 두사람사랑응원한단다..요즘60대노인들왜이래',
#   '1',
#   '17',
#   '6',
#   datetime.datetime(2017, 3, 25, 23, 15),
#   0],
#  ['여호와는 나의목자(art7****)',
#   '홍감독 영화는빼놓지않고 봅니다.중독성이 있는것같아요.사람이야 어떻든ㆍㆍ영화는 영화로만!',
#   '10',
#   '18',
#   '7',
#   datetime.datetime(2018, 1, 22, 22, 10),
#   '관람객'],
#  ['하이하바(hiha****)',
#   '평점조작알바처단이 급선무다',
#   '1',
#   '18',
#   '7',
#   datetime.datetime(2017, 3, 25, 10, 25),
#   0],
#  ['dlgu****',
#   '제 정신 아닌 년/놈들이 만든건 예술로 못친다?ㅋㅋ 그런 저열한 마인드가진 사람이 많다는게 나한텐 역겨운 세상이다. 예술과 본인감정을 구분짓지 못하는...',
#   '10',
#   '21',
#   '10',
#   datetime.datetime(2017, 10, 25, 1, 29),
#   0],
#  ['모지효(moji****)',
#   '모든걸 합리화 시키는 사랑타령남들 신경 안쓰는척하면서 귀에 단 말들만 받아들이려는 이중성ㅋ개관적 힘을 얻으려면 상대방 입장도 들여다봤어야지그러므로 졸작',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2017, 5, 1, 15, 36),
#   0],
#  ['olive(toey****)',
#   '응 그래 보기도 싫어^^',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2017, 4, 17, 15, 36),
#   0],
#  ['이샤블루엘(ange****)',
#   '정말 별로인 영화 이런게 예술이라니',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 4, 6, 13, 37),
#   0],
#  ['그손(dose****)',
#   '아 제발 0점좀 만들어주세요. 1점도 아깝단 말이에요',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 4, 5, 21, 41),
#   0],
#  ['달팽이엑기스(csw3****)',
#   '뭘 이해해달라는거냐!!',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 4, 1, 9, 52),
#   0],
#  ['tkdf****',
#   '완전 지들얘기고만 얼마나떳떳한 관계라고 영화로까지만들어 진짜 가증스럽다',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 3, 28, 19, 4),
#   0],
#  ['먼지(cat1****)',
#   '왜이런 추잡한 영화를 굳이 개봉하나;; 그렇게 개봉할 영화가 없나..',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 3, 26, 23, 23),
#   0],
#  ['네묘(xmar****)',
#   '별점 반개도 주기 아까움',
#   '1',
#   '13',
#   '3',
#   datetime.datetime(2017, 3, 28, 19, 57),
#   0],
#  ['verano(nora****)',
#   '내 스타일 아님  그다지 재미없음',
#   '1',
#   '13',
#   '3',
#   datetime.datetime(2017, 3, 27, 20, 12),
#   0],
#  ['BalanceX(crit****)',
#   '더럽고 역겹고 토쏠리고 구역질나고 토악질나오고 불결하고 추잡하고 구질구질하고 소름끼치고 닭살 돋고 머저리같고 지진아같은 것들이 자기들의 불륜을 이런식으로 얘기하네? 법(도덕)위에 예술이 있다고 생각하는것인가? 둘이 ...',
#   '1',
#   '14',
#   '4',
#   datetime.datetime(2017, 3, 29, 12, 11),
#   0],
#  ['Manfromist(neve****)',
#   '개인적인 잘못은 지탄받아야 하지만 영화 자체는 수작',
#   '10',
#   '15',
#   '5',
#   datetime.datetime(2018, 1, 30, 10, 25),
#   0],
#  ['Kermit2424(yuna****)',
#   '진짜라고 생각하나보네여 ㅉ',
#   '1',
#   '15',
#   '5',
#   datetime.datetime(2017, 3, 26, 18, 2),
#   0],
#  ['h(hell****)',
#   '이건 예술이 아니다. 안타깝다 모든게.',
#   '1',
#   '16',
#   '6',
#   datetime.datetime(2017, 3, 26, 19, 26),
#   0],
#  ['꿀잼이(bing****)',
#   '평점 1점이  잘만들었다는 증거인듯.. ㅋㅋㅋㅋ',
#   '10',
#   '18',
#   '8',
#   datetime.datetime(2017, 5, 16, 2, 21),
#   0],
#  ['작은숲(unoi****)',
#   '사랑이란 말을 더럽히지 마세요....',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2017, 5, 1, 16, 42),
#   0],
#  ['프프(atth****)',
#   '드럽네 불륜을 미화라니. 아들새끼 꼭 낳아서 그 마누라가 꼭 불륜햇으면 좋겟네. 그때 니 아들 마누라를 진심으로 축하해줘라 알겟냐',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2017, 4, 12, 12, 52),
#   0],
#  ['차라(ozni****)',
#   '흥행 한다고 언플하던데 헐 관객수',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2017, 4, 1, 20, 52),
#   0],
#  ['pont****',
#   '늙은 남성이 젊은 여성에게 영화로 아양 떠는 느낌을 알고 싶다면..',
#   '5',
#   '11',
#   '2',
#   datetime.datetime(2018, 3, 12, 10, 49),
#   0],
#  ['루피(kjke****)',
#   '그저 그짓에 미쳐서 아주 그냥 미친 영화로구먼.',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 5, 1, 18, 17),
#   0],
#  ['주연맘(ppka****)',
#   '헉 너무 재미없다 ㅠ 아무 느낌이 없다 ㅠ 어케 외국서 수상했는디 모르겠음',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 4, 5, 23, 18),
#   0],
#  ['Nosferatu(film****)',
#   '부잣집 아드님의 감독놀이에 놀아나는 개돼지들',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 4, 3, 19, 7),
#   0],
#  ['omg(pmg1****)',
#   '불륜(현실)을 사랑으로 포장하고 재단하여 정당화하려니 그의 촛점을 잃었구나~ 진정한 예술가는 타의 모범이 되는 삶을 살아야한다. 그래야 예술의 행위가 숭고해지고 무결점 작품들이 나오는것이며 대중들에게도 좋은 에너지...',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 3, 31, 16, 22),
#   0],
#  ['바닐라(pine****)',
#   '추잡한 영화를 가지고 예술이라 찬양해주다니. 신민의식 오졌다리 오졌다',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 3, 30, 10, 29),
#   0],
#  ['파란나라(naya****)',
#   '둘이 별나라에서 사시길..',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 3, 26, 23, 47),
#   0],
#  ['cherryblossom(kwak****)',
#   '인간의 외로움과 고독은 관계 속에서 파생된다는 것, 하지만 해답은 자신에게서 찾아진다는...영화의 마지막 장면애서 좀 쓸쓸한 여운이 남네요.',
#   '9',
#   '12',
#   '3',
#   datetime.datetime(2019, 10, 19, 19, 35),
#   '관람객'],
#  ['dndn(ttng****)',
#   '부끄러운 줄 알아라 머리에 똥만 차가지고 무슨 예술?',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 4, 7, 11, 39),
#   0],
#  ['김송희(1331****)',
#   '내 가정이 불륜으로 파탄이 났다면 그때도 옹호할 수 있을까. 예술을 더럽히지 마라.',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 4, 1, 0, 28),
#   0],
#  ['아침햇살(attr****)',
#   '저 졸린눈때문에 더 졸린영화',
#   '2',
#   '12',
#   '3',
#   datetime.datetime(2017, 3, 31, 8, 53),
#   0],
#  ['cckb****',
#   '참 한심하다   이 영화가 어떻게 예술이라고 볼수있지...',
#   '2',
#   '12',
#   '3',
#   datetime.datetime(2017, 3, 28, 17, 52),
#   0],
#  ['느낌(soph****)',
#   '역겹다 정말. 제발 대중앞에 나오지 말고 니들끼리 살던지 말던지',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 3, 27, 10, 30),
#   0],
#  ['루즌아(wlsl****)',
#   '생각보다 되게 추악하고 역겨웠습니다. 기대하고 봤던 제 자신에게 미안합니다.',
#   '4',
#   '13',
#   '4',
#   datetime.datetime(2017, 4, 11, 23, 15),
#   '관람객'],
#  ['clas****',
#   '일기는 일기장에나 써야지 왜 남한테 보여주나',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 31, 11, 12),
#   0],
#  ['르블옹(ghh7****)',
#   '이런걸 왜 보지....',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 29, 11, 4),
#   0],
#  ['뽀동이(san9****)',
#   '평점 쓰라는데 영화에 말은 없고 죄다 둘 이야기만 썼네요... 그만큼 보나마나한 내용...',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 29, 7, 8),
#   0],
#  ['pony sia(myvi****)',
#   '안보고싶다.뿌린대로거둘거라고믿는다.',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 28, 20, 22),
#   0],
#  ['싱클레어(wood****)',
#   '아무리 사실과 영화를 별개로 떼어놓고 보려해도 쉽지 않다. 온갖 변명과 동정호소가 지나쳤다. 마지막 권해효와 송선미의 변론은 낯간지럽기까지 하다.',
#   '4',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 27, 19, 19),
#   0],
#  ['rmsu****',
#   '1점도 아깝다어차피 언제나 그래왔지만',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 26, 20, 23),
#   0],
#  ['불면증vamfa(vamf****)',
#   '안보고 싶다 광고도 홍보도 포스터도 정볻도 기사도',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 26, 14, 12),
#   0],
#  ['얼빈(waka****)',
#   '일점도 아깝다. 망하는 걸론 모자르다.',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 25, 20, 4),
#   0],
#  ['황정희(siwa****)',
#   '예술은 그런게 아닙니다',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 25, 18, 51),
#   0],
#  ['supi****',
#   '워~~워  어차피 문재인 대통령 되면 홍상수 전문배우 골수  친노 문성근 권해효 등등이 있어 호위무사로  나섬 그래서 홍상수는 화이트리슽 1위에 오를 거 임  활 개를 칠 거 임. 문체부 장관 될라~우어~~',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 24, 16, 29),
#   0],
#  ['브라이언(huma****)',
#   '호기심에 들여다본 필름속 그들의 불장난에 농락당했다.마치 날것 씹다가 씁쓸해서 뱉어버린 듯...',
#   '3',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 24, 8, 20),
#   0],
#  ['appr****',
#   '년 놈들 제발 사라져라  뭐가 잘났다고 꼭 죄받고 후회 할거다',
#   '4',
#   '13',
#   '4',
#   datetime.datetime(2017, 3, 24, 7, 48),
#   0],
#  ['헝퀴(hong****)',
#   '6;20분꺼 예매했다가  늦을것같아서  취소전화를했는데  응대가 정말이지 너무 형편없었다. Ku시네마트랩 복짜가 들어갔던 남자알바생^^ 태어나서  처음으로 컨플레인걸어봐요. 꼭 교육다시받으시길',
#   '1',
#   '14',
#   '5',
#   datetime.datetime(2017, 4, 1, 20, 40),
#   '관람객'],
#  ['dlwn****',
#   '개, 돼지들이라면 재밌을것.',
#   '1',
#   '14',
#   '5',
#   datetime.datetime(2017, 3, 28, 22, 2),
#   0],
#  ['HUMANISTHUS(lyc2****)',
#   '그냥 안보면 되는데눈에 띄지마라.',
#   '1',
#   '14',
#   '5',
#   datetime.datetime(2017, 3, 28, 16, 2),
#   0],
#  ['믹키삼촌(zzan****)',
#   '최악의 영화  보지마시길',
#   '1',
#   '14',
#   '5',
#   datetime.datetime(2017, 3, 28, 15, 36),
#   0],
#  ['hyis****',
#   '영화로만 보자면 진짜.... 먹먹하고 저릿하다홍상수의 진가를 알수있는 작품',
#   '10',
#   '16',
#   '7',
#   datetime.datetime(2018, 2, 28, 3, 23),
#   0],
#  ['금이(sogo****)',
#   '영화를 볼수록 마음이 냉담해진다. 대사도 행동도 그다지 공감되지 않았던 영화',
#   '3',
#   '9',
#   '1',
#   datetime.datetime(2017, 4, 16, 7, 49),
#   '관람객'],
#  ['꼬야(syuj****)',
#   '영화를 영화로 보고 가리지 않는편인데 이 영화는 가리게된다. 안볼란다.',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 4, 3, 17, 6),
#   0],
#  ['dwoo****',
#   '잘만든 자리합리화 영화',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 4, 3, 15, 57),
#   0],
#  ['배성희(iris****)',
#   '걍둘이 보거나 불륜커플공감대 형성 ㅎㅎㅎ',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 4, 3, 9, 59),
#   0],
#  ['양th양(didt****)',
#   '예술이라고 치장한 더러운 영화',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 4, 1, 14, 28),
#   0],
#  ['상대(oks0****)',
#   '상수야! 내가 너 좋아하면안되냐? 어이가없어서 웃음만 나오네  머리가 어떻게 된것도 아니고 ㅋㅋㅋㅋ 대단해!  방송이나 기사에 좀 그만나오세요^',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 3, 30, 22, 15),
#   0],
#  ['방가방가(ayu1****)',
#   '왜 사람들이 다 1 점 줬는데 평균이 7.79인지  이해가 안되네여 .... 조작 이 심하네....',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 3, 30, 15, 9),
#   0],
#  ['dkdkdkdk(dk95****)',
#   'ㅎㅎ웃음만나지요 ㅎㅎ',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 4, 23, 1, 12),
#   0],
#  ['참(yout****)',
#   '영화는 너네만 보는게 아니라고 생각합니다',
#   '4',
#   '10',
#   '2',
#   datetime.datetime(2017, 4, 14, 22, 16),
#   '관람객'],
#  ['hyunji(tang****)',
#   '욕밖에 안나온다 진짜 무슨 생각으로 이딴 영화를 만들었지',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 4, 6, 18, 37),
#   0],
#  ['김지유(quee****)',
#   '반개도 아까운 영화...내가 이돈으로 밥한그릇 사먹을걸 생각한 영화',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 4, 6, 16, 40),
#   0],
#  ['gluc****',
#   '똥이다 똥 그냥 똥이다 똥',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 4, 2, 14, 57),
#   0],
#  ['이가영(rkdu****)',
#   '영화였다면가능하지만실제로 실화승화시킨영화',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 4, 1, 14, 27),
#   0],
#  ['suhe****',
#   '징그러움... 별루임 지루함',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 3, 30, 12, 11),
#   0],
#  ['piinkpet(saga****)',
#   '이거 리얼다큐라면서요?',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 3, 30, 11, 52),
#   0],
#  ['Pin(hipo****)',
#   '그냥그래요ㅣ그냥 그런;;',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 3, 29, 22, 50),
#   0],
#  ['Di Pascale Benoit(bdip****)',
#   '쓸모 없는 gossip 떠나서 그냥 재미없다. 감독님~ 생활의 발견 같은 영화 다시 만들어주세요!',
#   '4',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 16, 17, 37),
#   '관람객'],
#  ['엣헴(inbo****)',
#   '많이 역겹고 더럽네요.',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 6, 13, 21),
#   0],
#  ['StarBlossom(pink****)',
#   '예술을 수단으로 자신의 행위를 합리화 시키려는 것으로밖에 보이지 않는다사랑에 경계가 없다고 한들 넘어서는 안될 선이있다.그리고 너무 이기적인 사랑이다둘을 제외하고는 가장 가까운 사람들에게는 지울 수 없는 상처를 안겨...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 5, 17, 5),
#   0],
#  ['재유(dbsk****)',
#   '예술로 위장한 불륜1점도 아깝습니다.',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 5, 8, 41),
#   0],
#  ['hh(cleo****)',
#   '불륜은 범죄다. 어떤 이유에서도 합리화될수없다',
#   '2',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 5, 8, 18),
#   0],
#  ['비비드(vivi****)',
#   '영화에 거품이 잔뜩끼여 있는 느낌',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 2, 2, 43),
#   0],
#  ['jung****',
#   '일기는 일기장에....',
#   '2',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 2, 0, 39),
#   0],
#  ['루마니아(rhdb****)',
#   '논할 가치도 없는 열자열자',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 1, 16, 19),
#   0],
#  ['sjhl****',
#   '보는내내 심난했음 불륜을 저니 미화시킬까 ;;;',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 4, 1, 0, 7),
#   0],
#  ['옌이(yewo****)',
#   '윽극혐 불륜영화라니ㅠㅠ',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 31, 22, 57),
#   0],
#  ['이정민(clem****)',
#   '부끄러움을 아시길 바랍니다',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 31, 18, 6),
#   0],
#  ['강민성(jean****)',
#   '정신나간 감독의 넋두리에 돈만 낭비했네요. 이건 정말 애들 장난만도 못하네요.',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 28, 22, 34),
#   0],
#  ['D4(tbgh****)',
#   '응 꺼져 제발 부탁이니 꺼져',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 28, 21, 54),
#   0],
#  ['삥그르르(lkj5****)',
#   '응 해액노잼이야앙 정말',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 28, 20, 59),
#   0],
#  ['Ynee(dusa****)',
#   '이딴영화도 개봉을 하는구낰ㅋㅋ',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 27, 20, 37),
#   0],
#  ['백두산(back****)',
#   '평론가 새. 끼들. 돈. 처 받았냐. 병. 신 새끼들',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 27, 20, 15),
#   0],
#  ['sandra(xwyt****)',
#   '비린내  난다. 열자열자열자',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 3, 27, 20, 14),
#   0],
#  ['포로로롱(rain****)',
#   '최대한 외부적 요소를 배제하고 보려 했으니 보는 내내 정말 불편했음. 감독의 해명으로 밖에 보이지 않던 영화',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 4, 21, 15, 47),
#   '관람객'],
#  ['kuk3****',
#   '이것도 영화냐   av q비디오  수준',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 4, 5, 6, 33),
#   0],
#  ['sjan****',
#   '1점도 아깝다. 불륜녀와 불륜남의 자전적 이야기라메? 이제 홍상수감독 양화는 아웃. 김민희 영화도. 내 평생은 안본다.',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 4, 2, 0, 4),
#   0],
#  ['aval****',
#   '더럽다 더러운 년놈들 영화가 개봉에 걸려있거 예매순위에도 있다는게 황당하네...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 3, 31, 23, 14),
#   0],
#  ['보노보노(motp****)',
#   '불륜에 의한, 불륜을 위한, 영화 뭐 말이 필요한가.',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 3, 29, 16, 14),
#   0],
#  ['plcplc(ojhu****)',
#   '평론가들은 일반인들이랑 눈깔이 다름?',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 3, 28, 22, 8),
#   0],
#  ['rach****',
#   '1점도 주기싫은 영상. 영화라고 하기도 싫다.',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 3, 27, 11, 19),
#   0],
#  ['베놈(cidd****)',
#   '흥행 쩔더라 욕은 욕대로하면서 보러가는 인간들이 많은거보면 이나라는 진짜 정치나 연예계나 경제나 썩을대로 썩은듯..  국민들도 걍 호구새키들이라 걍 당해도 싸다 다 핵맞고 뒈져버렸으면 좋겠다.',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 3, 25, 19, 56),
#   0],
#  ['노마드(inwo****)',
#   '버러지 같은 것들하고 같이 영화찍고 싶나.. 여자는 누군지 모르겠고.. 정재영 권해효 문성근 나오는 영화는 이제 안봐야지.. 인생 똑바로 살아라 버러지들아 불륜이 뭐 자랑이라고 영화로까지 만들고 아주 소설을 쓰고 앉...',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 3, 27, 22, 49),
#   0],
#  ['okcu****',
#   '재미없다. 그리고 홍감독 영화는 패턴이 너무 뻔하다',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 3, 27, 13, 15),
#   0],
#  ['쓰밍(dbry****)',
#   '아니 차라리 미녀와야수를보겠다새로운영화도많은데 왜굳이 이런더러운영화를볼까ㅡㅡ',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 3, 25, 20, 8),
#   0],
#  ['Alex(lemo****)',
#   '불륜은 어떤것으로든 정당화 될 수 없다',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2017, 4, 18, 18, 46),
#   '관람객'],
#  ['rush****',
#   '대단하다 이걸 보는 인간들이 있네ㅉㅉㅉ 불륜마니아들이 대부분 이겠어ㅋ 제정신 가진 인간이라면 역겨워서라도 안볼텐데ㅋ',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2017, 3, 28, 14, 30),
#   0],
#  ['도니(loll****)',
#   '반개도아깝다...예술로 표현한 자체도 역겹다',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2017, 3, 28, 14, 16),
#   0],
#  ['s121****',
#   '유명인의 유출된 포르노 보는 마음으로 보게된다. 치졸하고 비겁해서 신기한 포르노.',
#   '2',
#   '14',
#   '6',
#   datetime.datetime(2017, 3, 26, 18, 53),
#   0],
#  ['lovs****',
#   '별 반개도 주기 아깝다 예술적 사랑이라 포장해 토 쏠린다',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2017, 3, 26, 17, 39),
#   0],
#  ['안녕하세요(hye0****)',
#   '아...술 담배생각만....',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2017, 3, 27, 19, 30),
#   '관람객'],
#  ['다미(wdam****)',
#   '자기변명 자기연민 지긋지긋',
#   '7',
#   '18',
#   '10',
#   datetime.datetime(2017, 3, 27, 21, 19),
#   '관람객'],
#  ['jeon****',
#   '좀처럼 혹평은 하지않는 자신입니다.하비만 기만당한것 같아 도저히 팜을수가 없네요! 결혼한 주부로서 공감할 부분도 있을것 같아 혹시나 ~  쿨쿨 자고 일어난 신랑한테 욕바가지~저자신도 대학동아리 수준에도 못미치는~시간...',
#   '1',
#   '29',
#   '21',
#   datetime.datetime(2017, 3, 27, 13, 10),
#   '관람객'],
#  ['LH(pdle****)',
#   '내가 원하는 건 그냥 나답게 사는 거야. 흔들리지 않고, 무슨 일이 일어나도 나답게 살기로 했어. 김민희의 대사.',
#   '8',
#   '39',
#   '31',
#   datetime.datetime(2017, 3, 26, 17, 57),
#   '관람객'],
#  ['효(mcir****)',
#   '글쎄 나는 잘모르겠네~',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2017, 5, 1, 21, 49),
#   0],
#  ['kangzzang(yray****)',
#   '먼놈의 영화가 싸이코 집합소같냐 ㅋㅋㅋ',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2018, 6, 19, 0, 16),
#   0],
#  ['예지(yeji****)',
#   '대체 뭘 말하려는 건지, 내가 정신세계를 이해하지 못하는건가?도통 뭔 말인지 모르겠다. 그리고 듣기도 아주 많이 불편하다',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2018, 3, 22, 17, 53),
#   0],
#  ['myri****',
#   '김민희에 대한 홍상수의, 홍상수식 김민희 이야기',
#   '7',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 10, 18, 22),
#   '관람객'],
#  ['seun****',
#   '김민희는 왜 상을 받았지..? 연기를 잘한게 아닌 그냥 자신의 현실을 찍은거임. 홍상수 감독은 너무 자신의 상황에 심취해 있음. 자신이 찍으면 예술이고 남이 찍으면 아류인가? 꼭 내가 하면 로맨스고 남이하면 불륜이듯...',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 5, 4, 18, 17),
#   0],
#  ['pink****',
#   '이런영화 만들지말고 보지도 마세요.',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 5, 1, 23, 14),
#   0],
#  ['텔레타비(jyj0****)',
#   '엿 쳐드세요~~~~ ㅋ',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 30, 17, 22),
#   0],
#  ['김슬기(seul****)',
#   '응~~~안봐야지~~~',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 22, 22, 19),
#   0],
#  ['소율(ohia****)',
#   '할말이 없을 정도로 별로다..별로 정말..',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 16, 19, 35),
#   0],
#  ['모리스(budd****)',
#   '홍상수에대해서 적나라하게 댓글달아서 공감1위하고있었는데 홍상수가 신고해서 삭제됨 ㅋㅋㅋ 홍상수 참으로 치졸하고 찌질한 늙은이다.',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 13, 20, 16),
#   0],
#  ['IDEALE(yile****)',
#   '자신들의 비도덕성을 예술로 위장하는  가짜 예술가들의 자화자찬, 이런 부류들은 대답이 한결같다  " 영화는 영화로 봐주세요"  예술을 말하기 이전에 부끄러움을 말할수 인간들이 되기를 바란다',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 12, 15, 2),
#   0],
#  ['눈물이뚝뚝(zos4****)',
#   '0개는없나 에휴 1개도아까움',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 11, 15, 35),
#   0],
#  ['ldks****',
#   '에휴 이상하다 이상해 너무 보기 힘들었던',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 4, 9, 20, 12),
#   0],
#  ['소야(rumi****)',
#   '결국엔 자기 변명인거지 뭐',
#   '1',
#   '8',
#   '1',
# ...
#   '1',
#   '1',
#   '1',
#   datetime.datetime(2017, 8, 6, 17, 3),
#   0],
#  ['그리마(shim****)',
#   '무 엇 이 무 엇 이 X같 을 까. 바 람 난 년 놈 이 X같 지 요.',
#   '1',
#   '1',
#   '1',
#   datetime.datetime(2017, 5, 13, 17, 14),
#   0],
#  ['hcsk****',
#   '다른 홍상수 영화와 달리 잘 느끼지를 못하겠다....',
#   '2',
#   '1',
#   '1',
#   datetime.datetime(2017, 5, 13, 16, 4),
#   0],
#  ['사랑이(oliv****)',
#   '아/~~~오글거려 죽을거같아요ㅡㅡ다들 국어책읽는거같고.어느정도 예상은햇지만너무어느면에서도 왜난와닿지가않을가ㅠㅠ',
#   '1',
#   '1',
#   '1',
#   datetime.datetime(2017, 5, 13, 14, 40),
#   0],
#  ['meene(mine****)',
#   '기대를 너무 많이 했나. . . .',
#   '5',
#   '1',
#   '1',
#   datetime.datetime(2017, 5, 11, 21, 30),
#   '관람객'],
#  ['ksh7****',
#   '홍상수의 연출의 깊이는 더욱 깊어졌고, 배우들의 연기에서 묻어나오는 자연스러움의 감흥은 더욱 유쾌해졌다. 시간과 사랑의 물결에 잠시 몸을 맡기는 듯한 기분을 느낀다.',
#   '7',
#   '2',
#   '2',
#   datetime.datetime(2019, 10, 15, 23, 1),
#   0],
#  ['더쿠(bbis****)',
#   '정신이 건강한 사람들이 영화를 만들었으면해요..ㅋㅋ',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2019, 6, 19, 0, 30),
#   0],
#  ['붉은공룡(pigl****)',
#   '인간은 책임을 져야하는 동물이랍니다',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2019, 6, 15, 7, 2),
#   0],
#  ['살콩이네(0915****)',
#   '홍이 이용하는듯ㅋ 어떻게 이걸 영화로만드냐',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2018, 6, 7, 13, 52),
#   0],
#  ['Jelly(love****)',
#   '문성근 연기 개잘하네 ㅋㅋ',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2018, 4, 15, 22, 51),
#   0],
#  ['torn****',
#   '본능으로 움직인것을 이성으로 가리려고..',
#   '6',
#   '2',
#   '2',
#   datetime.datetime(2017, 10, 23, 1, 35),
#   0],
#  ['아름다운지나(jina****)',
#   '영화는 역시 젊은사람들이 만들어야 한다.',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2017, 10, 5, 14, 48),
#   0],
#  ['티티새(timh****)',
#   '1점 주면 개인사 때문이라 오해할 수 있어 2점을 준다. "유부남 남자 온다" - 이 말 한마디 하는데 20분에 걸쳐, 했던말 또하고 또하고... 치매 노인이 만든 영화같다. 홈캠으로 찍은듯한 영상, ...',
#   '2',
#   '2',
#   '2',
#   datetime.datetime(2017, 10, 5, 2, 2),
#   0],
#  ['박선호(pshx****)',
#   '평점테러에 참여하지 않으면 안될것같아서 참여함. 말로  담기엔 내 입이 더러워짐',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2017, 10, 3, 15, 14),
#   0],
#  ['블랙스플린터(outs****)',
#   '언제부터 영화를 좋아하면 천박한 짓까기 사랑으로 이해하고 감싸줬냐?  평론가들 면상보면 연애 한번 못해보게 생겨서 그런지 사랑이 뭔지 모르는듯. 어떤 사랑이 동물처럼 하는 사랑을 아름답다고 이해하는지?',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2017, 9, 29, 2, 23),
#   0],
#  ['소소하게(love****)',
#   '빠져드네요..첨엔 영화의 모든게 다 어색햇는데 끝난후엔 나도 등장인물들과 함께 그공간에 같이 있엇던 기분.  주위에 흔한 옷, 표정, 말투, 생각, 행동...영화같지않은 영화. 유니크하네요~물론 감독 의도나 주제 그...',
#   '8',
#   '2',
#   '2',
#   datetime.datetime(2017, 8, 30, 23, 59),
#   0],
#  ['alex****',
#   '어우 ㅉㅉ니들이 하는게 예술이냐? 쓰레기지',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2017, 8, 20, 17, 17),
#   0],
#  ['창천(heod****)',
#   '연기도 좋고, 영희도 좋다. ND',
#   '9',
#   '2',
#   '2',
#   datetime.datetime(2017, 8, 3, 3, 52),
#   0],
#  ['타짱(kiwi****)',
#   '정상수형님 누드 볼려구 다운받았는데 안 나오네요...',
#   '6',
#   '2',
#   '2',
#   datetime.datetime(2017, 7, 25, 23, 47),
#   0],
#  ['뫼르소(seul****)',
#   '홍상수와 김민희의 독백, 그리고 사랑과 야만의 경계',
#   '7',
#   '2',
#   '2',
#   datetime.datetime(2017, 7, 18, 22, 4),
#   0],
#  ['바람의언덕(sipj****)',
#   '드라마를 가장한 다큐멘터리. 예술을 가장한 자기변명.',
#   '7',
#   '2',
#   '2',
#   datetime.datetime(2017, 7, 16, 15, 27),
#   0],
#  ['Gkk(gk94****)',
#   '솔직한 감정표현이 영화를 이끈다',
#   '4',
#   '2',
#   '2',
#   datetime.datetime(2017, 5, 15, 20, 26),
#   '관람객'],
#  ['상어가죽(kara****)',
#   '그러지 않아도 되는데 부자연스러운 대사들이 많이 나옴...점점 영화화 각본의 갭이 커지고있는 홍상...',
#   '5',
#   '2',
#   '2',
#   datetime.datetime(2017, 5, 15, 10, 42),
#   0],
#  ['blue****',
#   'OO들만 글 올려서 한마디하네영화도 안보고 욕하는 넘들. 지가 누군지도 모르면서 욕하는 놈들. 불륜으로 상처받는 소수를 위하는 척 OO하는 놈들. 모두 진짜 어려운일 발생할때 숨는 새끼들인거 알고 있슴 글 그만쓰고 ...',
#   '9',
#   '2',
#   '2',
#   datetime.datetime(2017, 5, 14, 8, 22),
#   0],
#  ['프로스트(fros****)',
#   '자기 복제는 끝이 없어라.',
#   '1',
#   '2',
#   '2',
#   datetime.datetime(2017, 5, 13, 1, 46),
#   0],
#  ['별명(j920****)',
#   '영화에만 집중하고 싶었다',
#   '5',
#   '2',
#   '2',
#   datetime.datetime(2017, 4, 10, 16, 8),
#   '관람객'],
#  ['ses2****',
#   '그럭저럭....,.',
#   '4',
#   '2',
#   '2',
#   datetime.datetime(2017, 4, 6, 19, 12),
#   '관람객'],
#  ['모귀(mono****)',
#   '일어나세요. 여기서 이러고 있음 정말 큰일나요.',
#   '5',
#   '2',
#   '2',
#   datetime.datetime(2017, 4, 6, 14, 10),
#   0],
#  ['Timon(bruc****)',
#   '김민희는 아름답다... 홍상수는 복도 많지...',
#   '8',
#   '3',
#   '3',
#   datetime.datetime(2020, 6, 9, 15, 23),
#   0],
#  ['감자깡(thta****)',
#   '사랑 앞에서 도덕을 운운하는 더러운 사람들은 이해를 못하겠지 사랑은 해봤니?',
#   '10',
#   '3',
#   '3',
#   datetime.datetime(2019, 12, 11, 21, 59),
#   0],
#  ['mue(fres****)',
#   '비난하고 비판하는 관객들 네티즌들 보다 영화업계 이중적인 사람들의 이야기 같네요. 모두 올바른 사람들은 아니지만 똑바로 살려고 하는 사람들이 만드는 영화를 보고 싶네요.책임지지도 못하는 일들 벌이면서 예술이라고 이야...',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2019, 10, 7, 17, 59),
#   0],
#  ['이지은(jieu****)',
#   '나는 김민희 홍상수 사랑에 딴지를 걸고 싶지는 않다. 하지만 이 영화를 보고 손발이 오글아 든다. 담백하지 못하고 굉장히 느끼하다. 죽일놈의 오글오글 사랑타령 철학적인 척 아는 척 사춘기 중2에게 세상 누구보다 심각...',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2019, 9, 11, 7, 22),
#   0],
#  ['OShw(mama****)',
#   '이 영화 진짜 졸작:) 불륜에 대한 자기 변명에 젊은 여자에게 사랑받는다는 유치한 오만과 치기로 가득찼다. 한심 ㅉㅉㅉ',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2019, 6, 15, 17, 21),
#   0],
#  ['lini****',
#   '불륜을 포장하지 마세요',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2019, 6, 15, 15, 9),
#   0],
#  ['dahg****',
#   '아름답게 포장하려해봤자 불륜인걸요.',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2019, 6, 15, 9, 12),
#   0],
#  ['komse(q9we****)',
#   '오만과 편견:여자의 세계의 모든 개인, 연인, 가정에게 강자의 위치사랑에 있어서까지 강자의 위치를 가졌던 여자가 사랑하지 못한 이유잘 해오셨습니다:남자에게 오직 필요했던 단 한마디',
#   '10',
#   '3',
#   '3',
#   datetime.datetime(2018, 8, 30, 9, 23),
#   0],
#  ['qpaa****',
#   '홍상수 팬으로서 최고의 망작, OOO작',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2018, 8, 24, 0, 20),
#   0],
#  ['유나짱(marc****)',
#   '사랑일까?자기가 하고싶은 데로 하는것일까?',
#   '7',
#   '3',
#   '3',
#   datetime.datetime(2018, 6, 6, 0, 16),
#   0],
#  ['친절한윤재씨(kind****)',
#   '나도 결국 인간이라는 홍상수의 고백, 역겹다기 보다는 측은하고 웃겨',
#   '8',
#   '3',
#   '3',
#   datetime.datetime(2018, 1, 9, 11, 50),
#   0],
#  ['울티마(danz****)',
#   '그래서 뭐 예쁜 사랑 중이니 이쁘게 봐달라고??',
#   '5',
#   '3',
#   '3',
#   datetime.datetime(2017, 12, 3, 19, 54),
#   0],
#  ['1387546(medi****)',
#   '일기는 일기장에. . . .',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 10, 29, 16, 43),
#   0],
#  ['대박천재(dlru****)',
#   '밤의 해변에서 혼자 쳐맞아봐야지 정신차리지.',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 10, 28, 17, 4),
#   0],
#  ['aakso(joug****)',
#   '이거 1점도 너무 아까운데...;;',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 10, 12, 8, 44),
#   0],
#  ['Coldplay(wl__****)',
#   '영화 좋았는데 왜자꾸 사적인 이야기를 끌어들여서 영화평점을 메길라고 하지... 한국인 종특인가.. 그러면서 이병헌 영화는 아주  잘 주는 이중성 ㅋㅋㅋㅋ 보지도 않고 평점메기네 나는 좋았는데 ㅎㅎ',
#   '9',
#   '3',
#   '3',
#   datetime.datetime(2017, 7, 31, 21, 30),
#   0],
#  ['John Mercury(cnrr****)',
#   '<필연적으로 존재하는 사랑>에 대한 외침.',
#   '7',
#   '3',
#   '3',
#   datetime.datetime(2017, 7, 17, 2, 31),
#   0],
#  ['mandy(dand****)',
#   '성실하고 정직한 사람들이  쓰레기같은 사람들에 의해서 상처받고 조롱받는다. 이 영화를 통해 그런 역겨움이 더 절실해졌다. 사랑? 누군가를 배신하면서 하는게 사랑이라면 사랑하지 않으리라',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 7, 16, 3, 20),
#   0],
#  ['이클로이(slig****)',
#   '남의 마음 짓밚고,배신하는게 사랑인가? 단막극보다 훨씬 못한 영화',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 7, 16, 0, 28),
#   0],
#  ['jum2****',
#   '감독님.. 영화 만들시간에 아내분과 어떻게 해야할지 해결을 하세요..;; 대한민국 참 부끄럽다',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 7, 13, 1, 30),
#   0],
#  ['행복한날(lhyl****)',
#   '삶에 행운을 빌어요 그래서 7.그만큼 사랑해서 가족들에게 상처주는거라면 그책임도 모두 당신꺼에요 당신은 당신선택에 책임을 질수있는 그리고 그럴 의무가있는 성인이니까요. 세상은 사랑을 바탕으로 곱셈 나눗셈 함수까지 가...',
#   '7',
#   '3',
#   '3',
#   datetime.datetime(2017, 5, 20, 4, 22),
#   0],
#  ['뿡탁(kzt2****)',
#   '더럽다 너무 더럽다 겁나 더럽다',
#   '1',
#   '3',
#   '3',
#   datetime.datetime(2017, 5, 15, 22, 13),
#   0],
#  ['정재호(wjdw****)',
#   '재밌었네요 행각했던것보다',
#   '7',
#   '3',
#   '3',
#   datetime.datetime(2017, 5, 14, 16, 37),
#   '관람객'],
#  ['러브넬슨(love****)',
#   '죄없는자 돌로 쳐라! 김민희의 연기가 매력적이았던... 되고싶다 자유인! 영화속 그녀처럼,, 사랑을 갈구하고, 상처받은 그 속에서 순수한 것을 찾으려는 인간의 고뇌와 몸부림! 어느 순간 그녀의 모습이 사랑스럽게 보인...',
#   '8',
#   '3',
#   '3',
#   datetime.datetime(2017, 5, 14, 16, 27),
#   0],
#  ['흠(mell****)',
#   '하고싶은 말 다 했구나 싶음',
#   '6',
#   '3',
#   '3',
#   datetime.datetime(2017, 4, 1, 22, 8),
#   '관람객'],
#  ['김영호(rica****)',
#   '지들은 뭐 도덕적으로 아주 깨끗한척 홍감독 욕하는 꼬라지들 보면 한숨만 나온다 개돼지들 ㅉㅉ',
#   '8',
#   '4',
#   '4',
#   datetime.datetime(2019, 6, 29, 7, 43),
#   0],
#  ['에몽이(ryok****)',
#   '멋있고 또 보고 싶은영화입니다~^^최고입니다',
#   '10',
#   '4',
#   '4',
#   datetime.datetime(2019, 1, 27, 2, 8),
#   0],
#  ['라즈알굴(dlwo****)',
#   '항상 평론가를 위한 영화만 만듬...',
#   '1',
#   '4',
#   '4',
#   datetime.datetime(2018, 8, 25, 12, 42),
#   0],
#  ['디셈버(hang****)',
#   '감독, 배우의 인격이 아닌 영화 자체의 작품성만 본다면...',
#   '10',
#   '4',
#   '4',
#   datetime.datetime(2018, 8, 7, 11, 3),
#   0],
#  ['화이트로즈(mkjh****)',
#   '별한개 준것들은 영화볼줄 모르는 OOO기들이다',
#   '10',
#   '4',
#   '4',
#   datetime.datetime(2017, 9, 22, 19, 8),
#   0],
#  ['소징이(yyyy****)',
#   '핵노잼의 극치였습니다',
#   '1',
#   '4',
#   '4',
#   datetime.datetime(2017, 7, 27, 5, 53),
#   0],
#  ['낸둥(rkdt****)',
#   '나는 영화보는 눈이 없나보다.. 카메라 구도도 지루하고 느릿느릿. 영화가 아니라 약간 페이크 다큐느낌? 뭔가 예술적이고 독창적인 영화를 만들고싶었나본데.. 나는 그게 좀 거북하게 느껴졌어요. 심심하면 담배 뻑뻑 피고...',
#   '1',
#   '4',
#   '4',
#   datetime.datetime(2017, 7, 23, 3, 38),
#   0],
#  ['민소라(uniw****)',
#   '댓글알바 1~2명이 명의도용하면서 여러계정으로 언플해대는구나(높은점수준건 죄다 관람객,오히려 더 수상해 ㅋㅋ)댓글알바야~시간당 얼마받고 일하냐?///쉴드 치시는분들 집에 계신 아내(또는 남편)에게 말하세요.나도 새...',
#   '1',
#   '4',
#   '4',
#   datetime.datetime(2017, 7, 20, 18, 18),
#   0],
#  ['lovbabo(wjgi****)',
#   "차라리 '사랑과 전쟁' 드라마를 보는게 더 나을듯 ....예술이라는  이름으로  시간과 돈과 필름 이 모든것을 낭비한건 아닌지  안타까울 따름이다",
#   '1',
#   '4',
#   '4',
#   datetime.datetime(2017, 5, 18, 19, 6),
#   0],
#  ['SnB(keco****)',
#   '관람 후 기빨려서 혼났습니다. 기빨리는 영화네요',
#   '2',
#   '4',
#   '4',
#   datetime.datetime(2017, 5, 15, 10, 43),
#   '관람객'],
#  ['슬로(void****)',
#   '자기만의 감정 앞에 가족의 피눈물이 사소하고 기만적이고 불필요한 것이라는 궁색한 변명. 홍감독의 자녀가 이 변명을  잊지 않고 기억해 되돌려주더라도 원망하지 않을런지',
#   '2',
#   '4',
#   '4',
#   datetime.datetime(2017, 4, 30, 4, 0),
#   0],
#  ['해려니(ryun****)',
#   '읭 잘모르겠다 뮤슨영화지',
#   '7',
#   '4',
#   '4',
#   datetime.datetime(2017, 3, 29, 22, 2),
#   '관람객'],
#  ['풀장(pool****)',
#   '사람은 싫지만 영화는 미워할 수가 없네요... 영화인지 현실인지, 정말 흥미진진하게 봤네요',
#   '7',
#   '5',
#   '5',
#   datetime.datetime(2019, 5, 9, 19, 47),
#   0],
#  ['kisw****',
#   '평식이가 7점줫는데 1점주는 년들은 골이비엇네',
#   '10',
#   '5',
#   '5',
#   datetime.datetime(2019, 3, 19, 17, 51),
#   0],
#  ['시속(lian****)',
#   '니들이 사랑할 자격이 있냐? 니들이 사랑을 알아? 이 두 대사로 정리되는 영화.',
#   '7',
#   '5',
#   '5',
#   datetime.datetime(2018, 5, 6, 15, 42),
#   0],
#  ['재규어(popy****)',
#   '홍 형 영화중 젤 별로임...;;;',
#   '1',
#   '5',
#   '5',
#   datetime.datetime(2018, 2, 26, 9, 51),
#   0],
#  ['뿌(qorq****)',
#   '김민희홍상수실력은인정',
#   '10',
#   '5',
#   '5',
#   datetime.datetime(2017, 12, 19, 14, 31),
#   0],
#  ['radi****',
#   '영화 평점을 쓰거라. 불륜평점쓰지말고. 니네 이러다 나중에 늙어서 태극기 든다~',
#   '9',
#   '5',
#   '5',
#   datetime.datetime(2017, 12, 10, 23, 4),
#   0],
#  ['Foxtail(chsj****)',
#   '홍상수의 영화는 예측할 수 없다.',
#   '10',
#   '5',
#   '5',
#   datetime.datetime(2017, 12, 6, 10, 8),
#   0],
#  ['아더왕(mylw****)',
#   '일상적인 얘기들이 흘러가는 영화, 의외로 시간 가는 줄 모르고 봤음',
#   '7',
#   '5',
#   '5',
#   datetime.datetime(2017, 5, 16, 22, 52),
#   '관람객'],
#  ['과립(kwar****)',
#   '밤의 해변에서 홍상수 혼자',
#   '8',
#   '5',
#   '5',
#   datetime.datetime(2017, 3, 31, 9, 40),
#   '관람객'],
#  ['yeob****',
#   '이것들아 영화를 봐라! 불륜을 보지말고',
#   '10',
#   '6',
#   '6',
#   datetime.datetime(2018, 12, 28, 3, 31),
#   0],
#  ['vivi****',
#   '멋진 영화입니다. 정말 멋진 영화입니다. 가슴에서 머리에서 지워지지 않는 여운을 남길 정도로 아름다운 감정연기와 연출, 아름다운 장면 게다가 음악까지. 모든 것이 완벽한 영화. 2번을 보았는데도 또 보고 싶네요. 김...',
#   '10',
#   '6',
#   '6',
#   datetime.datetime(2017, 4, 13, 17, 2),
#   0],
#  ['SiD(park****)',
#   '껍데기는 가라, 고함을 지른 후 수줍은 미소를 짓고. 오늘 사랑하고 내일 죽으리',
#   '10',
#   '7',
#   '7',
#   datetime.datetime(2018, 10, 10, 22, 37),
#   0],
#  ['가을(sess****)',
#   '마지막 장면이 기억에 남았어요',
#   '10',
#   '7',
#   '7',
#   datetime.datetime(2017, 5, 13, 15, 18),
#   '관람객'],
#  ['jsou****',
#   '정말 사랑했고 그게 깨져버리면 미치는구나. 미친놈년들.',
#   '3',
#   '7',
#   '7',
#   datetime.datetime(2017, 3, 28, 11, 37),
#   0],
#  ['sung****',
#   '1점짜리 수준낮은 선동배댓글에 공감이나 쳐하는 인간들 엿먹으라고 만든 영화..속이 시원하구만..ㅋㅋㅋㅋ...홍상수 감독 영화중에 젤 잼있었음...그리고 베를린 영화제의 여우주연상 선택도 제대로인듯',
#   '9',
#   '8',
#   '8',
#   datetime.datetime(2019, 6, 11, 8, 4),
#   0],
#  ['마크(hess****)',
#   '삶의 어떤 시점에서는 사랑이 다라고 느껴질 때가 있었다.',
#   '8',
#   '8',
#   '8',
#   datetime.datetime(2017, 3, 27, 18, 1),
#   0],
#  ['sjsl****',
#   '할리웃 배우들이 바람피고 사랑하면 예술이고 멋있고한국인이하면 더럽지?',
#   '10',
#   '9',
#   '9',
#   datetime.datetime(2018, 3, 24, 18, 30),
#   0],
#  ['주니여니(aema****)',
#   '여진이 요란했어요.영화에만 집중하고 보면 좋겠슴니다',
#   '9',
#   '9',
#   '9',
#   datetime.datetime(2017, 3, 28, 19, 48),
#   0],
#  ['dani(xoxo****)',
#   '산뜻한 고독의 산뜻한 풍경',
#   '8',
#   '9',
#   '9',
#   datetime.datetime(2017, 3, 27, 14, 52),
#   0],
#  ['keep****',
#   '쓸쓸하다.  누군가를 선택하면 외로움과 고독함이 따라서 오나보다.',
#   '7',
#   '16',
#   '16',
#   datetime.datetime(2017, 3, 28, 17, 18),
#   '관람객'],
#  ['김민정(dram****)',
#   '가짜라고 그것이 아닌건 다 가짜라고 소리치는 김민희가 안예쁠 이유는 없었다.',
#   '8',
#   '25',
#   '25',
#   datetime.datetime(2017, 3, 27, 21, 23),
#   '관람객'],
#  ['zZ(kane****)',
#   '인생은 짧으니 너대로 살라고 쉽게 대사로 읊어주는 영화',
#   '8',
#   '58',
#   '58',
#   datetime.datetime(2017, 3, 24, 1, 59),
#   '관람객'],
#  ['yjs7****',
#   '과하게 욕하는 사람들은 심심해서 그러는게  맞다고 생각. 당사자들의 도덕적인 문제는 당사자들끼리 알아서 해결하거나 대가를 치르겠지 왜그리 남의 일에 에너지 써가며 씹고뜯는지 이해불가..영화는 전부 다 이해하지는 못해...',
#   '8',
#   '0',
#   '1',
#   datetime.datetime(2020, 9, 6, 21, 4),
#   0],
#  ['포대화상미륵존여래불(baks****)',
#   '한국 영화판에서 홍상수는 봉준호나 박찬욱 나홍진을 제외하곤 유일한 작가임',
#   '8',
#   '0',
#   '1',
#   datetime.datetime(2020, 8, 25, 1, 23),
#   0],
#  ['TempusFugit(tear****)',
#   "처한 현실에 따라 하고 싶은 말만 조금씩 달라질 뿐 이 영화와 저 영화의 씬을 섞어도 전혀 이질감 없을 지속적인 자기 복제.  '그냥 입 좀 조용히 하세요. 다 자격 없어요. 다 비겁하고, 다 가짜에 만족하고...",
#   '7',
#   '0',
#   '1',
#   datetime.datetime(2020, 8, 14, 16, 10),
#   0],
#  ['왕따거부(meta****)',
#   '‘입 좀 조용히하세요’가 기억에 남는다',
#   '8',
#   '0',
#   '1',
#   datetime.datetime(2020, 7, 7, 6, 55),
#   0],
#  ['은채맘(essa****)',
#   '별하나가전분데  어케 7점이 넘지;;;;',
#   '1',
#   '0',
#   '1',
#   datetime.datetime(2020, 5, 20, 11, 6),
#   0],
#  ['장나윤(smil****)',
#   '평점 남기는 것들 그렇게 역겹다 더럽다~ 이렇게 적을거면 애초에 역겨운 영화를 왜 본거야? 돈쓰고 시간쓰고? ㅋㅋㅋ하여간 이상한것들 많다',
#   '2',
#   '0',
#   '1',
#   datetime.datetime(2020, 5, 1, 13, 43),
#   0],
#  ['헤루미(heyl****)',
#   'ㅋ....뭥미? 시간낭비...',
#   '1',
#   '0',
#   '1',
#   datetime.datetime(2020, 3, 21, 18, 30),
#   0],
#  ['coverture(jin0****)',
#   '도대체 뭘 말하려는건지 모르겟다 시간 아까움',
#   '2',
#   '0',
#   '1',
#   datetime.datetime(2020, 3, 15, 2, 50),
#   0],
#  ['뚜찌(dudd****)',
#   '영화 창의적 기법은 좋은데 정말 변명하는거 같다 감독이 영환 참 잘 만진다는 생각들게 한 작품이긴함',
#   '4',
#   '0',
#   '1',
#   datetime.datetime(2020, 2, 10, 7, 19),
#   0],
#  ['hips(dkan****)',
#   '머리기 깨질꺼 같다. 자세 돌아보면 얼굴값 하는 놈들만 만나서 후회하는 것인가. 아니면정재영이 하는 역활을 만나는 것이 좋은가 답은 정재영이다. 썩어빠진 세상은 사랑하는 여자에게 그런소리 들으면 잡혀산다 이딴말로 꾸...',
#   '7',
#   '0',
#   '1',
#   datetime.datetime(2017, 11, 29, 9, 32),
#   0],
#  ['힐리우스(jazz****)',
#   '아직도 사랑을 찾고 있니 ?',
#   '7',
#   '0',
#   '1',
#   datetime.datetime(2017, 10, 9, 10, 2),
#   0],
#  ['전상현(rkfk****)',
#   '못봤다네나는 바보인가',
#   '6',
#   '0',
#   '1',
#   datetime.datetime(2017, 7, 21, 12, 45),
#   '관람객'],
#  ['feel****',
#   '그냥그냥그냥그랬음..',
#   '7',
#   '0',
#   '1',
#   datetime.datetime(2017, 5, 3, 15, 15),
#   '관람객'],
#  ['쪼꼬(si45****)',
#   '마음이 아려요...연기가 너무 좋네요',
#   '10',
#   '1',
#   '2',
#   datetime.datetime(2020, 8, 21, 20, 3),
#   0],
#  ['또릿(fm07****)',
#   '왜 김민희가 홍상수를 사랑할 수 밖에 없었는지 알게 해준 영화. 논란과 구설수를 떠나 영화 자체만을 보았을 때 , 누가 봐도 거장의 작품이다.',
#   '10',
#   '1',
#   '2',
#   datetime.datetime(2020, 8, 14, 5, 47),
#   0],
#  ['step****',
#   '외국,,특히 유럽감독 배우들이 바람피는건 능력이요 일상이라고 생각해주는게 시크라고 생각하는 좃미개 허세코리언들이 여기와서 개념행세 지적질중ㅋㅋㅋㅋ',
#   '10',
#   '1',
#   '2',
#   datetime.datetime(2020, 6, 9, 16, 40),
#   0],
#  ['김기석(tl21****)',
#   '음악 좋네. 그런데 영희야 너 그렇게 안 예뻐.',
#   '6',
#   '1',
#   '2',
#   datetime.datetime(2020, 3, 21, 7, 39),
#   0],
#  ['로셀리나(samw****)',
#   '감독의 김민희에 대한 헌정영화인가?조연들의 여주인공에 대한 찬양은 못봐줄지경이고 감독의 예술세계를 이해못하는 나같은 관객은 무시당하는 그들만의 영화임그리고 창문닦는 남자 정체 뭔지..',
#   '1',
#   '1',
#   '2',
#   datetime.datetime(2020, 3, 15, 20, 54),
#   0],
#  ['겨울눈꽃(jwch****)',
#   '불륜 개인사는 둘째치고 내용이 두서없는데다 대사도 넘 허접하고 진짜 대학생들이 만든 줄... 김민희 연기도 넘 어색하고 국어책 읽는 것 같던데 여우주연상 준게 이해가 안감. 유치한 김민희 찬양도 그렇고 돈내고 봤으면...',
#   '1',
#   '1',
#   '2',
#   datetime.datetime(2020, 2, 28, 15, 16),
#   0],
#  ['스미스(hhch****)',
#   '하루하루가 지옥이고 후회로 살고있다 내일 당장죽어도 괜찮다',
#   '2',
#   '1',
#   '2',
#   datetime.datetime(2018, 12, 1, 21, 19),
#   0],
#  ['데이즈(dayz****)',
#   "그냥 어쩌다가 보았다. 공감한 대목은 딱히 없었으나 진정 '사랑'이 무엇인지에 대해서는 다시 생각해보게 된다",
#   '6',
#   '1',
#   '2',
#   datetime.datetime(2018, 1, 22, 16, 5),
#   0],
#  ['Alicia_H(flyy****)',
#   '그들에 사랑을 이해할순 없지만 사랑=고독 그것을 설명하고 싶어하는 그리고 김민희를 위해 그녀의 말을 조금은 들어달라는 .. 맞아요 우리가 사랑을 줄수 있는 사랑을 받을 자격이 있는 사람이 몇이나 있겠어요 정답은 없죠...',
#   '7',
#   '1',
#   '2',
#   datetime.datetime(2017, 11, 24, 3, 11),
#   0],
#  ['미겨노(allr****)',
#   '후회도 계속하다보면 달콤하다 키아~ 역시 영화는 맥주랑 담배피면서 봐야돼 ㅋ 극장가서보면 개짜증',
#   '8',
#   '1',
#   '2',
#   datetime.datetime(2017, 10, 6, 23, 5),
#   0],
#  ['ppod****',
#   '둘이 찍은 영화는 니 둘이나 봐라~~ 웩~',
#   '1',
#   '1',
#   '2',
#   datetime.datetime(2017, 10, 1, 20, 10),
#   0],
#  ['동현(lala****)',
#   '똥이야 이건 비정상이지',
#   '1',
#   '1',
#   '2',
#   datetime.datetime(2017, 10, 1, 16, 16),
#   0],
#  ['아줌마(12aj****)',
#   '정상적인 마음으로 영화 찍어주시길..',
#   '1',
#   '1',
#   '2',
#   datetime.datetime(2017, 8, 19, 4, 0),
#   0],
#  ['kasun(tcat****)',
#   '정말 의미없는 영화. ㅆㄹㄱ',
#   '1',
#   '1',
#   '2',
#   datetime.datetime(2017, 8, 5, 17, 20),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                        0  ...    6
# 0          이상현(lshk****)  ...    0
# 1               7112****  ...    0
# 2               qkrs****  ...    0
# 3           카이(tlsc****)  ...    0
# 4          누군가(jhh1****)  ...    0
# ...                  ...  ...  ...
# 1885         신(sino****)  ...  관람객
# 1886            toss****  ...    0
# 1887            spmi****  ...  관람객
# 1888        마늘(acid****)  ...  관람객
# 1889  minororo(tari****)  ...    0
#
# [1890 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                 nickname  ... watch_movie
# 0          이상현(lshk****)  ...           0
# 1               7112****  ...           0
# 2               qkrs****  ...           0
# 3           카이(tlsc****)  ...           0
# 4          누군가(jhh1****)  ...           0
# ...                  ...  ...         ...
# 1885         신(sino****)  ...         관람객
# 1886            toss****  ...           0
# 1887            spmi****  ...         관람객
# 1888        마늘(acid****)  ...         관람객
# 1889  minororo(tari****)  ...           0
#
# [1890 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
