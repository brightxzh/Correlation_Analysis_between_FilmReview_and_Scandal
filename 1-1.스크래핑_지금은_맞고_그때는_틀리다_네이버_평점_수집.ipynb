# %% [markdown]
# <a href="https://colab.research.google.com/github/brightxzh/movie_review/blob/main/1-1.%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EC%A7%80%EA%B8%88%EC%9D%80_%EB%A7%9E%EA%B3%A0_%EA%B7%B8%EB%95%8C%EB%8A%94_%ED%8B%80%EB%A6%AC%EB%8B%A4_%EB%84%A4%EC%9D%B4%EB%B2%84_%ED%8F%89%EC%A0%90_%EC%88%98%EC%A7%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 140199 ## 지금은맞고그때는틀리다
total_count = 2586  ## 전체 크기=2,586

# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false#

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=251
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=252
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=253
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=254
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=255
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=256
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=257
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=258

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20201109160108" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20201109160108" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20201109160108" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20201109160108" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="140199"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>2,586</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																그때는 맞고 지금은 쳐맞아야지
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304700, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>우리동네(nnli****)</span>
# </a>
# </em>
# <em>2016.06.21 15:03</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','nnli****', 'krMx1ti9dK4g3B1/Ax5jM6l4ts1iDkSUeG28x4xhMjI=', '그때는 맞고 지금은 쳐맞아야지 ', '11304700', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304700">5388</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304700">271</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																영화 제목이 의미하는 말 지금(김민희와 불륜)은 맞고 그때(30년전 결혼)는 틀리다. 지금은 틀리고 그때가 맞다 정신차려라 늘그니 양반아
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304425, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>샤막여우(saew****)</span>
# </a>
# </em>
# <em>2016.06.21 13:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','saew****', 'IkTSAACrHX4zELGdBcivogHtqAEd9TpJKWHvc1Wfe6M=', '영화 제목이 의미하는 말 지금(김민희와 불륜)은 맞고 그때(30년전 결혼)는 틀리다. 지금은 틀리고 그때가 맞다 정신차려라 늘그니 양반아 ', '11304425', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304425">2571</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304425">201</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																바람을피면 그때도맞고 지금도 맞아요
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304567, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>이로사사(dnjs****)</span>
# </a>
# </em>
# <em>2016.06.21 14:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','dnjs****', 'QNtkG3N7IM6Q5OsTHKsFwG1dO5+7S6BAiV8DmbpkT60=', '바람을피면 그때도맞고 지금도 맞아요 ', '11304567', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304567">1954</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304567">138</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																솔직하셔서 좋으시겠어요.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(10362740, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>바ㄱ수지ㄴ(xoxo****)</span>
# </a>
# </em>
# <em>2015.09.25 00:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','xoxo****', 'mWGYvhHIUIqlEk63NdTGdcCPQuhSbFNiNjwuWxGJ+XI=', '솔직하셔서 좋으시겠어요. ', '10362740', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_10362740">1568</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_10362740">179</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																'예술'이라는 같잖은 탈을 쓰고  발정난 추한 늙은이의  비겁한 민낯
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304881, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>kink****</span>
# </a>
# </em>
# <em>2016.06.21 16:23</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','kink****', 'bXMwXKrzJ16Za58SNagBvZUvi09Mn3kVey1U8HSmUa8=', '\'예술\'이라는 같잖은 탈을 쓰고  발정난 추한 늙은이의  비겁한 민낯 ', '11304881', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304881">1348</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304881">101</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:70.0%"></span></span><em>7</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																홍상수와 김민희의 자전적 이야기
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11303921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>theregt(ther****)</span>
# </a>
# </em>
# <em>2016.06.21 09:19</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ther****', 'Bg3MNJqS/kEQPXl1wF/DvPYgwWxTar1ARoNlXhdVn/w=', '홍상수와 김민희의 자전적 이야기 ', '11303921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11303921">1254</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11303921">71</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																영화시사회에서 가슴을  쥐어짰을 아내를 평생 꿈에서 생각하며 지옥을 맛보아라
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11305259, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>페이페이(feih****)</span>
# </a>
# </em>
# <em>2016.06.21 19:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','feih****', 'A/cHNjf8TrF2Ft8EFL/Es/8e/kOPutJ9p+FiMzHq6wA=', '영화시사회에서 가슴을  쥐어짰을 아내를 평생 꿈에서 생각하며 지옥을 맛보아라 ', '11305259', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11305259">1157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11305259">75</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																지금도 그때도 니들은 틀리다...평점 내립시다...
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304112, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>보통의존재(xxxx****)</span>
# </a>
# </em>
# <em>2016.06.21 11:24</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','xxxx****', '32dcsr1yjWxZ56RKs/1Pc9tqOL40O1YXIPjfzhMNMr8=', '지금도 그때도 니들은 틀리다...평점 내립시다... ', '11304112', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304112">1111</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304112">100</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																ㅋㅋㅋㅋ 지들끼리 풀발기 해서 영화찍고 좋다고 2편까지 나온다는데 불륜도 미화 시키면 사랑이냐? 대단하다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304125, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>행복의경운기(isdn****)</span>
# </a>
# </em>
# <em>2016.06.21 11:28</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','isdn****', 'pSLlx7cN1srTisOoJJf9wmgf61TjyS87Wy0NHNrVqrY=', 'ㅋㅋㅋㅋ 지들끼리 풀발기 해서 영화찍고 좋다고 2편까지 나온다는데 불륜도 미화 시키면 사랑이냐? 대단하다. ', '11304125', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304125">954</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304125">77</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																저 와꾸로 20살 어린 여배우 꼬시면서 내가 이 정도 능력남이야 하면서 뿌듯했겠지? 현실은 대중적으로 히트친 영화 한 편 없는 이름빨 인성 쓰레기 감독 ㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304483, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>엔돌핀(pete****)</span>
# </a>
# </em>
# <em>2016.06.21 13:32</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','pete****', 'Pze01Kw9sFJTV9xtZiFpn+26KJoK9ZWm8SReI87B+p0=', '저 와꾸로 20살 어린 여배우 꼬시면서 내가 이 정도 능력남이야 하면서 뿌듯했겠지? 현실은 대중적으로 히트친 영화 한 편 없는 이름빨 인성 쓰레기 감독 ㅋㅋ ', '11304483', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304483">679</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304483">84</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=140199&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "140199",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=140199#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=140199&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=140199#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("140199", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																그때는 맞고 지금은 쳐맞아야지
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304700, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>우리동네(nnli****)</span>
# </a>
# </em>
# <em>2016.06.21 15:03</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','nnli****', 'krMx1ti9dK4g3B1/Ax5jM6l4ts1iDkSUeG28x4xhMjI=', '그때는 맞고 지금은 쳐맞아야지 ', '11304700', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304700">5388</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304700">271</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																영화 제목이 의미하는 말 지금(김민희와 불륜)은 맞고 그때(30년전 결혼)는 틀리다. 지금은 틀리고 그때가 맞다 정신차려라 늘그니 양반아
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(11304425, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>샤막여우(saew****)</span>
# </a>
# </em>
# <em>2016.06.21 13:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','saew****', 'IkTSAACrHX4zELGdBcivogHtqAEd9TpJKWHvc1Wfe6M=', '영화 제목이 의미하는 말 지금(김민희와 불륜)은 맞고 그때(30년전 결혼)는 틀리다. 지금은 틀리고 그때가 맞다 정신차려라 늘그니 양반아 ', '11304425', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_11304425">2571</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_11304425">201</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t그때는 맞고 지금은 쳐맞아야지 \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '그때는 맞고 지금은 쳐맞아야지'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '1'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('5388', '271')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# '우리동네(nnli****)'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2016, 6, 21, 15, 3)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 140199
total_count = 2586  ## 전체 크기=2586

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['우리동네(nnli****)',
#   '그때는 맞고 지금은 쳐맞아야지',
#   '1',
#   '5388',
#   '271',
#   datetime.datetime(2016, 6, 21, 15, 3),
#   0],
#  ['샤막여우(saew****)',
#   '영화 제목이 의미하는 말 지금(김민희와 불륜)은 맞고 그때(30년전 결혼)는 틀리다. 지금은 틀리고 그때가 맞다 정신차려라 늘그니 양반아',
#   '1',
#   '2571',
#   '201',
#   datetime.datetime(2016, 6, 21, 13, 11),
#   0],
#  ['이로사사(dnjs****)',
#   '바람을피면 그때도맞고 지금도 맞아요',
#   '1',
#   '1954',
#   '138',
#   datetime.datetime(2016, 6, 21, 14, 7),
#   0],
#  ['바ㄱ수지ㄴ(xoxo****)',
#   '솔직하셔서 좋으시겠어요.',
#   '9',
#   '1568',
#   '179',
#   datetime.datetime(2015, 9, 25, 0, 7),
#   '관람객'],
#  ['kink****',
#   "'예술'이라는 같잖은 탈을 쓰고  발정난 추한 늙은이의  비겁한 민낯",
#   '1',
#   '1348',
#   '101',
#   datetime.datetime(2016, 6, 21, 16, 23),
#   0],
#  ['theregt(ther****)',
#   '홍상수와 김민희의 자전적 이야기',
#   '7',
#   '1254',
#   '71',
#   datetime.datetime(2016, 6, 21, 9, 19),
#   0],
#  ['페이페이(feih****)',
#   '영화시사회에서 가슴을  쥐어짰을 아내를 평생 꿈에서 생각하며 지옥을 맛보아라',
#   '1',
#   '1157',
#   '75',
#   datetime.datetime(2016, 6, 21, 19, 7),
#   0],
#  ['보통의존재(xxxx****)',
#   '지금도 그때도 니들은 틀리다...평점 내립시다...',
#   '1',
#   '1111',
#   '100',
#   datetime.datetime(2016, 6, 21, 11, 24),
#   0],
#  ['행복의경운기(isdn****)',
#   'ㅋㅋㅋㅋ 지들끼리 풀발기 해서 영화찍고 좋다고 2편까지 나온다는데 불륜도 미화 시키면 사랑이냐? 대단하다.',
#   '1',
#   '954',
#   '77',
#   datetime.datetime(2016, 6, 21, 11, 28),
#   0],
#  ['엔돌핀(pete****)',
#   '저 와꾸로 20살 어린 여배우 꼬시면서 내가 이 정도 능력남이야 하면서 뿌듯했겠지? 현실은 대중적으로 히트친 영화 한 편 없는 이름빨 인성 쓰레기 감독 ㅋㅋ',
#   '1',
#   '679',
#   '84',
#   datetime.datetime(2016, 6, 21, 13, 32),
#   0],
#  ['맨(7100****)',
#   '예술적으로 이해력 부족하신분께는 비추합니다. 이해하려고 노력했지만 감독 의도조차 파악못한일인',
#   '1',
#   '685',
#   '91',
#   datetime.datetime(2015, 10, 2, 1, 40),
#   0],
#  ['미키(hopi****)',
#   '김민희 똑같이 돌려받기를',
#   '1',
#   '619',
#   '58',
#   datetime.datetime(2016, 6, 21, 17, 9),
#   0],
#  ['황혼에서(koym****)',
#   '지금도 틀렸고 그 때도 틀렸어',
#   '1',
#   '596',
#   '56',
#   datetime.datetime(2016, 6, 21, 18, 7),
#   '관람객'],
#  ['청명(tnse****)',
#   '영화를 통해 대사하나하나에 설레고 눈물짓고 감동하였었다. 그런데 그게 부도덕한 감정에서 나오는 진심이었다니, 어이가 없고 스스로에게 미안해진다. 홍상수감독은 이영화를 통해 사랑의 감정을 느끼게한 많은 사람에게 반드시...',
#   '1',
#   '541',
#   '60',
#   datetime.datetime(2016, 6, 21, 12, 25),
#   0],
#  ['김다은(dawo****)',
#   '이 영화볼때 왜이리 역겹나 했는데 감독 본인의 현실이라서 그랬나보다',
#   '1',
#   '487',
#   '35',
#   datetime.datetime(2016, 6, 21, 16, 56),
#   0],
#  ['nove(sinj****)',
#   '감독 와이프가 이걸보고 얼굴이 화끈거렸다더만...진짝 최악이다 홍상수 자전적영화',
#   '1',
#   '480',
#   '38',
#   datetime.datetime(2016, 6, 21, 15, 49),
#   0],
#  ['조인성(ligh****)',
#   '똑똑한 척 예술적인 시각을 갖은 척 멋진 말들을 내뱉어 볼려고 노력하는 사람들 그런데 모든 진실이 드러난 후 그들은 그냥 멍청이들이였다',
#   '1',
#   '405',
#   '30',
#   datetime.datetime(2016, 6, 21, 11, 39),
#   0],
#  ['뭉쿤(danc****)',
#   '영화를 찍으셔야지 왜 다큐를 찍으셨죠?',
#   '1',
#   '378',
#   '29',
#   datetime.datetime(2016, 6, 21, 18, 58),
#   0],
#  ['와일드엣(dkfk****)',
#   '불륜을 사랑으로 착각한 감독 ㅉㅉ',
#   '1',
#   '356',
#   '31',
#   datetime.datetime(2016, 6, 21, 11, 36),
#   0],
#  ['최준수(june****)',
#   '20살 어린 여배우가 꼬리쳤다면 안돼요 싫어요 전 가정이 있는 남자에요 했어야지 홀딱 넘어가면 쓰나',
#   '1',
#   '362',
#   '46',
#   datetime.datetime(2016, 6, 21, 13, 29),
#   0],
#  ['씨즌(blue****)',
#   '홍상수영화특징..여자랑 술마시는 장면은 꼭나오고 나중에 어찌해볼려는 수작이 있고..이러한것에 잼있다고 열광하는 관객들~;;;;.. 이젠 다른패턴의 영화찍을때도 안됐나?',
#   '1',
#   '334',
#   '44',
#   datetime.datetime(2015, 10, 23, 8, 26),
#   0],
#  ['사월(hjso****)',
#   '"우리 사람은 되지 못해도 괴물은 되지 말자."',
#   '1',
#   '307',
#   '22',
#   datetime.datetime(2016, 6, 21, 18, 36),
#   0],
#  ['혀니후니엄마(wan1****)',
#   '정재영은 무슨 죄냐....',
#   '1',
#   '275',
#   '18',
#   datetime.datetime(2016, 6, 21, 18, 18),
#   0],
#  ['써머필즈(summ****)',
#   '감독본인의 불륜에 대한 욕구를 영화로 표출한 영화라고 할 수 있겠다',
#   '1',
#   '282',
#   '25',
#   datetime.datetime(2016, 6, 21, 12, 12),
#   0],
#  ['코독(ssim****)',
#   '남자들의 개수작에 대하여  ㅋ',
#   '5',
#   '266',
#   '17',
#   datetime.datetime(2016, 6, 13, 13, 55),
#   '관람객'],
#  ['박준석(gomu****)',
#   '결정적인 순간이 미치는 영향들. 한마디 말로 생기는 일이 있는가 하면 한번의 표현으로 생기는 일도 있다. 지금이라고 딱히 맞지도 않고 그때라고 무조건 틀리지도 않다.',
#   '10',
#   '469',
#   '233',
#   datetime.datetime(2015, 9, 24, 3, 41),
#   0],
#  ['사월(lala****)',
#   '그냥 더러움 그자체 불륜 미화 영화',
#   '1',
#   '260',
#   '28',
#   datetime.datetime(2016, 6, 21, 11, 59),
#   0],
#  ['ajy(silv****)',
#   '예술에 윤리라는 잣대를 들이대지 말라는 아래 댓글 보고 씁니다. 예술은 자유롭되 방종에 빠져서는 안되는 겁니다. 자신의 부도덕을 포장하려 예술을 이용하는 사람은 예술가라고 불릴 자격이 없고, 대중은 그 결과물을 비난...',
#   '1',
#   '239',
#   '19',
#   datetime.datetime(2016, 6, 21, 16, 26),
#   0],
#  ['김오영(oeui****)',
#   '매 불륜에 술 담배에 시시콜콜한 인생이네 평생을 남녀관계 여자 사랑갈구 찌질 피곤하지도 않나 그저 설렘 탐욕 딱 그정도만 즐기는거지 희생하는 숭고한 사랑은 하나도 없네(이 영화에서 정재영은 10점 만점)',
#   '1',
#   '211',
#   '15',
#   datetime.datetime(2016, 6, 12, 20, 37),
#   0],
#  ['shki****',
#   '싸이코 할배 영화 싫다...곧 버림받아라',
#   '1',
#   '215',
#   '20',
#   datetime.datetime(2016, 6, 21, 18, 31),
#   0],
#  ['민준석(minj****)',
#   '불륜은 맞고 결혼은 틀리다',
#   '1',
#   '198',
#   '19',
#   datetime.datetime(2016, 6, 21, 13, 42),
#   0],
#  ['쓰레기통(prot****)',
#   '나도 진지한척 알아주는 척말고 솔직하게 해볼걸 그랬다.',
#   '9',
#   '295',
#   '117',
#   datetime.datetime(2015, 10, 5, 19, 39),
#   '관람객'],
#  ['지식산업(mic8****)',
#   '홍상수영화는 참 짜증나~ 홍상수 머릿속엔 뭐가 들었을까? 섹, 씹, 오입, 붕가붕가, 떡... 사랑이라는 건 있나?  홍상수 아바타 정재영이 불쌍하다....',
#   '4',
#   '199',
#   '23',
#   datetime.datetime(2016, 6, 21, 14, 7),
#   0],
#  ['goodmovie(meis****)',
#   '끔찍하고 더럽고 치졸하고 비열하다',
#   '1',
#   '188',
#   '15',
#   datetime.datetime(2016, 6, 21, 16, 15),
#   0],
#  ['doto****',
#   '진짜 나쁜 놈.  영화제목까지 아내가슴에 대못을 박아야 했나? (아내를 택했던) 그때의 선택은 틀렸고, (불륜을 저지른) 지금의 선택은 맞다고?  아내와의 과거를 그렇게 송두리째 부정해야 속이 시원했냐?  영화속에서...',
#   '1',
#   '187',
#   '19',
#   datetime.datetime(2016, 6, 22, 0, 13),
#   0],
#  ['애몽(aoih****)',
#   '매 순간 선택에 의해 지금도 그때가 된다.',
#   '10',
#   '239',
#   '84',
#   datetime.datetime(2015, 9, 24, 1, 58),
#   0],
#  ['첼강딱(dsme****)',
#   '지금도 불륜 그때도 불륜',
#   '1',
#   '162',
#   '10',
#   datetime.datetime(2016, 6, 21, 18, 25),
#   0],
#  ['MOMO(z3jw****)',
#   '말투,화법,태도의 미묘한 차이가  우리의 삶을 얼마나 변화시키는가. 우리의  삶은 그렇게 단조롭지 않다. 상황에 따른 절대적인 정답은 없다.',
#   '10',
#   '229',
#   '79',
#   datetime.datetime(2015, 10, 8, 19, 51),
#   '관람객'],
#  ['ㅇㅎ(hyoy****)',
#   '알고보니 아주 더러운 영화',
#   '9',
#   '163',
#   '20',
#   datetime.datetime(2016, 6, 21, 18, 58),
#   0],
#  ['윤동욱(ans5****)',
#   '다음 영화는 어떻게 해야 남편관리를 잘 할 수있는지를 보여주는 영화였으면 하는 기대에 1점 드립니다.',
#   '1',
#   '144',
#   '9',
#   datetime.datetime(2016, 6, 21, 16, 17),
#   0],
#  ['작은밤하늘(92re****)',
#   '자기합리화 영화..  심지어 영화로 가족에게 상처도 줘..?이건뭐..  요리사가 독극물 만들어놓고 요리라고 우기는격',
#   '1',
#   '148',
#   '14',
#   datetime.datetime(2016, 6, 21, 16, 21),
#   0],
#  ['ghfu****',
#   '딸이 제일불쌍함. 아빠가 바람피고  다닌다고 주위에서 얼마나 쑥덕거릴까 쯧ㅊ듯',
#   '1',
#   '138',
#   '9',
#   datetime.datetime(2016, 6, 21, 16, 14),
#   0],
#  ['포로리로리(0167****)',
#   '1점도 아깝다 부끄러운줄 알아라',
#   '1',
#   '125',
#   '12',
#   datetime.datetime(2016, 6, 21, 19, 3),
#   0],
#  ['cmg6****',
#   '정의구현하러 왔습니다 ㅋㅋㅋ',
#   '1',
#   '126',
#   '13',
#   datetime.datetime(2016, 6, 21, 12, 30),
#   0],
#  ['비기베어(kosu****)',
#   '졸라 싫다 진짜 개싫어 미친',
#   '1',
#   '114',
#   '12',
#   datetime.datetime(2016, 6, 21, 12, 33),
#   0],
#  ['소윤희부(lees****)',
#   '난 예술영화를 볼 수준이 안되는가보다',
#   '2',
#   '123',
#   '23',
#   datetime.datetime(2015, 10, 23, 18, 11),
#   0],
#  ['아름다운차이(winm****)',
#   '예의 갖춰 이리 뻔뻔한 것도 재주 같습니다ㅋ',
#   '8',
#   '125',
#   '25',
#   datetime.datetime(2015, 9, 25, 6, 52),
#   '관람객'],
#  ['이야이햐(dlth****)',
#   '최근 몇년동안 본 홍상수 작품중에 제일재밌다ㅋㅋㅋ정재영 연기 진짜와ㅎㄷㄷ',
#   '10',
#   '351',
#   '251',
#   datetime.datetime(2015, 9, 24, 1, 58),
#   0],
#  ['rlat****',
#   '와...역겨워.. 언젠가 돌려받을 날이 올거다. 분명.',
#   '1',
#   '104',
#   '6',
#   datetime.datetime(2016, 6, 21, 12, 47),
#   0],
#  ['핑크(runa****)',
#   '더럽고 역겹고 토나와. 어우 ㅋㅋㅋ',
#   '1',
#   '105',
#   '8',
#   datetime.datetime(2016, 6, 21, 12, 37),
#   0],
#  ['버럭해민(seal****)',
#   '소소하게 터지는 웃음, 현실성 100',
#   '10',
#   '150',
#   '63',
#   datetime.datetime(2015, 9, 27, 0, 10),
#   '관람객'],
#  ['판다(dir_****)',
#   '그때도 틀리고 지금도 틀리다',
#   '1',
#   '93',
#   '7',
#   datetime.datetime(2016, 6, 21, 13, 19),
#   0],
#  ['강은채(kang****)',
#   '지 더러운 얘기를 합리화해놨네ㅉㅉ',
#   '1',
#   '87',
#   '7',
#   datetime.datetime(2016, 6, 21, 23, 9),
#   0],
#  ['assh****',
#   '이곳이 불륜의 성지인가요?',
#   '1',
#   '86',
#   '8',
#   datetime.datetime(2016, 6, 21, 17, 15),
#   0],
#  ['아로아(ecla****)',
#   '아게 자기 부인 가슴에 대못 박은 영화라지? 이거 보고 불륜 커플은 더 희열을 느끼겠지. 우리 사랑은 이보다 강하다.. 하면서. 변태들',
#   '1',
#   '89',
#   '11',
#   datetime.datetime(2016, 6, 21, 22, 26),
#   0],
#  ['A Moon Shaped Pool(cas5****)',
#   '아무리 세상이 타락했다지만 최소한 인간으로서의 예의는 서로 갖추고 헤어진 후 새로 시작했어야지. 30년 넘게 뒷바라지하고 치매 걸린 지 어미 수발까지 든 조강지처에게 이렇게 통수를 치다니 사랑을 떠나 인간으로서 기본...',
#   '1',
#   '80',
#   '5',
#   datetime.datetime(2016, 6, 22, 8, 25),
#   0],
#  ['setr****',
#   '진짜 내모습을 알아야 진짜 당신의 모습을 볼 수 있다.',
#   '10',
#   '110',
#   '37',
#   datetime.datetime(2015, 9, 25, 22, 57),
#   '관람객'],
#  ['ㅇㅈ(fshr****)',
#   '더럽다더러워 간통죄 다시 생겨야합니다',
#   '1',
#   '82',
#   '11',
#   datetime.datetime(2016, 6, 21, 12, 31),
#   0],
#  ['히어로즈(kms0****)',
#   '평론가들 특징 : 어떤 감독이 난해한 영화를 낸다 -> 대중들:??? -> 평론가들 : 자신도 난해하지만 의미있는척, 아는척을 오지게한다 -> 그러면 대중들은 평론가는 뭔가 좀 다르구나하고 느껴서 인...',
#   '1',
#   '89',
#   '20',
#   datetime.datetime(2016, 6, 21, 14, 50),
#   0],
#  ['취생몽사(gooo****)',
#   '상영관이 많이 있었으면 좋겠습니다.영화 선택의 자유가 없으니 상영관이   많은  영화의 천만관객이 좋게만 보이진 않습니다. 진짜 영화가 재밌고 잘만들어서 그런건지 기타의 힘인지..',
#   '10',
#   '216',
#   '152',
#   datetime.datetime(2015, 9, 24, 10, 31),
#   0],
#  ['불낙지볶음(that****)',
#   '감독님이 만드신 영화가 본인얘기라면서요 .',
#   '1',
#   '64',
#   '1',
#   datetime.datetime(2016, 6, 21, 16, 55),
#   0],
#  ['김군(hity****)',
#   '본인의 인생, 얘기, 생각, 바램을 영화로 녹여봤자 남들은 이해해줄수 없는 손가락질 받는 인생 얘기 일 뿐.',
#   '1',
#   '66',
#   '3',
#   datetime.datetime(2016, 6, 21, 17, 10),
#   0],
#  ['azur****',
#   '감독이나 여배우나 둘 다 재수없다',
#   '1',
#   '70',
#   '7',
#   datetime.datetime(2016, 6, 21, 13, 16),
#   0],
#  ['로기(ksr6****)',
#   '홍상수 감독에게 크게 실망했다. 본인은 그게 진정한 사랑을 찾아 헤매는 과정이라 생각하겠지만 남겨진 가족들에 대한 책임감과 존중을 저버런 행동일뿐',
#   '1',
#   '65',
#   '3',
#   datetime.datetime(2016, 6, 21, 21, 34),
#   0],
#  ['신비(blue****)',
#   '짐승이냐 돌아가면서 짝짓기하게?',
#   '1',
#   '70',
#   '8',
#   datetime.datetime(2016, 6, 21, 22, 19),
#   0],
#  ['아이오베희단(ysh9****)',
#   '남자가 옷도 벗고 그러는 영화라 잼씀',
#   '10',
#   '114',
#   '52',
#   datetime.datetime(2015, 9, 28, 0, 14),
#   0],
#  ['락사마(ckr3****)',
#   '상영관좀 늘려주세요 지방에 사는 사람들은 서울까지 가서 봐야하나요',
#   '10',
#   '322',
#   '261',
#   datetime.datetime(2015, 9, 24, 17, 16),
#   0],
#  ['열두시반(6_6b****)',
#   '적나라해서 창피하기도 싫기도 하지만 동시에 너무 사랑스러워서 내가 영화속에 있었으면 좋겠다 싶은 느낌. 빨리 날이 추워졌으면 좋겠다.',
#   '9',
#   '195',
#   '137',
#   datetime.datetime(2015, 9, 27, 15, 48),
#   '관람객'],
#  ['crea****',
#   '사랑만 있으면 그 다른 어떠한 것은 희생을 감수하겠다는 듯이 아내도, 자식도 모두 버렸으니, 이제 기존의 영화도, 앞으로 만드는 영화도 대중들의 따가운 눈초리를 받는 것도 아무렇지 않게느끼시겠지요?',
#   '1',
#   '64',
#   '7',
#   datetime.datetime(2016, 6, 21, 17, 13),
#   0],
#  ['hapo****',
#   '자전적 불륜 이야기?ㅋㅋ',
#   '1',
#   '59',
#   '3',
#   datetime.datetime(2016, 6, 21, 13, 30),
#   0],
#  ['김휘(gimh****)',
#   '요즘들어한사람을알아가며지금은맞고그때는틀린경우가많았는데감정적으로힘든부분이영화를보고한결나아졌다.',
#   '10',
#   '133',
#   '77',
#   datetime.datetime(2015, 9, 24, 15, 0),
#   '관람객'],
#  ['달빛요정역전만루홈런(jyjy****)',
#   '네  다음  노양심 불륜남녀  ㅉㅉㅉ',
#   '1',
#   '60',
#   '5',
#   datetime.datetime(2016, 6, 21, 20, 5),
#   0],
#  ['ㅇㅇ(haj1****)',
#   '지금은 맞고 그때도 맞아야지',
#   '1',
#   '59',
#   '5',
#   datetime.datetime(2016, 6, 21, 20, 7),
#   0],
#  ['isnt****',
#   '이걸보는 감독 가족의 마음은 어떨까 생각만해도 괴롭다 딸이 불쌍',
#   '1',
#   '57',
#   '4',
#   datetime.datetime(2016, 6, 21, 18, 48),
#   0],
#  ['배송송(toon****)',
#   '최악인듯 볼가치조차없다',
#   '1',
#   '57',
#   '5',
#   datetime.datetime(2016, 6, 21, 19, 44),
#   0],
#  ['죠(aram****)',
#   '...어이없다 정말 가족들 가슴에 못박고 뭐하는짓이냐',
#   '1',
#   '55',
#   '4',
#   datetime.datetime(2016, 6, 21, 13, 46),
#   0],
#  ['버럭(star****)',
#   '1점도 주기싫다....',
#   '1',
#   '56',
#   '5',
#   datetime.datetime(2016, 6, 21, 10, 21),
#   0],
#  ['스이미(swim****)',
#   '정재영씨 능구렁이 25마리짜리 연기ㅋㅋㅋ영화관에서 못참고 소리내서 웃었어요',
#   '8',
#   '69',
#   '18',
#   datetime.datetime(2015, 10, 11, 0, 32),
#   '관람객'],
#  ['여름비(tpdl****)',
#   '최악 그 이외의 말도 아깝다',
#   '1',
#   '52',
#   '2',
#   datetime.datetime(2016, 6, 21, 13, 20),
#   0],
#  ['목군(cool****)',
#   '0점 없나요? 정말 역겹고 더러워서 올라올 것 같네요. 홍감독님 헐리우드 진출하셔야겠네 ㅉㅉ',
#   '1',
#   '55',
#   '6',
#   datetime.datetime(2016, 6, 21, 10, 55),
#   0],
#  ['조롱이(bsb1****)',
#   '특유의 웃음코드가 너무 좋다. 1부: 순간순간을 살아가자고 말만 내뱉음 2부 : 진짜 순간순간을 사는건 이런거라 보여줌',
#   '10',
#   '100',
#   '52',
#   datetime.datetime(2015, 9, 29, 4, 46),
#   0],
#  ['trud(mctr****)',
#   '홍상수 영화중에 베스트 3에 들어갈만한 최고작. 절대적으로 옳은 것이란 존재하지 않는다. 각자의 취향 그리고 그  상황과 그 때가 있을뿐.',
#   '10',
#   '100',
#   '53',
#   datetime.datetime(2015, 9, 27, 17, 38),
#   0],
#  ['happyrosa(happ****)',
#   '휴지통에 들어가야 했고, 들어갈 영화',
#   '1',
#   '51',
#   '5',
#   datetime.datetime(2016, 6, 21, 20, 36),
#   0],
#  ['링구아(saic****)',
#   '같은 말을 해도 언제 어떻게 표현하느냐에 따라 이미지가 달라진다',
#   '10',
#   '63',
#   '19',
#   datetime.datetime(2015, 9, 25, 17, 58),
#   0],
#  ['kims****',
#   '무심코 지나친 찰나의 순간속에 우린 얼마나 많은 선택을 하고 있었던가',
#   '10',
#   '53',
#   '10',
#   datetime.datetime(2015, 10, 13, 10, 28),
#   '관람객'],
#  ['단ㅂ(gela****)',
#   '소주가 땡기는 영화 입니다',
#   '10',
#   '72',
#   '29',
#   datetime.datetime(2015, 10, 15, 20, 45),
#   '관람객'],
#  ['ddae****',
#   '김민희 진짜 실망데스요 ㅋㅋ영화를 잘 만들면 뭐해?자기 이야기가 영화인걸김민희 진짜 연기도 잘하고그랬는데 불륜녀 ㅎㄷㄷ홍상수는 명감독이 아니었다...어떻게 불륜녀땜에자식도 있으면서 이혼하자해 ㅎㄷㄷ진짜 영화만 찍으니...',
#   '1',
#   '51',
#   '9',
#   datetime.datetime(2016, 6, 21, 19, 16),
#   0],
#  ['당근(bv05****)',
#   '1점도 아깝지만 어쩔 수 없네요',
#   '1',
#   '45',
#   '5',
#   datetime.datetime(2016, 6, 21, 17, 23),
#   0],
#  ['dmti****',
#   '김민희보다 당신이 더 이해안되',
#   '1',
#   '46',
#   '6',
#   datetime.datetime(2016, 6, 21, 21, 19),
#   0],
#  ['jjji****',
#   '부부는 의리가 있어야한다.',
#   '1',
#   '45',
#   '6',
#   datetime.datetime(2016, 6, 21, 23, 19),
#   0],
#  ['마쉬멜로(hiti****)',
#   '더러운 불륜남녀가 만든영화 줘도 안봐요~',
#   '1',
#   '45',
#   '6',
#   datetime.datetime(2016, 6, 21, 21, 5),
#   0],
#  ['TOTAL ECLIPSE(etha****)',
#   '우웩~우웩~우웩~우웩~',
#   '1',
#   '45',
#   '6',
#   datetime.datetime(2016, 6, 21, 15, 29),
#   0],
#  ['ZOOKI(zook****)',
#   '올해에도 역시 좋았다. 정재영과 김민희의 조합도 상당히 매력적이다.',
#   '9',
#   '73',
#   '34',
#   datetime.datetime(2015, 9, 24, 17, 12),
#   '관람객'],
#  ['바나나킥(sara****)',
#   '재밌는 영화....정배우의 생몸이 계속 아른거리는...',
#   '10',
#   '91',
#   '52',
#   datetime.datetime(2015, 9, 24, 17, 28),
#   '관람객'],
#  ['olav****',
#   '불륜할거면 왜결혼해서 애는낳냐',
#   '1',
#   '40',
#   '2',
#   datetime.datetime(2016, 6, 22, 0, 36),
#   0],
#  ['kkil****',
#   '지금은 맞고, 나중에도 좀 맞자. 시원하게 싸다구 좀 맞자.',
#   '1',
#   '42',
#   '4',
#   datetime.datetime(2016, 6, 21, 16, 52),
#   0],
#  ['온달(euns****)',
#   '중간에 장면이 한번 더 반복되면서 관객입장에서는 곱씹는 느낌이랄까 항상 그랬지만 곁가지 설명이없어서 더 좋았다',
#   '10',
#   '58',
#   '20',
#   datetime.datetime(2015, 9, 24, 19, 41),
#   '관람객'],
#  ['옹양옹양(rt_n****)',
#   '"이런 느낌 갖게 해주셔서 제가 고마워요. 평생 잘 간직할게요." 라는 함춘수의 대사는 어떤 멜로드라마의 대사보다 아름다웠다.',
#   '10',
#   '131',
#   '93',
#   datetime.datetime(2015, 9, 27, 11, 36),
#   0],
#  ['유딤(dbfl****)',
#   '아이고... 예술을 명목으로 이렇게는 살지 맙시다들.',
#   '1',
#   '38',
#   '1',
#   datetime.datetime(2016, 6, 21, 22, 25),
#   0],
#  ['이진아(minh****)',
#   '감독님 기법이랑 느낌 다 너무 좋다  다할만큼만 하고 사는거에요 라는 대사가 맴맴돈다  빠짐 푹',
#   '10',
#   '75',
#   '38',
#   datetime.datetime(2015, 9, 25, 22, 56),
#   '관람객'],
#  ['핑크블러드(milk****)',
#   '이런걸 꼭 영화로 만들어야 하는건가',
#   '4',
#   '44',
#   '8',
#   datetime.datetime(2016, 5, 27, 11, 18),
#   '관람객'],
#  ['엘리펀트(kano****)',
#   '베댓이 되게 웃기네 ㅋㅋ속편 제목으로 딱일 듯',
#   '1',
#   '37',
#   '2',
#   datetime.datetime(2016, 6, 21, 23, 48),
#   0],
#  ['nano****',
#   '의외로 많은 한국 관객들이 어벤져스식 영웅 블록버스터 영화에 슬슬 질려가고 있다. 그래서 정재영, 김민희의 영화 포스터가 더 눈에 들어온다. 비록 홍상수라는 이름이 대중적 재미를 보장하지 못할지라도 이런 잔잔하고 소...',
#   '8',
#   '86',
#   '51',
#   datetime.datetime(2015, 9, 27, 18, 36),
#   0],
#  ['only****',
#   '반복을 통해 순간의 중요성을 깨닫고 앞으로 내인생의 순간들에서 진심을 다해 하루하루를 살아야겠다는 생각이 들었다',
#   '8',
#   '46',
#   '12',
#   datetime.datetime(2015, 9, 30, 1, 0),
#   '관람객'],
#  ['이야기(wkw2****)',
#   '지금은맞고그때는틀리다:다 잊은줄 알았던 같이 소주잔을 기울이던 그녀가 생각난다..소주의 단맛이 그립다..오!수정이 이은주를 위한 영화였다면 이영화는 김민희를 위한 영화같다..내가 뭐라고..라고 말하던 외로워하던 그녀...',
#   '10',
#   '74',
#   '40',
#   datetime.datetime(2015, 9, 25, 1, 20),
#   0],
#  ['우댜미(bwrn****)',
#   '최악최악최악ㅎㅎㅎㅎ',
#   '1',
#   '37',
#   '4',
#   datetime.datetime(2016, 6, 21, 23, 15),
#   0],
#  ['yeum****',
#   '홍상수 영화는 생각하게 하는 힘이 있다',
#   '10',
#   '101',
#   '68',
#   datetime.datetime(2015, 9, 25, 23, 48),
#   '관람객'],
#  ['ㅇㄼㅂㄹ(kgh9****)',
#   '영화여 인생이여ㅋㅋㅋㅋ 웃기는 인간',
#   '1',
#   '33',
#   '1',
#   datetime.datetime(2016, 6, 21, 22, 14),
#   0],
#  ['이슬(mayb****)',
#   '변ㄴ태아즈씨 일기나 쓰세요',
#   '1',
#   '35',
#   '3',
#   datetime.datetime(2016, 6, 21, 14, 58),
#   0],
#  ['앨리스(uc79****)',
#   '아 이게 그 홍상수감독의 마음을 담은 그 영화? 이런쓰레영화에 평점이 필요해?1점도아깝다 ㅋ',
#   '1',
#   '36',
#   '5',
#   datetime.datetime(2016, 6, 21, 14, 40),
#   0],
#  ['김샤방(jino****)',
#   '같은 상황, 다른 말, 다른 결말',
#   '8',
#   '41',
#   '10',
#   datetime.datetime(2015, 9, 27, 11, 47),
#   '관람객'],
#  ['이지수(lhn7****)',
#   '별반개 ,이것도 아까움',
#   '1',
#   '32',
#   '2',
#   datetime.datetime(2016, 6, 21, 20, 50),
#   0],
#  ['접니다(leon****)',
#   '언제 맞아본 적이 있긴 했는가?',
#   '1',
#   '32',
#   '2',
#   datetime.datetime(2016, 6, 21, 15, 6),
#   0],
#  ['이삐(wjsd****)',
#   '여기가 지금 젤 핫하다는곳 맞죠?',
#   '1',
#   '35',
#   '5',
#   datetime.datetime(2016, 6, 21, 16, 27),
#   0],
#  ['라이언(ryan****)',
#   '개인사이라고는 하지만.. 증말 부도덕하네',
#   '1',
#   '30',
#   '1',
#   datetime.datetime(2016, 6, 21, 13, 17),
#   0],
#  ['강북청soul맹01(seji****)',
#   '어떻게 이해를 해야 하는 작품인지..',
#   '1',
#   '31',
#   '2',
#   datetime.datetime(2016, 6, 21, 17, 10),
#   0],
#  ['이향_졸귀(choi****)',
#   '0점 주고싶은데 ~~~',
#   '1',
#   '31',
#   '2',
#   datetime.datetime(2016, 6, 21, 11, 25),
#   0],
#  ['레이피어(puri****)',
#   '나에게도 무수히 많은, 삶을 아주 약간 비틀고 싶은 순간들이 있다. 이 영화가 너무 좋아서 나는 거리를 잠시 배회해야만 했다.',
#   '10',
#   '55',
#   '26',
#   datetime.datetime(2015, 9, 29, 23, 53),
#   '관람객'],
#  ['상남동(angl****)',
#   '지금은사귀고 그때는아니다',
#   '1',
#   '32',
#   '4',
#   datetime.datetime(2016, 6, 21, 11, 15),
#   0],
#  ['히든카드(fall****)',
#   '갑자기 사랑한다는 장면에서 극장안 관객들다빵터짐 ㅎ윤여정 배우님 신의한수 ㅎㅎ',
#   '9',
#   '42',
#   '14',
#   datetime.datetime(2015, 9, 27, 5, 53),
#   0],
#  ['LP(ogr5****)',
#   '홍상수는 매번 다른 경지를 만든다.',
#   '9',
#   '86',
#   '58',
#   datetime.datetime(2015, 9, 24, 0, 2),
#   0],
#  ['gksr****',
#   '그 연예인의 그 코디ㅋㅋ',
#   '1',
#   '29',
#   '2',
#   datetime.datetime(2016, 6, 21, 23, 21),
#   0],
#  ['사과(cha9****)',
#   '이게 불륜의 시초라는 의미로1점드립니다참 더럽네요',
#   '1',
#   '28',
#   '2',
#   datetime.datetime(2016, 6, 22, 1, 34),
#   0],
#  ['hki1****',
#   '김민희나 홍상수나 인간쓰1레기들',
#   '1',
#   '30',
#   '4',
#   datetime.datetime(2016, 6, 21, 12, 22),
#   0],
#  ['eodl****',
#   '아직도 두분이 만나시려나~?',
#   '10',
#   '30',
#   '4',
#   datetime.datetime(2016, 6, 7, 13, 15),
#   0],
#  ['참예스(jeae****)',
#   '더럽다 더러워 정말..',
#   '1',
#   '26',
#   '1',
#   datetime.datetime(2016, 6, 21, 14, 10),
#   0],
#  ['kang7733(nkc7****)',
#   '기자관리 잘하지 그랬냐',
#   '1',
#   '27',
#   '2',
#   datetime.datetime(2016, 6, 21, 12, 53),
#   0],
#  ['kang****',
#   '무슨얘기를하려는건지 잘모르겠다',
#   '5',
#   '43',
#   '18',
#   datetime.datetime(2015, 10, 2, 23, 3),
#   '관람객'],
#  ['임(gkqr****)',
#   '영화보면서 이게 다 무슨대산가 뭔소리야 왜이래 했는데 그 얘기였다니.... 대실망',
#   '1',
#   '25',
#   '1',
#   datetime.datetime(2016, 6, 22, 0, 28),
#   0],
#  ['nell****',
#   '상수형 항상 풀발기 절대 고개 안숙여',
#   '1',
#   '25',
#   '1',
#   datetime.datetime(2016, 6, 21, 16, 7),
#   0],
#  ['설짱(love****)',
#   '지금보면 이런일이터질줄미리예상하고. 대중에게 본인들입장에서 이해를돕고자 미리만들어낸영화인듯.지네는로맨스라고생각할지모르지만 이건명백한불륜맞다',
#   '1',
#   '22',
#   '0',
#   datetime.datetime(2016, 6, 23, 10, 31),
#   0],
#  ['넌모농(tldh****)',
#   '다른건 몰라도 그녀때문에 딸 유학비를 중단했다는건 기가 차다.',
#   '1',
#   '24',
#   '2',
#   datetime.datetime(2016, 6, 23, 9, 16),
#   0],
#  ['Dbdjdjd(bdj6****)',
#   '기사 나기전에 홍상수 김민희에 대한 찬양댓글들 ㅈㄴ 웃긴다',
#   '1',
#   '24',
#   '2',
#   datetime.datetime(2016, 6, 21, 17, 47),
#   0],
#  ['ssumit(tnal****)',
#   '우웩 ㅜㅜ볼생각없어..',
#   '1',
#   '22',
#   '1',
#   datetime.datetime(2016, 6, 21, 19, 59),
#   0],
#  ['58983672h(wsdl****)',
#   '볼필요없다고볼필요가,,',
#   '1',
#   '22',
#   '1',
#   datetime.datetime(2016, 6, 21, 10, 54),
#   0],
#  ['blac****',
#   '진짜 더럽다 시바...',
#   '1',
#   '24',
#   '3',
#   datetime.datetime(2016, 6, 21, 12, 10),
#   0],
#  ['흰진(hear****)',
#   '어이상실...ㅋㅋㅋㅋ',
#   '1',
#   '25',
#   '4',
#   datetime.datetime(2016, 6, 21, 12, 20),
#   0],
#  ['쉐쉐(pop8****)',
#   '유부남 그걸 밝히는 타이밍.  그 차이로 그는 그녀의 기억속에 다르게 저장된다.  나도 해봤고 또 당당해봤을 그 미묘한 남녀의 줄다리기.  내가하면 진지 설렘.  내가 스시집 사장이면 웃기고들있네 할어떤 만남 이야기...',
#   '8',
#   '28',
#   '7',
#   datetime.datetime(2015, 10, 16, 0, 12),
#   0],
#  ['pds96(park****)',
#   '지금까지 본 홍상수 감독 영화중 가장 좋았다.. 유쾌함',
#   '10',
#   '55',
#   '34',
#   datetime.datetime(2015, 9, 24, 19, 43),
#   '관람객'],
#  ['sayt****',
#   '별로 이런걸영화라고..',
#   '1',
#   '21',
#   '1',
#   datetime.datetime(2016, 6, 22, 1, 14),
#   0],
#  ['핵잼(pwb1****)',
#   'FUN FUN 하다..',
#   '1',
#   '21',
#   '1',
#   datetime.datetime(2016, 6, 21, 15, 31),
#   0],
#  ['레인보우(club****)',
#   '이게 그건가. 101010자',
#   '1',
#   '21',
#   '1',
#   datetime.datetime(2016, 6, 21, 15, 26),
#   0],
#  ['bamdori(heem****)',
#   '지금도 잼없고 그때도 잼없고 앞으로 도 잼 없을거 같다!',
#   '1',
#   '33',
#   '13',
#   datetime.datetime(2015, 10, 25, 9, 27),
#   0],
#  ['lyjj****',
#   '개념은 어디로 쳐드셨는지?앞으로 김양 영화 절대 안본다쌍수영화도 안본다 더러워 ㅠㅠ0점이 없어서 할수없이 1점이다 부끄러운 줄 알아라',
#   '1',
#   '21',
#   '2',
#   datetime.datetime(2016, 6, 21, 14, 59),
#   0],
#  ['거포나성범(eock****)',
#   '이 영화를 정말 좋게 봤던 나로서는..왠지 모를 배신감만 커졌다',
#   '1',
#   '23',
#   '4',
#   datetime.datetime(2016, 6, 21, 14, 54),
#   0],
#  ['ssam****',
#   '정말 민감한 감성으로 가득찬 영화...',
#   '10',
#   '31',
#   '12',
#   datetime.datetime(2015, 9, 28, 22, 21),
#   '관람객'],
#  ['김메롱(wow_****)',
#   '이동진 평론가...홍상수, 지금도 옳고 그때도 옳다ㅋㅋㅋㅋ',
#   '1',
#   '21',
#   '3',
#   datetime.datetime(2016, 6, 21, 23, 11),
#   0],
#  ['나디아(neo_****)',
#   '제목 뜻이 항상 궁금했는데 와.. 지금(김민희)은 맞고 그 때(부인)은 틀리다 이거네. 이 정도면 거의 소시오 인 듯. 정말 잔인하다.. 부인도 볼 건데 지네들 불륜 얘기를 영화로 ... 진짜 소름돋는다. 사람이 맞...',
#   '1',
#   '18',
#   '1',
#   datetime.datetime(2016, 6, 23, 8, 55),
#   0],
#  ['leec****',
#   '홍상수감독님과 첩의 자전적 이야기~',
#   '1',
#   '19',
#   '2',
#   datetime.datetime(2016, 6, 23, 13, 3),
#   0],
#  ['앙헬(koko****)',
#   '성지순례왔습니다~~~',
#   '10',
#   '21',
#   '4',
#   datetime.datetime(2016, 6, 21, 11, 58),
#   0],
#  ['깔록이(ky19****)',
#   '처음 1시간은 김민희가 예쁜영화, 다음 1시간은 홍상수가 예쁜영화',
#   '10',
#   '94',
#   '77',
#   datetime.datetime(2015, 9, 24, 16, 10),
#   0],
#  ['부자아빠(espa****)',
#   '예술을 가장한 지저분하고 추악한 스캔들..그이상도 그 이하도 아님~',
#   '1',
#   '16',
#   '0',
#   datetime.datetime(2016, 6, 23, 11, 25),
#   0],
#  ['vivere est amare(frid****)',
#   '홍상수 영화보고 나면 항상 불쾌하고 찜찜했는데 왜 씨네21에선  최고라고 할까 맨날 궁금했는데,  씨네21까지 싫어진다.',
#   '1',
#   '16',
#   '0',
#   datetime.datetime(2016, 6, 23, 10, 55),
#   0],
#  ['안나미(anna****)',
#   '똑같이 당하시길 바랍니다.',
#   '1',
#   '17',
#   '1',
#   datetime.datetime(2016, 6, 23, 15, 58),
#   0],
#  ['ERROR(spec****)',
#   '지금은 맞을지 몰라도 앞으로는 조땔꺼다',
#   '1',
#   '17',
#   '1',
#   datetime.datetime(2016, 6, 22, 14, 36),
#   0],
#  ['윤댕이(love****)',
#   '그때는 맞고, 지금은 틀니다.',
#   '1',
#   '17',
#   '1',
#   datetime.datetime(2016, 6, 22, 11, 45),
#   0],
#  ['Smile(sung****)',
#   '에휴ㅠ가조이불쌍...',
#   '1',
#   '17',
#   '1',
#   datetime.datetime(2016, 6, 21, 12, 32),
#   0],
#  ['투영맘(chsh****)',
#   '예술을 가장한 졸작!   거장이 아닌 찌질남! 관심도 아깝다',
#   '1',
#   '18',
#   '2',
#   datetime.datetime(2016, 6, 22, 10, 2),
#   0],
#  ['드로잉(same****)',
#   '뭣이 중헌지도 모름서!!',
#   '1',
#   '18',
#   '2',
#   datetime.datetime(2016, 6, 21, 12, 53),
#   0],
#  ['맑은(iamr****)',
#   '홍상수감독 영화는 왜 거의 비슷하다고 느끼게 될까?',
#   '5',
#   '18',
#   '2',
#   datetime.datetime(2015, 11, 19, 15, 38),
#   '관람객'],
#  ['스카우터(ju74****)',
#   '역시 쓸데없는 오지랖의 나라답다. 남 개인사가지고 제3자가 왈가왈부하는 사회인식이 정말 개탄스럽다. 불륜이든 바람이든 그가정사 문제지 그거가지고 남이 어쨋냐 저쨋냐 하면서 작품까지 테러하다니. 이런꼴보기 싫어서 결혼...',
#   '10',
#   '21',
#   '5',
#   datetime.datetime(2017, 3, 8, 13, 2),
#   0],
#  ['라따뚜이(bala****)',
#   '우리는 기억에 의존해서 이것이 맞고 이것이 틀리다라고 과연 규정할수 있는지. 그리고 실컷 웃기다.',
#   '9',
#   '24',
#   '8',
#   datetime.datetime(2015, 9, 24, 22, 21),
#   '관람객'],
#  ['김선주(seon****)',
#   '뭐지? ...나 26년인생 ...영화보다가처음나와봄...사람들다자고,,.? 뭐지?나만이상한건가',
#   '1',
#   '37',
#   '21',
#   datetime.datetime(2015, 9, 28, 23, 9),
#   0],
#  ['켄타(miru****)',
#   '난 이런 불륜영화가 예술로 포장되는게 정말 역겹다.',
#   '1',
#   '17',
#   '2',
#   datetime.datetime(2016, 6, 24, 20, 6),
#   0],
#  ['돋내(dpfn****)',
#   '불륜....ㅂㄹ ㅂㄹ',
#   '1',
#   '17',
#   '2',
#   datetime.datetime(2016, 6, 22, 0, 40),
#   0],
#  ['abd1****',
#   '볼 필요가있는 영화인가?',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2016, 6, 21, 12, 30),
#   0],
#  ['쥐링(koso****)',
#   '가을 밤 딱 좋은 영화!! 관람 후 소주한잔 하고 픈 영화!!',
#   '9',
#   '28',
#   '13',
#   datetime.datetime(2015, 9, 28, 23, 24),
#   '관람객'],
#  ['깨꺄깽깽깨(alwl****)',
#   '보기싫은데 티비에서 졸라 하길래 그래 어디 한번 보자 봤는데 내용이 완전 쓰렉이더만 보는 내내 역겹다? 이 생각뿐:;차라리 그 딴 스캔들 터져도 그 감독의 영화가 재밌다면 능력은 인정해줄텐데 도대체 난 모르겟댜 딴 ...',
#   '1',
#   '14',
#   '0',
#   datetime.datetime(2016, 6, 23, 12, 0),
#   0],
#  ['민뽕자매맘(with****)',
#   '그렇게 자신들 이야기가 하고 싶었으면 당당히 나오시던가,,',
#   '1',
#   '14',
#   '0',
#   datetime.datetime(2016, 6, 23, 1, 24),
#   0],
#  ['커피(lkh8****)',
#   '0점이없는게안타깝다 더러운영화',
#   '1',
#   '14',
#   '0',
#   datetime.datetime(2016, 6, 22, 12, 58),
#   0],
#  ['한가로이(love****)',
#   '도대체가 이영화로 표현하고자 하는게 뭔가요?',
#   '1',
#   '14',
#   '0',
#   datetime.datetime(2016, 6, 2, 16, 22),
#   0],
#  ['하나(xzkd****)',
#   '진짜 다들 높이 평가할 영화가 맞나? 나만 보기 힘들었나?',
#   '2',
#   '14',
#   '0',
#   datetime.datetime(2016, 6, 2, 11, 59),
#   0],
#  ['kjh_****',
#   '영화에도 나옵니다. 극중 함춘수 감독의 입을 통해 "나는 영화 만들때 아무 생각없이 시작한다. 의미 따위를 꼭 부여해야 하냐?"며 평론가를 질타하지요. 그럼에도 평론가 및 소수 팬들은 멋드러진 의미를 ...',
#   '1',
#   '14',
#   '0',
#   datetime.datetime(2016, 1, 30, 13, 31),
#   0],
#  ['소야(ynk1****)',
#   '이 영화를 극장에서 혼자 보면서 가슴이 찢어졌을 부인분 생각하니 내가다 화가나네 지금 둘이 세기의 로맨스 영화 찍는 것 같고 전부인 것 같고 그렇겠지 현실은 본인이 찍은 영화보다 더할거다. 죽을때까지 남 손가락질 받...',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2016, 6, 23, 3, 18),
#   0],
#  ['매이(twon****)',
#   '이 감독 아저씨는 꿈이 불륜인가 보다. 영화마다 결혼한 남자가 불륜을 꿈꾸거나 행동에 옮기는구나. 그래서 꿈을 이룬거구나. 토나와',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2016, 6, 22, 22, 13),
#   0],
#  ['Min(only****)',
#   '조강지처가 좋더라~ 썬연료가 좋더라~~',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2016, 6, 22, 6, 9),
#   0],
#  ['nogo****',
#   '빵점도 아까운 불륜영화',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2016, 6, 22, 3, 44),
#   0],
#  ['뚜뚜(khs6****)',
#   '개인적으로 별로 흠...',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2016, 6, 21, 18, 23),
#   0],
#  ['해롱아(seth****)',
#   '..ㅗ...ㅗ...',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2016, 6, 21, 18, 9),
#   0],
#  ['김송환(info****)',
#   '이거 보고 가슴이 찢어질 가족들을 생각해봐라!!!!',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2016, 6, 22, 1, 52),
#   0],
#  ['천입니다(chc3****)',
#   '더러운영화ㅁㄴㅇ로ㅓㅓ',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2016, 6, 21, 12, 22),
#   0],
#  ['루이스(djtj****)',
#   '내가 나이가 들었나보네. 예전엔 홍상수 감독 영화가 지루해서 못 볼 것 같았는데 지금은 이렇게 여백이 많고 일상적인 영화가 좋다. 홍상수와 김민희 씨의 조합 앞으로도 또 다른 작품으로 뵐 수 있길 바랍니다. ^^',
#   '10',
#   '18',
#   '4',
#   datetime.datetime(2017, 4, 24, 2, 48),
#   0],
#  ['와우(idsk****)',
#   '해피엔딩 베드엔딩 같은 건 없다. 삶은 맺고 끝맺음 없이 연속적으로 흘러간다. 아무 차이가 없는 듯 큰 차이를 갖는다. 동시에 과연 무엇이 달라졌을까',
#   '9',
#   '20',
#   '6',
#   datetime.datetime(2015, 10, 4, 1, 57),
#   0],
#  ['gjwl****',
#   '그날의 공기와 냄새까지도 전달해내는 작품',
#   '7',
#   '24',
#   '10',
#   datetime.datetime(2015, 10, 10, 10, 1),
#   '관람객'],
#  ['Kim(erik****)',
#   '건전한 사회의 구성원이라면 제 정신으로 볼수가 없는 영화. 내가 긴급조치 19호도 그냥 아무 생각없이 본 사람인데 이 영화는 정말 아니다...',
#   '1',
#   '25',
#   '11',
#   datetime.datetime(2015, 10, 4, 13, 18),
#   0],
#  ['juns****',
#   '지금도 이 시간에 일어나는 모든 것들이 그때가 되고 있으니 그러니 아쉽지 않게 살아가는 게 좋지 않나 싶다.... 그래서 지금도 맞고 그때도 맞다',
#   '10',
#   '25',
#   '11',
#   datetime.datetime(2015, 9, 25, 2, 21),
#   0],
#  ['거북아(ogh2****)',
#   '혼자 조조로 보러 갔었다.나말고도 많은 사람들이 혼자 보러 온 것에 놀랐다.혼자서도 잔잔히 보기 좋은영화.정재영의 연기는 역시!',
#   '10',
#   '27',
#   '14',
#   datetime.datetime(2015, 9, 25, 23, 22),
#   0],
#  ['maat****',
#   '틀려요 틀려요 정말 틀린거에요.사랑이 아무리 소중해도 자신이 아버지인건 잊지말아야죠.',
#   '1',
#   '12',
#   '0',
#   datetime.datetime(2016, 6, 23, 12, 5),
#   0],
#  ['1205(x-12****)',
#   '그냥 한심하다. 본인들 사랑이 세기의 사랑이라도 되는 줄 아는가.',
#   '1',
#   '12',
#   '0',
#   datetime.datetime(2016, 6, 22, 11, 26),
#   0],
#  ['momo****',
#   '정신차려10자10자',
#   '1',
#   '12',
#   '0',
#   datetime.datetime(2016, 6, 21, 14, 10),
#   0],
#  ['암굴여왕(vict****)',
#   '이영화는홍할배가 김민희를 유혹하기위해김민희를위한 이벤트적인영화이다 보통감독은여배우에게 이렇게연기하라지시하는데 이 영화는 김민희를위한영화여서 김민희가 이렇게하자 저렇게하자하면 감독은 무조건오케이오케이한거고 그래서김민희...',
#   '1',
#   '13',
#   '1',
#   datetime.datetime(2016, 6, 24, 0, 56),
#   0],
#  ['렝갓(reng****)',
#   '어휴어휴어휴어휴어휴',
#   '1',
#   '13',
#   '1',
#   datetime.datetime(2016, 6, 21, 10, 22),
#   0],
#  ['Roadmovie(hiju****)',
#   '영화로 사랑고백이라니... 촌스럽고 치사하고 이기적이네요. 지금은 사랑이겠지만 언젠가는 후회하실거에요.',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2016, 6, 22, 13, 2),
#   0],
#  ['보노보노야(vbnm****)',
#   '인생을 살면서 내옆사람보다 새로운사람에게 설렘을 느끼는 일이 많겠죠 . 근데 결혼한사람들은 어떻게 잘 지낼까요? 솔직해서 참 좋으시겠으시다만 그럴거면 혼자사셨어야죠',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2016, 6, 22, 10, 29),
#   0],
#  ['brum****',
#   '뭔 그지같은 영화를 ..',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2015, 10, 24, 20, 53),
#   0],
#  ['맴구짱(7221****)',
#   '뭣 모르던 스물 다섯 어린 시절의 선택은 어리석었으며, 지금 우리의 사랑은 더할 나위 없이 아름답다.',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2016, 6, 21, 11, 27),
#   0],
#  ['이상원(ntl_****)',
#   '매 순간순간 지금이 맞다.그 때도 과거로 거슬러가면 지금이지 않는가...',
#   '9',
#   '18',
#   '6',
#   datetime.datetime(2015, 10, 4, 3, 34),
#   '관람객'],
#  ['좋은날(dead****)',
#   '평점 조절합시다..너무 높네.',
#   '1',
#   '24',
#   '12',
#   datetime.datetime(2015, 11, 17, 19, 34),
#   0],
#  ['호빗의지배(came****)',
#   '삶 날것 그대로의 위트 좋았어요 역시',
#   '10',
#   '26',
#   '14',
#   datetime.datetime(2015, 9, 30, 20, 36),
#   '관람객'],
#  ['요시(yosh****)',
#   '최악입니다 잘못됨을 아름답게 미화시키지마세요',
#   '1',
#   '11',
#   '0',
#   datetime.datetime(2016, 6, 22, 12, 17),
#   0],
#  ['카페라테(zodi****)',
#   '홍상수감독 본인 이야기네요.',
#   '1',
#   '11',
#   '0',
#   datetime.datetime(2016, 6, 22, 11, 42),
#   0],
#  ['가오리(just****)',
#   '안보길 잘한 영화..홍상수 영화는 앞으로도 안봅니다.김민희가 블랙리스트 된 것처럼 홍상수도 영화계에서 떠나길 바랍니다',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 23, 23, 0),
#   0],
#  ['캣챤(yhch****)',
#   '더러운 영화의 표본이네요',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 23, 15, 42),
#   0],
#  ['곰도리옹(litt****)',
#   '영화가 아니라 일기를 쓰셨네 불륜꿈나무 1점 드립니다',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 22, 20, 0),
#   0],
#  ['은성(myst****)',
#   '이 할부지가 젤 나쁘다 . 딸뻘에게 무슨짓이냐',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 22, 14, 35),
#   0],
#  ['클라우디오맑쇼(ant5****)',
#   '개노답 나이를 떵구녕으로 드셨나 그럴꺼면 합법적으로 이혼하고 김민희만나던가 자식도있던데 정상적인사람이라면 자식때문에 미안해서라도 이런짓안함김민희나 홍상수나 끼리끼리논다~간통죄 부활해라 개노답 아내딸 위자료 두둑히 챙...',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 22, 12, 18),
#   0],
#  ['닥터펭군(doct****)',
#   '대리만족해서 좋으시겠네요',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 21, 14, 1),
#   0],
#  ['hiph****',
#   '이런 개 OOO 휴....',
#   '1',
#   '12',
#   '1',
#   datetime.datetime(2016, 6, 21, 12, 48),
#   0],
#  ['miumiu(yuuu****)',
#   '김민희랑 홍상수 불륜을 알고보면 소름끼치는 영화다 이런 추한걸 예술이랍시고 내놓는 파렴치한... 가족보기 부끄럽지도 않더냐',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2016, 6, 22, 16, 47),
#   0],
#  ['shamrock(sham****)',
#   '1점도아깝다아아아잉?잉?ㅇ?ㅇㅅ?ㅅ',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2016, 6, 21, 14, 28),
#   0],
#  ['도미넌트(swee****)',
#   '감독뽕 맞아서 여기저기 저 감독입니다 저 감독이에요 하고 다니는 유부남이 자기 유부남인 사실 말 안 하고 어린여자한테 들이대는 찌질한 이야기',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2015, 12, 3, 21, 38),
#   0],
#  ['더블트러블(vasc****)',
#   '홍상수 감독님, 김민희씨 불륜기사가 났는데..사실이 아니기를 바라겠습니다.',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2016, 6, 21, 9, 41),
#   0],
#  ['HongJunKii(besu****)',
#   '결국은 이 영화로 내 영화는 곧 나임을 증명하시는 홍상수 클라스',
#   '10',
#   '17',
#   '6',
#   datetime.datetime(2016, 6, 21, 12, 56),
#   0],
#  ['와쎈버그(khgc****)',
#   '한끝 차이로 다른 스토리를 만들어버리는 섬세함!',
#   '9',
#   '18',
#   '7',
#   datetime.datetime(2015, 10, 13, 13, 51),
#   '관람객'],
#  ['utop****',
#   '자기 영화에 대한 평가에 돌직구를 던진 듯. 그런데 많이 친절해진 느낌.',
#   '9',
#   '18',
#   '7',
#   datetime.datetime(2015, 9, 24, 22, 10),
#   0],
#  ['인간답게(mcma****)',
#   '아오!!원주사는데 강원도는 강릉 한군데빼고 상영하는데가 한군데도 없음..ㅠ.ㅠ 빌어먹을 상영관 독점..',
#   '10',
#   '20',
#   '9',
#   datetime.datetime(2015, 9, 26, 15, 43),
#   0],
#  ['dook****',
#   '솔직히 일본영화가 부러울때가 있었다  자극적인 소재말고 일상의 소재를 아름답게 흥행 생각지 않고 한권의 소설책을 보는듯한것들이 일본영화에서는 많았는데 홍상수감독이 그것보다 더 아름다운 영화를 만들어줘서 고마울 뿐이다...',
#   '10',
#   '21',
#   '10',
#   datetime.datetime(2015, 12, 14, 23, 59),
#   0],
#  ['소공녀(supn****)',
#   '제가 본 홍상수 영화 중에 제일 재밌었어요 변주곡 형식~ 찌질한 남자는 여전한데 정재영이라 그런지 사랑스럽기까지하고 두번째 파트에서 김민희의 미묘하게 다른 감정선! 나비효과라기엔 거창하지만 작은 변화들이 쌓여서 크게...',
#   '10',
#   '28',
#   '17',
#   datetime.datetime(2015, 9, 30, 22, 10),
#   '관람객'],
#  ['nesl****',
#   '불륜영화일 뿐이다 간통죄가 폐지된결과랄까',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 24, 17, 23),
#   0],
#  ['sang****',
#   '왠만 하면 글 안쓰는데 바람 못고침ㅋㅋ 불치병이라서...대대손손 안풀릴 징조보이네 하늘은 다 위에서 보고있거든..',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 24, 2, 13),
#   0],
#  ['달님꿈꾸는(zizi****)',
#   '별 반개도 아깝다.할짓이 없어서 불륜을 저지르냐?니 둘은 헤어져도 예전으론 못돌아간다대중들은 이미 등 돌렸다',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 23, 10, 32),
#   0],
#  ['somethingelse(blue****)',
#   '이게 수필이었다니...',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 23, 10, 32),
#   0],
#  ['눈꽃송이(tvxq****)',
#   '별 하나도 아깝다.. 이런 불륜 저지르시려고 영화 만들으셨어요?  영화 제작비가 아깝네요',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 23, 9, 10),
#   0],
#  ['겨울사랑(minc****)',
#   '그 동안 위트 넘치는 사회비판적 블랙코미디를 잘 만들어왔다고 생각해 즐겨봐왔는데... 그 내용들은 감독 자신의 로망이었던 걸로 되어버렸고 영화내에서 보여진 모든것들이 쓰레기로 되어버렸다 평론가를 포함해 팬들을 모두 ...',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 23, 2, 1),
#   0],
#  ['넥서스북스666(ssss****)',
#   '감독님 어머 어머 웬일이니?지금 뭐하세요 어머 어머어머어머 이분 왜그러니?왜이래요 우리한테? 어머~ 미쳤나봐감독님! 어떡하면 좋아~왜이러세요!!!(개빡친화정)감독님 참으세요~!!',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 23, 1, 42),
#   0],
#  ['하늘금(kse9****)',
#   '지금은 너지만 다음엔 너보다 어린년 꼭 똑같이 당하길인생은 그렇더라',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 22, 21, 35),
#   0],
#  ['노쿠림(chyh****)',
#   'ㄴㄴ 맞는 인생을 살다가 지금 틀린듯',
#   '1',
#   '10',
#   '0',
#   datetime.datetime(2016, 6, 22, 11, 45),
#   0],
#  ['패션모드(in_m****)',
#   '외국영화제에서 유학파에 즉흥연기 방식으로 영화제작하니까 신기해서 상주겠지만, 원래 영화광들이 많은 한국에서 빛을 못봐온 홍상수. 한국영화팬은 이미 당신영화 인정안해줬었어. 근데 이번에 이영화 분륜이야기가 당신 마음의...',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2016, 6, 23, 16, 14),
#   0],
#  ['은영(foxy****)',
#   '1도 아깝다..0은 없냐?',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2016, 6, 23, 16, 11),
#   0],
#  ['akaa****',
#   '수필적영화인가ㄷㄷㄷ',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2016, 6, 22, 14, 51),
#   0],
#  ['dksdga(moli****)',
#   '대단한다. 데뷔작도 불륜얘기 성매매얘기 다른 제작한 영화들도 불륜얘기.. 불륜매니아네. 사랑이 열정만을 일컫지는 않는다. 친밀감과 헌신도 사랑의 구성요소이거늘... 그렇게 본능과 욕망만 좇는게 과연 예술가일까? 그게...',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2016, 6, 23, 15, 57),
#   0],
#  ['love****',
#   '세기의 사랑인 척...ㅋㅋㅋ현실은 그냥 더러운 불륜일 뿐',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2016, 6, 22, 11, 45),
#   0],
#  ['oms1****',
#   '같은 남자로서 너무 추잡하고 부끄럽다',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2016, 6, 22, 5, 17),
#   0],
#  ['kdhg****',
#   '홍상수는 솔직하기라도 하지 위선과 가증덩어리에 한국사람들',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2019, 6, 6, 3, 20),
#   0],
#  ['soni****',
#   '너무나 현실적인 있는 그대로의 영화라 좋다. 배우들 연기도 현실과 100% 일치. 자기 자신까지 객관화할 수 있는 능력이 존경스러움',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2016, 8, 7, 12, 13),
#   0],
#  ['ROCKHIP(hhb5****)',
#   '지금은 만나고 그때는 안만났다.',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2016, 6, 21, 9, 46),
#   0],
#  ['Ddddd(rudd****)',
#   '영화평점을하는곳이지 사람을 평점하지마세요 전 10점입니다',
#   '10',
#   '18',
#   '8',
#   datetime.datetime(2017, 2, 4, 5, 16),
#   0],
#  ['HJ(scsc****)',
#   '이런 느낌 갖게해줘서 고마워요. 재미있는 영화. 찰진 연기.',
#   '10',
#   '22',
#   '12',
#   datetime.datetime(2015, 9, 28, 23, 47),
#   0],
#  ['에이미(prin****)',
#   '같은장면, 다른마음.너무너무 재미있게 봤어요 :)사람의 마음이 움직이는 지점들, 사람의 행동을 끌어내는 말들.인상깊었습니다.표면사이에서 무언가를 끄집어내는 영화였어요.',
#   '10',
#   '23',
#   '13',
#   datetime.datetime(2015, 9, 25, 22, 44),
#   '관람객'],
#  ['isbl****',
#   '이 영화를 보라는거냐 아님 봐달라는거냐몰까요?',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2016, 6, 22, 0, 45),
#   0],
#  ['Lead2M(kait****)',
#   '북촌방향을 매우 인상적으로 봤었는데, 도덕적인 평가는 각자의 몫이고, 작품은 정말좋았다고 생각합니다. 김민희씨를 주연으로 기용한것에서 부터 영화 중간중란 감독님의 진심을 그대로 적나라할정도로 솔직하게 담은 용기에 박...',
#   '10',
#   '14',
#   '5',
#   datetime.datetime(2016, 8, 28, 1, 2),
#   0],
#  ['비람(hyuk****)',
#   '홍상수 영화를 보면서 처음으로 "설렘" 단어가 떠올랐습니다.',
#   '10',
#   '15',
#   '6',
#   datetime.datetime(2015, 9, 28, 21, 47),
#   '관람객'],
#  ['ghdz****',
#   '오랜만에 오니 막상 작품은 보지도 않은 사람들이 평점 테러를 저질렀네요. 시사회마다 여배우 치마 밑을 찍느라 바쁜 연예부 기자들로부터 결혼 윤리를 배우는 이상한 사람들. 찌든 삶을 살다가 갑자기 도덕 의식에 폭발하는...',
#   '10',
#   '16',
#   '7',
#   datetime.datetime(2016, 7, 23, 23, 51),
#   0],
#  ['모리처럼(live****)',
#   '누가 설명좀...대체 무슨 내용이에요? 또 왜 청소년관람불가에요? 아....',
#   '1',
#   '16',
#   '7',
#   datetime.datetime(2015, 10, 24, 18, 2),
#   0],
#  ['cine****',
#   '가히 최강이다...홍감독님..이제 대중성까지 완벽히 갖추기 시작했다..무섭다...',
#   '10',
#   '19',
#   '10',
#   datetime.datetime(2015, 10, 15, 22, 35),
#   '관람객'],
#  ['윤인(oops****)',
#   '잔잔하고 큰웃음 주는 영화 정말 좋았어요',
#   '10',
#   '21',
#   '12',
#   datetime.datetime(2015, 9, 27, 0, 37),
#   '관람객'],
#  ['쏘래(jseo****)',
#   '으으윽~~~어떻게 사랑이라 말할수 있지?  간통죄 폐지해서는 안되는거였어용ㅡㅡ;;',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 25, 23, 1),
#   0],
#  ['00(sixe****)',
#   '평점 개털리고 있네 ㅋㅋ 이거 8점대 영화 아니였나? ㅋㅋㅋㅋ 항상 역겨운 불륜 주제로 영화만들더니 결국 이렇게 당하는구나 ㅋㅋ',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 24, 16, 1),
#   0],
#  ['비비(drea****)',
#   '노망과 야망의 콜라보 :)',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 23, 23, 14),
#   0],
#  ['롤리롤릴(coco****)',
#   '자기변명 영화.. 예술을 모욕하지마라',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 23, 18, 38),
#   0],
#  ['멜로디(lemi****)',
#   '영화의 제목이 이해되지 않아 의미를 곱씹었던 기억이 있는데 사건이 터지고 경악함',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 23, 17, 39),
#   0],
#  ['잔디(aks_****)',
#   '맞고맞고또맞고더맞아라',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 23, 12, 17),
#   0],
#  ['wons****',
#   '너무 막장 영화네요 스트레스만 받았어요',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 23, 2, 47),
#   0],
#  ['진영(jiny****)',
#   '역겹다는 소리밖에.. 역겹다..',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 22, 8, 55),
#   0],
#  ['랄랄라린(ilov****)',
#   '실망이에요..열자열자',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 21, 14, 5),
#   0],
#  ['도토리(wow9****)',
#   '... 1점이 가장 낮은 점수 인기가요?',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2016, 6, 21, 13, 37),
#   0],
#  ['poodoori(bban****)',
#   '별로인 영화, 별로 였던 영화',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2016, 6, 22, 10, 20),
#   0],
#  ['내사랑똘앤미양(craz****)',
#   '0점이 없어서 짜증난다.',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2016, 6, 22, 10, 9),
#   0],
#  ['Diane(wid6****)',
#   '영화도 일점.. 감독도 일점... 아니 감독은 일점도 아깝아깝',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2016, 6, 22, 8, 20),
#   0],
#  ['jjm0****',
#   '국내 최고의 ㅂㄹ로맨스 홍삼수',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2016, 6, 22, 8, 19),
#   0],
#  ['마나부(koko****)',
#   '김민희가 왠 홍상수 영환가 했다 역시',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2016, 6, 22, 1, 10),
#   0],
#  ['똥치(jsk9****)',
#   '이건가요?? 그둘의 시작이....',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2016, 6, 21, 10, 1),
#   0],
#  ['황정희(siwa****)',
#   '돈에 미친 여자와 섹스에 미친 노인네',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 6, 24, 13, 49),
#   0],
#  ['롤리로리(vort****)',
#   '지금도 그때 도 다틀림.',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 6, 23, 15, 18),
#   0],
#  ['cris****',
#   '다틀렸어. 그때도지금도',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 6, 23, 15, 7),
#   0],
#  ['연디(kjkw****)',
#   '너무 뻔뻔하다. 스토리도 자기를 투영해서 쓴 것이나 다름없는데 이걸 개봉한 의도조차 너무나 불순하다. 사랑을 미화해서 불륜을 정당화할려고 하지마라. 예술이라는 이름이 퇴색되게 하는 영화감독임을 다시 느낌. 김민희랑 ...',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 6, 22, 11, 50),
#   0],
#  ['rlat****',
#   '본인들 불륜에 직업과 예술을 이용하는건가요?',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 6, 22, 5, 5),
#   0],
#  ['오백일후썸머(tmdg****)',
#   '민희는맞고 부인은틀리다',
#   '3',
#   '10',
#   '2',
#   datetime.datetime(2016, 6, 21, 12, 47),
#   0],
#  ['heem****',
#   '김민희와 정재영의 말과 행동에 온전히 집중하게 되는 영화',
#   '8',
#   '10',
#   '2',
#   datetime.datetime(2015, 10, 15, 17, 21),
#   '관람객'],
#  ['쿨캣(poli****)',
#   '음..저에게는 살짝 난해해요..중간중간 웃음을 주는 요소가 있긴 한데요..ㅎ여튼 제가 이영화에서 얻은건.. 사랑,연애에 있어선 솔직하고 꾸밈없는 모습이 매력있고 성공확률이 높다는거?ㅋㅋ',
#   '5',
#   '10',
#   '2',
#   datetime.datetime(2015, 9, 28, 20, 55),
#   '관람객'],
#  ['팡팡(must****)',
#   '민희씨 목소리가 차별성이 있어 넘 좋아요',
#   '10',
#   '11',
#   '3',
#   datetime.datetime(2016, 8, 27, 14, 0),
#   0],
#  ['블랭블랭(gene****)',
#   '상영관? 아무도 안보니깐 상영관 수 작게 잡는걸 니네집 근처에 없다고 늘리라고 지ㄹ들 좀 하지마라. 홍상수 같은 인간 동영상은 느그들 집에서나 보세요. 리얼한 불륜 스토리를 영화로  만드니 재미있다고 난리들 치는거 ...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 6, 21, 15, 5),
#   0],
#  ['wkdb****',
#   '내 인생영화.홍상수가 어떻든 김민희가 어떻든간에.',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2016, 8, 5, 4, 39),
#   0],
#  ['Aayo(aayo****)',
#   '핵노잼.. 몰입도가 제로다 그냥,, 중간중간 부자연스러을 클로즈업이 특히 깨더라',
#   '1',
#   '21',
#   '13',
#   datetime.datetime(2015, 10, 4, 8, 31),
#   0],
#  ['뱀슈(snak****)',
#   '또 봐야지, 계속 봐야지. 내 올해의 영화',
#   '9',
#   '23',
#   '15',
#   datetime.datetime(2015, 9, 25, 3, 3),
#   '관람객'],
#  ['초랭이(jeon****)',
#   '역대급  최악의 영화. 영화 촬영기법부터 부자연스러운 연출의 연속에 몰입하지못하고 그때문에 내용이 뭔지도 관심이 가지않았다. 이런걸 예술영화라고도 하나? 내가 지금까지 본 예술영화는 이러지않았는데?',
#   '1',
#   '26',
#   '18',
#   datetime.datetime(2015, 11, 19, 20, 19),
#   0],
#  ['Labbiel(dhfm****)',
#   '영화와 현실을 구분하지 못할때 영화인은 개가 된다',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 25, 15, 45),
#   0],
#  ['현(mujz****)',
#   '유부남 정재영이 찌질거리며 들이대는거 보기역겨워도 마지막에 둘이 그냥 갈길가는거보고 한번쯤은 생길법한 내면의 감정을 묘사하고 싶었던거라 생각했는데.. 왠걸.. 현실이 영화보다 더 말도안되는 3류영화급.',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 24, 21, 8),
#   0],
#  ['김하정(hjkl****)',
#   '...대중의사랑을받아일하는사람이자신의가정에사랑을줄줄모르면서만든영화실망스럽네요',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 24, 17, 33),
#   0],
#  ['김태균패대기제시카(revi****)',
#   '더러운 감독과 더러운 여배우 걸레같은 두남녀의 작품',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 23, 17, 58),
#   0],
#  ['new6****',
#   '매번 똑같은 영화 찍는데 상은 왜자꾸 주는겨~~',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 23, 13, 34),
#   0],
#  ['DrYun(2ndd****)',
#   '쓰레기들 . 인생 그렇게 살지마라. 공기가 아깝다',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 23, 11, 24),
#   0],
#  ['한솔이(hstc****)',
#   '니 영화를 봤던 시간이 아깝다....쓰레기',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 23, 1, 22),
#   0],
#  ['lllllll(stro****)',
#   '유부남이 다른여자꼬시는것 자체가 양심과 진심이 없는 행동이다.알량한 진심으로 사랑을 논하다니 ㅉㅉ아가씨들은 잘 들어라. 여자꼬시는 유부남들은 걸레다.',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 23, 0, 27),
#   0],
#  ['두부(neig****)',
#   '0을 주고 싶은데 평점 0을 만들어주세요',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 22, 22, 52),
#   0],
#  ['스폰쥐밥(yel9****)',
#   '이런거 처음써보는데 진짜 답없어서 씁니다..더러워',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 22, 13, 31),
#   0],
#  ['Alice(seul****)',
#   '감독의 더러운 사생활이 투영된 쓰레기 영화',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2016, 6, 22, 10, 36),
#   0],
#  ['stella(mado****)',
#   '술주정도 이정도면 민폐급. 평론가라는 이들의 지나치게 편향적인 평점에 거부감이 든다.',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 13, 11, 44),
#   0],
#  ['qmfo****',
#   '21살인 나도 한숨밖에 안나온다',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 24, 1, 11),
#   0],
#  ['쁑쁑스팍(trig****)',
#   '그켬별로짜증남지류함',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 23, 21, 58),
#   0],
#  ['act(allm****)',
#   '지금이나 그때나 계속 쳐맞아라.',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 23, 15, 4),
#   0],
#  ['엘롯기(cats****)',
#   '뭐..그냥 쓰레기 열자열자',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 23, 12, 44),
#   0],
#  ['젝키(ashu****)',
#   '피눈물 흘릴날이 올것이다 가정 파탄범들아',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 23, 12, 9),
#   0],
#  ['김(dela****)',
#   '제 점수는요 열자 채웁니다',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 23, 11, 32),
#   0],
#  ['dall****',
#   '감독의 개인사로 인해 이 영화를 보았다는 사실조차 상처받았다. 아름다웠던 영화는 이제 더러운 영화로 남아버렸다.',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 22, 22, 4),
#   0],
#  ['dwd0****',
#   '자전적 영화였네ㅋㅋㅋ',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 22, 14, 48),
#   0],
#  ['울어라콧구멍(dhj1****)',
#   '진심 꼬라지 보기 싫다ㅡㅡ',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2016, 6, 22, 11, 18),
#   0],
#  ['MIU(mari****)',
#   '할만큼 하는거에요.',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2015, 9, 25, 9, 28),
#   '관람객'],
#  ['noll****',
#   '처음 본 홍상수 영화보고 난 후 이전의 모든 영화가 보고싶었다감정을 사람을 삶을 날 것 그대로 표현하는 참 영민한 감독이다. 김민희가 홍상수를 사랑했는지 알겠다..! 스토리 위주의 영화를 좋아하는 한국사람에겐 영원히...',
#   '10',
#   '13',
#   '6',
#   datetime.datetime(2017, 5, 15, 22, 49),
#   0],
#  ['행복더하기(wung****)',
#   '영화는 휴지통 김민희 송윤아 커플들은 감옥행~~~',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 26, 0, 3),
#   0],
#  ['초전박살(uhid****)',
#   '희대의 쌍것들이 연출, 여주인공을 맡은 영화',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 25, 23, 28),
#   0],
#  ['쵸코봉봉(yuki****)',
#   '본능에만 충실하면 그게 짐승과 다를게뭐요! 너무 이기적인 사람이네..부인이싫으면 불륜말고 이혼을 먼저 했어야지! 비겁한인간아!',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 24, 9, 11),
#   0],
#  ['까치왕조FC(mebe****)',
#   '그때는 간통죄 폐지전이고 지금은 폐지되서 제목 더따구냐? 평생 외국이나 떠돌다 둘이 손잡고 객사해라 ㅉㅉ',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 24, 7, 53),
#   0],
#  ['lucky(pbh8****)',
#   '이런걸 영화라고 만들다니..쩝일기는 일기장에..',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 24, 7, 11),
#   0],
#  ['미셸마벨(sin2****)',
#   '영화같이 사는게 자유로운 영혼같고 진정한 예술가같고 막 그런가? 20대 초중반 까진 솔직히 나도 스킨스역병에 걸린적이 있었지  그게 내가 특별한줄 알았는데 그냥 염병이었어 ㅋㅋ 예술에 도덕이 없다 하더라도 니들실체는...',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 23, 51),
#   0],
#  ['Mr Ghost(rudg****)',
#   '1 도 아깝다 ㅋ ㅋ ㅋ ㅋ  0 이 없어서 1 로',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 17, 37),
#   0],
#  ['한글로만(bara****)',
#   '맞다는게 처맞는다는거겠지?',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 17, 25),
#   0],
#  ['jini****',
#   '최악이네요. 실망입니다.',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 17, 8),
#   0],
#  ['All in One(alli****)',
#   '김민희 홍상수 불륜 검색키워드가 나온판에 10점 만점주는 건 알반가? 문학, 영화 등은 인간의 감정을 드러나는 예술이다. 공과사는 구별해야한다는 사람에게 알린다. 예술인 영화는 공과사의 구분이 없다. 더러우면 더러운...',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 16, 56),
#   0],
#  ['꽃1녀(bang****)',
#   '진짜  할말이없네....',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 13, 54),
#   0],
#  ['킴향향(ksj2****)',
#   '일점도아까움 ㅉㅉㅉㅉ',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 13, 48),
#   0],
#  ['jhnb****',
#   '평점을 꼭 줘야하나..',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 13, 47),
#   0],
#  ['루돌프(anso****)',
#   '1점도 아깝다ㅡㅡ...',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 13, 36),
#   0],
#  ['mada****',
#   '열자열자열자열자열자',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 11, 42),
#   0],
#  ['웅시기(toto****)',
#   '역겹네ㅎㅎ쓰레기다ㅎ',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 11, 15),
#   0],
#  ['kogh****',
#   'ㄱㅐ썅마이웨이 핵ㄴㄷ',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 10, 59),
#   0],
#  ['오뚝이(park****)',
#   '니들ㅇㅣ 꿈꾸는 미래는 없을꺼다',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 9, 8),
#   0],
#  ['jinj****',
#   '정신차리시오 당신들 으이구',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 9, 1),
#   0],
#  ['esca****',
#   '쓰레기 배우에  쓰레기 감독에 쓰레기 영화ㅋㅋ',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 9, 0),
#   0],
#  ['용비불패(shwk****)',
#   '하품만 나오는 영화네요. 저하고 코드가 안맞는듯...',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 6, 31),
#   0],
#  ['skad****',
#   '지금은(내가 하면) 맞고(로멘스고) 그때는(남이 하면) 틀리다(불륜 간통이다.)',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 1, 17),
#   0],
#  ['로건(ejsh****)',
#   '불륜은 더럽다 그때도 지금도 앞으로도 영원히',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 1, 0),
#   0],
#  ['Minju(minj****)',
#   '그래봤자 불륜입니다.  상처 준 만큼 똑같이 돌려받기를..  경멸합니다',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 0, 32),
#   0],
#  ['ddss윙(asss****)',
#   '불륜남과 불륜녀의 그들만의 로맨스',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 0, 22),
#   0],
#  ['핸도리뇽(well****)',
#   '남 눈에 눈물나게하면 본인 눈엔 피눈물나요 이사람아...',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 23, 0, 20),
#   0],
#  ['aya3****',
#   '물고 빨고 해봐야 덧 없는 인생이다..이 못 배운 것들아..',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 22, 8, 58),
#   0],
#  ['JH Logic(narn****)',
#   '불륜 남녀 아웃! 그러게 남편 관리 좀 잘하지 그러셨어요',
#   '1',
#   '6',
#   '0',
#   datetime.datetime(2016, 6, 22, 8, 51),
#   0],
#  ['suri****',
#   '평론가들 기를 쓰고 칭찬한거 봐라. 수준하고는 ㅉㅉㅉ',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 30, 10, 15),
#   0],
#  ['djat****',
#   '같이 찍은  재영형님은 무슨죄인가요..ㅠ 재영형님 연기력 좋았는데!!',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 24, 13, 6),
#   0],
#  ['통닭구이(rain****)',
#   '감독의 도덕성이 의심됩니다.부부의 혼약은 잊으셨나요?',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 24, 3, 6),
#   0],
#  ['팅커(mans****)',
#   '간통죄 폐지되서 좋으시겠어요',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 23, 20, 35),
#   0],
#  ['yeun(2yeu****)',
#   '볼수록 혐오스러운 영화',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 23, 7, 13),
#   0],
#  ['YK(love****)',
#   '홍상수. 지금에 와서야  이 영화로인해 느낀다. 주인공 함춘수(홍상수)도 자기 투영한것이였고 자기옷을 정재영한테 입히고  예뻐서 사랑합니다 이 대사도 다  김민희한테 하는 자기 진심이였다는걸.  그냥 불륜 암시였던 ...',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 23, 3, 39),
#   0],
#  ['야무진(yamu****)',
#   '보이콧합니다! 보이콧합니다!',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 23, 1, 40),
#   0],
#  ['몽퀸(stor****)',
#   '역겹네요. 이제와서 진실이 밝혀지니 의도가 빤히 보이는 영화, 그 당시 당신 가족을 포함한 관객을 속인거군요. 거기에 놀아난 아무것도 모르는 사람들과 아내의 심정을 생각해보니 화가 치밉니다. 더럽네요..',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 22, 28),
#   0],
#  ['hyeb****',
#   '예술을 더러운 불륜을 위해 만들다니',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 20, 35),
#   0],
#  ['츄파춥스(js79****)',
#   '불륜 영화 찍고 불륜을 실천하다니...살인 영화 찍으면 살인날 뻔 했네...',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 16, 54),
#   0],
#  ['Nadasooooo(sooj****)',
#   'ㅉㅉㅉ 모가 맞다는건지;;;;ㅉㅉㅉ',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 10, 10),
#   0],
#  ['theh****',
#   '지금이 맞아??? 10자',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 10, 8),
#   0],
#  ['맥주box엔 헬멧필수(nasa****)',
#   '그냥 아무나 감독해도 만들수 있는 영화 제작비도 천만원쓴 영화임?',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 9, 56),
#   0],
#  ['해파리(yell****)',
#   '홍상수들어가는 영화 이제 안본다. 수많은 영화잇는데 왜봄ㅋㅋㅋ',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2016, 6, 22, 9, 54),
#   0],
#  ['k111****',
#   '찌질이 남녀 그외 찌질인',
#   '6',
#   '7',
#   '1',
#   datetime.datetime(2015, 10, 23, 22, 17),
#   0],
#  ['까만콩(wisd****)',
#   '영화의 형식을 빌린 약간 연극같은 느낌.  별것 아닌 소재와 특별할 것 없는 대사도 영화로 만드는 감독의 재주.',
#   '8',
#   '7',
#   '1',
#   datetime.datetime(2015, 10, 14, 17, 19),
#   0],
#  ['유나짱(yuna****)',
#   '아이거내스타일영화네.김민희너무매력적이다.',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 4, 11, 11, 52),
#   0],
#  ['진진(wldm****)',
#   '맞긴 뭘 맞아 틀렸지 ...',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2016, 9, 25, 20, 20),
#   0],
#  ['bin90(sjsg****)',
#   '영화속 대사들을 곱씹어볼 올해의 스캔들. 썩 훌륭하게 봤던 영화가 썩어가는 과정을 보는건 그리 유쾌하지 않으며 좋은 배우가 좋은 사람이 되지 못한 것에 대한 실망또한 씁쓸하다.',
#   '5',
#   '8',
#   '2',
#   datetime.datetime(2016, 6, 21, 14, 20),
#   0],
#  ['이현티(gusw****)',
#   '시간이 흐르면 더 잘 이해할 수 있을 것 같은. 순간의 미학.',
#   '9',
#   '9',
#   '3',
#   datetime.datetime(2015, 10, 10, 15, 1),
#   '관람객'],
#  ['감동건창(wotn****)',
#   '소소한 일상에서 우연히 만나 사랑을 하는 너무나도 순수하고 아름다운 영화였다',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2015, 9, 28, 20, 44),
#   0],
#  ['레니토이(534k****)',
#   '명불허전 홍.상.수..',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2015, 9, 25, 0, 11),
#   0],
#  ['요밍(topa****)',
#   '이 영화를 보고 아이러니하게 홍상수라는 감독이 더 좋아졌다.. 다른사람들이 다 손가락질 해도 돼.. 진짜 사랑 안해본 사람들이니까.. 결혼하면 그 사람만 사랑해야한다는 종교같은 믿음을 가진 신도들은 홍감독한테 손가락...',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2016, 9, 14, 22, 27),
#   0],
#  ['썰쥐ㅎ(hjjh****)',
#   '찌질하고 예민하고 솔직하고 취한듯한 영화라 너무 사랑스럽고 편안하다. 나도 있고 너도 있었다. 배우들 연기 최고다 정말. 불륜은 너무 안타깝지만 영화 자체는 좋은 영화다',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2016, 7, 1, 15, 2),
#   0],
#  ['f198****',
#   '김민희의 매력은 정말...특별히 자극적이지 않은 스토리인데 대사하나, 표정하나에 간질간질 긴장감이 생기는 독특한 느낌을 경험했습니다',
#   '9',
#   '10',
#   '4',
#   datetime.datetime(2015, 10, 27, 20, 57),
#   '관람객'],
#  ['김석종(blue****)',
#   '한국 남자 머릿속의 판타지이자 현장을 그대로 보여준다 편했음',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2015, 10, 14, 2, 6),
#   '관람객'],
#  ['툴펍(inde****)',
# ...
#   0],
#  ['둘리(coco****)',
#   '매력적인 김민희는 언제나 맞네요',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 25, 11, 4),
#   0],
#  ['Speechless(lsy_****)',
#   '좋았지만, 불필요한 러닝타임..',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 24, 23, 47),
#   0],
#  ['쏘울시티(tend****)',
#   '영화 관람의 포인트가 다채롭다. 그래서 지루하지 않다.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 24, 2, 7),
#   0],
#  ['바닷사람(adcr****)',
#   '네 영화가 대사 따위로 이루어진게 아니죠. 정말 크리에이티브한 극과 정재영 김민희씨 연기 정말 잘봤습니다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 23, 10, 32),
#   0],
#  ['DESCENDER(desc****)',
#   '그때도 옳고 지금도 옳다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 19, 3, 43),
#   0],
#  ['클로버(gold****)',
#   '사회적인 상식, 예절이라 불리는 가식을 개인적인 감정에 솔직함이 대조하여 보여준다. 영화 볼맛 나는 영화.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 19, 0, 58),
#   0],
#  ['떠나보까(kill****)',
#   '초창기에는 맞았고 과정속에선 틀렸고 이제는 딱 맞춘다',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 16, 22, 58),
#   0],
#  ['sury****',
#   '기대 없이 봤는데 참 재미있게 봤다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 15, 21, 23),
#   0],
#  ['유비뇽(m1n2****)',
#   '그냥 배드 엔딩이 해피 엔딩으로 변해서 관객들을 기분 좋게 만들어 놓고, 예술영화 여서 사람들이 뭔가 느낀 것 처럼 최면을 걸어 놓는 홍상수.이렇게 행동해서 이건 틀리고 저렇게 행동해서 이건 맞고 이것이 아니고 사람...',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 11, 16, 5),
#   0],
#  ['리본타이(kiss****)',
#   '19금에 선정성등 여러 주의 마크를 보고 김민희씨 베드신이라도 있는지 엄청 기대했는데,,근데 다보고 나서 자꾸 뭔가 여운같은게 남아 있다. 이상 야릇한,,이 느낌은 뭘까?! 틀렸던 그때의 아쉬움인가,,,',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 10, 15, 58),
#   0],
#  ['고기(logo****)',
#   '최근 홍상수 감독 영화들은 개봉 첫날 가서 보긴 하지만 두 번 보고 싶지 않다.',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 9, 3, 23),
#   0],
#  ['hyeri(9101****)',
#   '그때는 맞고  지금은 틀리다. 지금은 맞고 그때는 틀리다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 5, 20, 36),
#   0],
#  ['스투릿지(toky****)',
#   '졸라 재밌어서 깜짝놀랐다 ㅋㅋ그리고 김민희 너무 러블리하다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 5, 5, 56),
#   0],
#  ['쿨러닝(anet****)',
#   '홍상수감독의  영화는  어차피  호불호가 갈리고....영화 보고   제일 처음   느낀건... 김민희가  이렇게  매력적인  배우였나였다.. 김민희의   재발견...',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 2, 4, 57),
#   0],
#  ['해적(mais****)',
#   '홍상수감독의 영화는 한번만 보고 감독의 의도를 알아낸다는것은 힘든것같다..그래서 계속 보고싶어지나보다',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 1, 21, 10),
#   0],
#  ['싱거운(inkb****)',
#   '나의 언어로는 표현 할 수 없는 미묘한 감수성을 말 해 주니까 자꾸 보게 돼요. 홍상수 감독의 영화 중 제일 재미있게 보았어요.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 1, 20, 56),
#   0],
#  ['jaso****',
#   '끝나가는게 아쉬웠던 영화  잘봤습니다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 30, 16, 20),
#   0],
#  ['spre****',
#   '이영화.... 홍상수가 아는 어떤 실화를 바탕으로 한 영화가 아니라면 그는 정말 천재다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 30, 3, 27),
#   0],
#  ['김봉석(nylo****)',
#   '최고입니다 여러분 제가 이렇게 잘 생겼어요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 29, 0, 24),
#   '관람객'],
#  ['song****',
#   '보는 동안 옛 기억이 떠올라서 재밌게 봤습니다. 나는 호감을 얻기 위해 어떻게 말하고 행동 했었는지 생각하게 됐어요.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 27, 8, 36),
#   0],
#  ['최선을다하는자(dowo****)',
#   '여자도 마찬가지겠지만 특히 남자가 더욱더 공감하면서 볼 수 있는 영화다. 솔직함이 얼마나 중요한건지, 그리고 그것이 남녀사이에서 얼마나 필요한건지 절실히 느낄수 있는 영화.정말 재미있게 봤다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 27, 7, 37),
#   0],
#  ['뿅키(k_ac****)',
#   '홍상수식 스타일은 아무나 흉내낼수 없음은 인정. 그런데 왜... 난... 지루할까...아하...',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 24, 22, 17),
#   0],
#  ['수지맘(any7****)',
#   '1시간보다가 잠들었다. 다음날 중간부터 다시 보았다.정재영이 막걸리 마시다가 쓰러진후 벌떡 일어나 연기였다고 하는데 완전 빵터졌다. 정재영 안좋아하는데 연기가 대박이다. 김민희 연기는 진짜 셈세한듯..영화가 지루한데...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 20, 23, 24),
#   0],
#  ['메롱(ha_e****)',
#   '역시나 어색하고 오그라드는 것은 전작들과 비교해서 다름이 없다. 하지만, 이번의 새로운 연출기획은 눈여겨 볼 만한 듯.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 19, 9, 50),
#   0],
#  ['채움늘(almo****)',
#   '상수 영화 중에 처음으로 섹스가 없었던 거 같다.  내용의 밋밋함은 여전하고',
#   '4',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 16, 20, 26),
#   0],
#  ['CHILD(ichi****)',
#   '처음에는 이게 머야?라고 느꼈지만, 영화가 진행될수록 제목의 의미를 다시 느끼게 된다.',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 10, 23, 17),
#   0],
#  ['apex(z2en****)',
#   '연기는 정말 잘하는 것같다',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 10, 18, 12),
#   0],
#  ['북마크(lydf****)',
#   '왜 청불임 근데 ㅋㅋ 뭔가 소소하게 재미도 있고 긴장감도 있음',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 9, 1, 10),
#   0],
#  ['지구별(myco****)',
#   '배우를 위한 영화가 아니라 영화를 위한 배우들배우를 위한 연출이 아니라 영화를 위한 연출.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 8, 17, 33),
#   0],
#  ['육이공(glqk****)',
#   "나는 항상 '다른 결과의 나'와 살아간다",
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 7, 13, 50),
#   0],
#  ['lucr****',
#   '예민하게 생기셨어요 정말 예민하게 생기셨어요.. 퀄리티는 있지만 연민이 묻어나요, 그림 그리기 전에 우선 자신을 이해해 줄 수 있는 남자부터 찾아보세요.. 때로는 마음속에 있는 솔직한 감정을 그대로 표현하는게 좋겠다...',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 7, 8, 33),
#   0],
#  ['nina(wiza****)',
#   '홍상수 감독님 영화 정말 재미있습니다. 상영관 좀 늘려주세요. 지방에도요.(뭐 아침일찍나 밤늦게라도 좋습니다). 극장에서 보고 싶습니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 7, 1, 10),
#   0],
#  ['noregret(bloo****)',
#   '한번보고 두번봤는데 머릿속에 떠오르는 것들이 다르다. 한번 더 보고 싶고 관계에 질릴 때마다 생각날 것 같은 영화 가벼운 듯 보는 이마다 여러의미를 주는 것 같다.. 솔직하고 싶다',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 6, 20, 22),
#   0],
#  ['ye바다(misu****)',
#   '이런디테일의초점을둔지루할수도있는영화를전혀지루하지않게만드는건 천재여서가능한가??두배우연기대박!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 6, 13, 11),
#   0],
#  ['돌팔이(silo****)',
#   '홍상수식 평행우주 영화',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 6, 1, 59),
#   0],
#  ['발은생활(frie****)',
#   '홍상수 감독 영화 처음 보는 것이라 좀 지루할 줄 알았는데 긴장감도 있고 굉장히 재미있었음. 여자만 캐릭터가 달라지는 줄 알았는데 모두였다. 마지막은 애틋함까지 느껴지더만',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 5, 14, 18),
#   0],
#  ['달타냥(k101****)',
#   '이거 장르가 코미디 맞죠? 보면서 박장대소는 아니지만 입가에 미소가 떠나지를 않네요 아 모든 배우들 연기 기가막히고 소품하나하나 설정하나하나 재미있습니다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 5, 13, 50),
#   0],
#  ['akdl****',
#   '재밌당..김민희졸예인데',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 5, 7, 30),
#   0],
#  ['김동수(kkic****)',
#   '소주가 땡기는 영화라던데 .. 유부남 설레는 영화?',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 3, 22, 6),
#   0],
#  ['Plst(stk8****)',
#   '지금도맞고,그때도맞다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 3, 19, 19),
#   0],
#  ['만두(chla****)',
#   '지금 이순간이 정말 소중하다는 것 그것만으로도 충분하다.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 2, 21, 37),
#   0],
#  ['구름따라(3dmo****)',
#   '홍상수감독영화중에 제일 좋은듯. 지루하지만 빠져들게 하는것 그게 홍상수감독의 영화스타일이다',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 2, 18, 43),
#   0],
#  ['낙찌뽀끔(jsha****)',
#   '무슨.... /./.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 2, 17, 44),
#   0],
#  ['달콤쌉싸름(xnxl****)',
#   '홍상수가 세련되어졌다. 아니 한층 더 예민해졌다. 담백하게 전하는 아이러니의 파트1 과 파트2. 우리가 내뱉는 말의 울림이, 그리고 무의식의 몸짓이 불러오는 파동이 어떤 결과를 가져오는지에 대한 관찰. 맞고 틀리고를...',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 12, 1, 9, 26),
#   0],
#  ['바이오(love****)',
#   '가볍게 봐도, 무겁게 봐도 나름의 재미가 있는 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 30, 16, 48),
#   0],
#  ['Kee(heyd****)',
#   '주변의 환경과 생각에 얼마나 많은 선택을 강요받는가, 자 이젠 스스로에게 솔직할 때가 되었다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 27, 18, 20),
#   0],
#  ['안정숙(flam****)',
#   '이렇게 일상을 툭! 떼어다 놓은것 같은 영화가 좋다. 생생하게 우리들의 이야기가 아닌가!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 26, 23, 21),
#   0],
#  ['DJDN(dltk****)',
#   '처음부터 끝까지 인물들의 예민한 감성에 젖어들며 지금도 그때도 그 안에서 자꾸만 생각해보게 만드는 영화',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 26, 16, 27),
#   0],
#  ['호흡(pirm****)',
#   '기분좋게 야릇하다..',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 26, 12, 38),
#   0],
#  ['지존새댁(78ra****)',
#   '진짜. 올만에 몰입해서 재미있게 본 영화임. 정재영...진짜 연기 짱...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 25, 21, 35),
#   0],
#  ['Com왕(petu****)',
#   '홍상수는 그의 영화에서 오버하지 않는다. 그래서 그의 영화는 영화 같지 않은 대신에 우리의 일상을 그냥 표현한다.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 24, 0, 15),
#   0],
#  ['Dazin(muzi****)',
#   '두가지 나혼자만의 느낌은1. 말로 뭔가 포장하지 마라. 진실이 관계를 옳게 한다. 2. 유부남은 되도록 유부남임을 미리 밝히는게 오히려 약이다. ㅎㅎ',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 23, 23, 36),
#   '관람객'],
#  ['햄리잇(eyay****)',
#   '배우들의 역량이 돋보이는 영화.',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 23, 11, 27),
#   0],
#  ['김비니(kim_****)',
#   '함춘수의 명연기에 안웃을 수가 없음! 지금은 맞고 그때는 틀리네요',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 23, 8, 32),
#   0],
#  ['aedo****',
#   '롱테이크 임에도 불구하고 정재영의 섬세한 연기와 그 와중에 눈물을 흘리는 장면은 아직도 기억이 선명하다..',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 22, 1, 2),
#   0],
#  ['이키리(ppap****)',
#   '같은 상황을 두가지 방식으로 다룬 영화그냥 봐라. 남자가 극강의 찌질한 모습을 보여준다.하지만 다루는 내용은 심오하다. 한번으로는 잘이해하기 어려운 영화다',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 21, 20, 19),
#   0],
#  ['roma****',
#   '홍상수 영화가 아니라 김민희 영화구만',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 21, 10, 12),
#   0],
#  ['자유인(ryuw****)',
#   "이 영화를 한마디로 얘기하자면 '영화관은 틀렸고, 어둠의 경로는 맞다'",
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 21, 1, 3),
#   0],
#  ['bbosong2(seoj****)',
#   '잔잔하면서 약간지루할수도있지만 생활에서일어날수있는충분히자연스런상황들이공감되면서가슴에와닿네요..제가수원사는데수원이배경이되어반가웟습니다^^영화잘보았습니다',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 17, 23, 59),
#   0],
#  ['점일(refi****)',
#   "겨울과 봄의 공존 ''''",
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 17, 18, 31),
#   0],
#  ['동상이몽(yo_t****)',
#   '상영관이 말도 안되게 절대적으로 부족하네요. 경기지역이 1이라니.... 상영관 좀  늘려줘요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 17, 16, 38),
#   0],
#  ['쇼당(redk****)',
#   '김민희씨 연기 정말 잘하시네요....정재영님은 워낙 전부터 좋아 했던 배우지만....김민희씨...포스 ㄷㄷ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 16, 23, 52),
#   0],
#  ['Loooooo(loo0****)',
#   '죽어요그냥. 정재영 진짜 존경스러움♡♡♡',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 16, 23, 2),
#   0],
#  ['와반커반(69dl****)',
#   '리얼리티의 극치랄까...?',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 16, 11, 21),
#   0],
#  ['힐리우스(jazz****)',
#   '같은 시간 , 다른 순간들 , 툭하니 던져진다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 16, 9, 34),
#   0],
#  ['문재웅(zjcm****)',
#   '정재형이랑 김민희 귀여워서  미치겠다 ~~~~ ㅋㅋ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 15, 23, 30),
#   0],
#  ['ashi****',
#   '내  경험상 서투름 속에 감춰진 솔직한 진지함을 알아주는 여자는 단 한명도 없었다.거짓과 만용의 공격성에 벚꽃처럼 우수수 져버리는 여자만 봤다.',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 15, 13, 52),
#   0],
#  ['아잠시(baby****)',
#   '영화에대한 오만함을 없애준영화 많이배웠고 겸손해지겠습니다 감독님',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 15, 5, 46),
#   0],
#  ['태엽감는새(thsw****)',
#   '지금은 맞다고 생각했던게  나중엔 틀린거였다고 생각할수 있고 지금은 틀리다고 생각했던것이 결국엔 맞았던 걸수도 있다. 존재와 관계는 고정적인 것이 아니라 변화무쌍하고 얽히고 섥혀있어 예측불가능. 그렇다면 우린 계속생...',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 15, 3, 0),
#   0],
#  ['k053****',
#   '참.... 멋있진 않지만 맛있다 ..',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 15, 1, 32),
#   0],
#  ['하얀색(bboy****)',
#   '완벽했다. 성공적 과 뒤틀림 그리고 로맨틱 과 성공적 정재영!!!  , 김민희 의 재발견 양계장에 침을 뱉어라!!! 말이 안되게 말되게 하고 싶은 명작이다.!! 엘리엇 스미스가 관 을 뚫고 나와 팝콘을 보며 느꼈을 ...',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 15, 1, 15),
#   0],
#  ['me2day(all2****)',
#   '남자의 찌질함에 대해..',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 13, 22, 55),
#   '관람객'],
#  ['snappyprism(ssoi****)',
#   'ㅎㅎㅎ 병맛코드 최고!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 11, 18, 49),
#   '관람객'],
#  ['dani****',
#   '기대를 너무 많이 했나..So so..',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 7, 8, 44),
#   '관람객'],
#  ['최연주(wwmm****)',
#   '영화를 보고 나와서 영화에 대한 해석을 찾아보면 그때서야 이해가는 영화랄까....',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 7, 1, 26),
#   '관람객'],
#  ['순야(bell****)',
#   '참 리얼하다.오그라드는줄 앎. 느글느글. 이해가 된다. 공감된다.는 사람들 중 여자 있나? 하긴 침흘리는 군내나는 개저씨들 많긴 하더라. 젊으나 늙으나 예술동네서 헤롱거리는 여자들도 아직도 많이 있기는 하고.예술가연...',
#   '3',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 6, 13, 30),
#   0],
#  ['킴(ppp7****)',
#   '읭? 이라는 생각이 들었던..',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 6, 9, 59),
#   '관람객'],
#  ['destroyer(st4r****)',
#   '캐스팅도 그렇고 새로움에 기대를 가졌는데 좀 아쉽네요',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 10, 26, 2, 2),
#   '관람객'],
#  ['wow8****',
#   '과장되고 우려먹는 상반부  인물에 대한 연민과 위트있는 후반부',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 10, 25, 19, 27),
#   '관람객'],
#  ['SH(soni****)',
#   '유쾌한 꿈을 꾼 기분이 드는 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 10, 22, 16, 3),
#   '관람객'],
#  ['소우주(cosm****)',
#   '감독님... 정말 팬이에요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 10, 21, 23, 56),
#   '관람객'],
#  ['hoey****',
#   '홍상수스럽지 않았던 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 10, 13, 0, 0),
#   '관람객'],
#  ['동땡이(elec****)',
#   '유부남이 어떻게든 이쁜여자 꼬셔보려고 애쓰는 영화',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2019, 7, 7, 10, 1),
#   0],
#  ['ad(ditl****)',
#   '제목지은 꼬라지봐라 배우자에 대한 배려라고는 1도 없네 혼자 늙어죽을때 그때도 틀렸고 지금도 틀리다 영화나 내쇼',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2019, 4, 25, 1, 6),
#   0],
#  ['chdl****',
#   '모르겠고 초반 보는데 내가 너무 창피했다 내 생각나서',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2019, 4, 21, 15, 15),
#   0],
#  ['이라미르(hjle****)',
#   '흠      이영화로인해... 사회적인..',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2019, 1, 3, 19, 18),
#   0],
#  ['콥등이 부들부들(7606****)',
#   '왜 미성년자관람불가?야한거 하나 안나오노 ..홍상수 영화속 인물들은 다 제정신이 아니야',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2018, 6, 13, 14, 47),
#   0],
#  ['모노(moor****)',
#   '하고 싶은 말을 하며 사는 인간은 축복받은 인간이다.',
#   '7',
#   '2',
#   '1',
#   datetime.datetime(2017, 12, 24, 23, 22),
#   0],
#  ['pean****',
#   "두번째가 시작할때 '오,수정'과 비슷하려나 했는데 또다른시각의 느낌!무얼 말하려는지 어렴풋 알겠는 느낌.사람은 그림을 보든 누군가를 보든 자신을 투영해서 보려한다는거,어렵지만 대충은 알것 같다.그리고 ...",
#   '7',
#   '2',
#   '1',
#   datetime.datetime(2017, 11, 1, 4, 8),
#   0],
#  ['김창수(kcs9****)',
#   '그의 영화는 홍상수의 변호인이다.',
#   '8',
#   '2',
#   '1',
#   datetime.datetime(2017, 5, 27, 20, 30),
#   0],
#  ['바람의언덕(sipj****)',
#   '홍상수, 김민희의 100% 리얼 자전적 이야기.',
#   '8',
#   '2',
#   '1',
#   datetime.datetime(2017, 5, 2, 21, 54),
#   0],
#  ['김정현(lj82****)',
#   '궁금해서 보려 했으나 너무 지루해서  다 보지 못함',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2017, 4, 13, 15, 23),
#   0],
#  ['Double saber(shsr****)',
#   '조물주 앞에 부끄럽지 않으세요 할아버지?',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2017, 3, 16, 16, 34),
#   0],
#  ['스누피(so80****)',
#   '그때도 틀리고 지금도 틀리다 간통죄 부활시켜야함 !',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2017, 3, 13, 19, 42),
#   0],
#  ['Lovely poison(yj23****)',
#   '바람 펴서 여기까지 와 보니 지금은 바람(지들이 생각하기에는 사랑)피게 된게 맞고 그 당시(이제 막 설레인답씨고 시작하면서 딴에 양심에 찔려 고민하는척 했을)에는 틀렸다고 합리화 시키느라 부단히도 애쓴 영화.',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 12, 31, 1, 2),
#   0],
#  ['N_JINNY(sksk****)',
#   '극장에서는 지루해도 괜찮은 영화라고 봤고 무슨 이야기가 하고싶은건지 몰랐는데 이제야 알것 같다 이 영화의 의미를',
#   '6',
#   '2',
#   '1',
#   datetime.datetime(2016, 10, 13, 10, 42),
#   '관람객'],
#  ['jukebox(daro****)',
#   '홍상수감독의 자기반영성에 관한 에피소드는 늘 그래왔듯이 지속되고 있었으나.. 사생활이 노출된 이후 현실과 극영화의 경계가 무너지면서 이입자체가 다르게 해석된다. 그러나 감독은 지금도 그랬고 그때도 그랬다..',
#   '8',
#   '2',
#   '1',
#   datetime.datetime(2016, 10, 4, 2, 35),
#   0],
#  ['dc마트(whgk****)',
#   '피곤한데 보다가 잘잤습니다.',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 8, 27, 18, 57),
#   0],
#  ['엘츠(uiek****)',
#   '더럽다 더러워부인은 진짜 착한 사람같은데부인이랑 딸한테 무슨 짓이야똑같이 돌려받고 지옥에나 떨어져라',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 7, 12, 12, 34),
#   0],
#  ['123w****',
#   '지금은다르지열자열자',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 28, 16, 4),
#   0],
#  ['ping9(als4****)',
#   '감독의 치먕적인 윤리적 결함',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 27, 23, 57),
#   0],
#  ['0666****',
#   '노답인영화^^ 비추입니다',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 22, 39),
#   0],
#  ['아지(dudw****)',
#   'ㅡㅡ 뭐 이렇지...????',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 22, 22),
#   0],
#  ['aijj****',
#   'ㅋ ㅋ ㅋ ㅋ  정말어이가없네',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 22, 1),
#   0],
#  ['용구리(yong****)',
#   '감독 철학부족,  배우 연기 철학부족',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 20, 51),
#   0],
#  ['햇살마리(yoon****)',
#   '별로에요....,....,',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 20, 25),
#   0],
#  ['민콩(j612****)',
#   '지금은맞고 그때는 틀니다',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 20, 4),
#   0],
#  ['wjd9****',
#   '지금은 절대 틀렸다 예술이랍시고... 더러움',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 18, 59),
#   0],
#  ['ㅇ(0105****)',
#   '1점 드리고가용 깔깔깔',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 18, 50),
#   0],
#  ['airf****',
#   '이건 뭐. 에휴....',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 18, 44),
#   0],
#  ['얄리(reji****)',
#   "지금도 그때도 틀림!'?!,?!?,.",
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 17, 23),
#   0],
#  ['xhfl****',
#   'ㅉㅉㅉㅉ정신 좀 차리지',
#   '1',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 22, 16, 39),
#   0],
#  ['Seungcho(stel****)',
#   '그때는틀리고지금은맞다',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2016, 6, 11, 17, 41),
#   '관람객'],
#  ['주라리(jura****)',
#   '생각했던 모든 시나리오를 뒤집은 영화. 신선한 충격이었습니다.',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2016, 5, 30, 12, 10),
#   '관람객'],
#  ['풋내기(jisu****)',
#   '믿음에 충분히 부합하는 홍상수 감독과 발군의 연기력 정재영!',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2016, 5, 17, 16, 55),
#   '관람객'],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                      0  ...    6
# 0       우리동네(nnli****)  ...    0
# 1       샤막여우(saew****)  ...    0
# 2       이로사사(dnjs****)  ...    0
# 3      바ㄱ수지ㄴ(xoxo****)  ...  관람객
# 4             kink****  ...    0
# ...                ...  ...  ...
# 2575    멸치오빠(song****)  ...    0
# 2576      개한(imda****)  ...    0
# 2577  ableso(smar****)  ...    0
# 2578    웨이헤밍(chom****)  ...    0
# 2579          thes****  ...    0
#
# [2580 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#               nickname  ... watch_movie
# 0       우리동네(nnli****)  ...           0
# 1       샤막여우(saew****)  ...           0
# 2       이로사사(dnjs****)  ...           0
# 3      바ㄱ수지ㄴ(xoxo****)  ...         관람객
# 4             kink****  ...           0
# ...                ...  ...         ...
# 2575    멸치오빠(song****)  ...           0
# 2576      개한(imda****)  ...           0
# 2577  ableso(smar****)  ...           0
# 2578    웨이헤밍(chom****)  ...           0
# 2579          thes****  ...           0
#
# [2580 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
